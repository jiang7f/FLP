# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit_aer import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits))
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(3, 100, 3):
  print(f'rand == {i}')
  test(20, 3, np.random.rand(2 * 3))
# Out:
# rand == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.0455
#        x: [ 3.744e-01  2.098e-01  1.372e+00  7.580e-01  8.259e-01
#             1.310e-01]
#     nfev: 60
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 5.9% 81
# 0000000000 4.4% 40
# 0100010000 3.2% 43
# 0101000000 3.1% 43
# 0001000000 2.0% 42
# 0000010000 2.0% 42
# 0000000001 1.9% 60
# 0101010000 1.9% 5
# 0000000100 1.8% 60
# 0100110000 1.7% 84
# 0111000000 1.7% 84
# 0100000010 1.4% 101
# 0100001000 1.4% 101
# 0100010010 1.0% 63
# 0101001000 1.0% 63
# 0000001000 1.0% 60
# 0000000010 1.0% 60
# 0011000000 0.9% 83
# 0000110000 0.9% 83
# 0001000001 0.9% 62
# rand == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.663
#        x: [ 4.627e-01  1.934e+00  3.815e-01  1.865e+00  6.788e-01
#             6.514e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0010100000 16.5% 42
# 1010100000 3.8% 4
# 0110110000 3.3% 85
# 0111100000 3.2% 85
# 1010100010 3.0% 24
# 1010101000 2.9% 24
# 0111110000 2.4% 87
# 0010100100 1.7% 62
# 0010100001 1.6% 62
# 0000101000 1.4% 61
# 0010000010 1.3% 61
# 0001100000 1.2% 43
# 1010000000 1.1% 43
# 1000100000 1.1% 43
# 0110100000 1.1% 83
# 0010010000 1.1% 43
# 1001100000 1.0% 45
# 1010010000 1.0% 45
# 0010110000 0.7% 84
# 0011100000 0.7% 84
# rand == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.265
#        x: [ 8.169e-01  3.260e-01  3.094e-01  1.585e+00 -6.531e-02
#             1.202e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1001010000 2.9% 86
# 1101110000 2.6% 48
# 1101010000 2.6% 47
# 1111010000 2.6% 48
# 1011010000 1.9% 87
# 1001110000 1.9% 87
# 1111110000 1.9% 49
# 1001010010 1.7% 66
# 1001011000 1.6% 66
# 1101010010 1.5% 27
# 1101011000 1.5% 27
# 0001010000 1.4% 44
# 0101010000 1.2% 5
# 1001100000 1.1% 45
# 1010010000 1.1% 45
# 1111010010 1.0% 28
# 1101111000 1.0% 28
# 1101000000 0.9% 85
# 1111000000 0.9% 86
# 1100010000 0.9% 85
# rand == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 54.867
#        x: [ 4.640e-01  1.950e-01  1.667e+00  9.290e-01  8.480e-01
#             8.716e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 12.7% 44
# 0101010000 12.6% 5
# 0000010000 4.5% 42
# 0001000000 4.4% 42
# 1101010000 3.9% 47
# 1001010000 3.4% 86
# 0101000000 2.2% 43
# 0100010000 2.2% 43
# 0000000000 1.6% 40
# 0101000001 1.5% 23
# 0100010100 1.4% 23
# 0101010100 1.3% 25
# 0101010001 1.2% 25
# 0001010010 1.1% 64
# 0001011000 1.1% 64
# 0101011000 1.0% 25
# 0101010010 1.0% 25
# 0101110010 1.0% 106
# 0111011000 1.0% 106
# 0011011000 1.0% 145
# rand == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 63.357
#        x: [ 3.052e-01  1.345e+00  8.638e-01  1.697e+00  3.251e-01
#             4.824e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 12.4% 44
# 1001010000 4.4% 86
# 0001010010 3.8% 64
# 0001011000 3.7% 64
# 0101010000 3.0% 5
# 0000010000 2.7% 42
# 0001000000 2.6% 42
# 1011010000 2.0% 87
# 1001110000 2.0% 87
# 0001000001 1.5% 62
# 0000010100 1.5% 62
# 0000000000 1.5% 40
# 0101000000 1.3% 43
# 0100010000 1.3% 43
# 1101010000 1.1% 47
# 0101000001 1.1% 23
# 0100010100 1.1% 23
# 0100000000 1.0% 81
# 0101010001 0.9% 25
# 0101010100 0.9% 25
# rand == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.7415
#        x: [ 1.267e+00  8.426e-02  8.707e-01  6.564e-01  1.448e+00
#             2.475e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 10.7% 47
# 0101010000 4.0% 5
# 1000000000 3.6% 82
# 1110010000 2.8% 46
# 1101100000 2.8% 46
# 1001010000 1.9% 86
# 1101100001 1.9% 26
# 1110010100 1.8% 26
# 1110100000 1.5% 45
# 0000000000 1.4% 40
# 1001000000 1.3% 84
# 1000010000 1.3% 84
# 1100010000 1.2% 85
# 1101000000 1.1% 85
# 0101011010 1.0% 45
# 1100100000 1.0% 84
# 1110000000 1.0% 84
# 0101010010 1.0% 25
# 0101011000 1.0% 25
# 1101010001 0.9% 67
# rand == 21
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 71.181
#        x: [ 7.279e-01  5.976e-01  8.107e-01  6.416e-01  8.940e-01
#             7.840e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 5.5% 40
# 0001000000 3.5% 42
# 0000010000 3.5% 42
# 0001010000 3.1% 44
# 0101010000 2.9% 5
# 0100000001 2.0% 61
# 0100000100 2.0% 61
# 0100010100 1.8% 23
# 0101000001 1.8% 23
# 0101000000 1.5% 43
# 0100010000 1.4% 43
# 0100000101 1.1% 41
# 1000000000 0.9% 82
# 0000001000 0.9% 60
# 0000000010 0.8% 60
# 0000100010 0.8% 101
# 0000000100 0.8% 60
# 1001000000 0.8% 84
# 1000010000 0.8% 84
# 0010001000 0.8% 101
# rand == 24
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 66.546
#        x: [ 6.401e-01  8.075e-01  1.223e+00  5.344e-02  6.196e-01
#            -1.194e-02]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 2.9% 47
# 1101010010 1.8% 27
# 1101011000 1.8% 27
# 1110100000 1.7% 45
# 1110010100 1.2% 26
# 1101100001 1.2% 26
# 0101010000 1.1% 5
# 1110100001 1.1% 25
# 1110100100 1.1% 25
# 1110010000 1.0% 46
# 1101100000 1.0% 46
# 1010100000 0.9% 4
# 1110010010 0.9% 26
# 1101101000 0.9% 26
# 1101110010 0.8% 68
# 1101000001 0.8% 65
# 1111011000 0.8% 68
# 1100010100 0.8% 65
# 1101110000 0.7% 48
# 1101000011 0.7% 45
# rand == 27
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 63.7745
#        x: [ 1.707e+00  1.249e+00  6.711e-01  8.073e-01  1.305e+00
#             2.945e-01]
#     nfev: 79
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1100001111 6.1% 43
# 1100101111 2.6% 44
# 1100011111 2.5% 45
# 1101001111 2.5% 45
# 1110001111 2.5% 44
# 1100011110 1.7% 25
# 1000001111 1.7% 82
# 1101001011 1.7% 25
# 1100001101 1.7% 63
# 1100000111 1.6% 63
# 0110100101 1.6% 43
# 1100001011 1.3% 63
# 1100001110 1.3% 63
# 1100101101 1.1% 24
# 1110000111 1.1% 24
# 1101001101 0.9% 65
# 1100010111 0.9% 65
# 1101011111 0.9% 47
# 1100101110 0.8% 64
# 1110001011 0.8% 64
# rand == 30
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 67.5165
#        x: [ 1.722e+00  1.672e-01  2.240e+00  4.846e-01  1.630e+00
#             1.802e+00]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0111110000 10.5% 87
# 0111010000 5.5% 46
# 0101110000 5.4% 46
# 1111110000 5.0% 49
# 1101110000 3.7% 48
# 1111010000 3.7% 48
# 0101010000 3.6% 5
# 1111111000 2.4% 69
# 1101010000 2.4% 47
# 1111110010 2.4% 69
# 0110110000 1.7% 85
# 0111100000 1.7% 85
# 1111011000 1.3% 68
# 1101110010 1.3% 68
# 1101111000 1.2% 28
# 1111010010 1.2% 28
# 0110010000 1.0% 44
# 0101100000 1.0% 44
# 1111100000 0.8% 47
# 1110110000 0.8% 47
# rand == 33
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 73.0005
#        x: [ 1.171e+00  1.929e+00  5.614e-01  1.454e+00  1.868e-01
#             8.733e-01]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100101 2.8% 5
# 1101011111 2.7% 47
# 1101101101 1.6% 26
# 1110010111 1.6% 26
# 1100010111 1.2% 65
# 1101001101 1.1% 65
# 1110100001 1.1% 25
# 0101001111 1.0% 83
# 1110100100 1.0% 25
# 0100011111 1.0% 83
# 1110010101 0.9% 46
# 1101100101 0.9% 46
# 0100001111 0.8% 81
# 1101101111 0.7% 46
# 1110011111 0.7% 46
# 0101011111 0.7% 85
# 0110100101 0.7% 43
# 1010100101 0.6% 44
# 1110010011 0.5% 46
# 1101101100 0.5% 46
# rand == 36
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.7665
#        x: [ 4.306e-01  6.975e-02  1.336e+00  1.169e-01  9.593e-01
#             5.182e-01]
#     nfev: 62
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 10.5% 47
# 0101010000 5.4% 5
# 0111110000 4.9% 87
# 1111110000 4.4% 49
# 1101110000 4.0% 48
# 1111010000 4.0% 48
# 0101110000 2.8% 46
# 0111010000 2.8% 46
# 1001000000 1.6% 84
# 1000010000 1.6% 84
# 0001000000 1.1% 42
# 1111010010 1.1% 28
# 0000010000 1.1% 42
# 1101111000 1.0% 28
# 1101010010 0.9% 27
# 1101011000 0.9% 27
# 1101100000 0.9% 46
# 1111000000 0.9% 86
# 1110010000 0.9% 46
# 1100110000 0.9% 86
# rand == 39
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 79.8165
#        x: [ 8.714e-01  1.252e+00  1.711e+00  1.237e+00  1.516e+00
#             1.805e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100110001 0.9% 104
# 0101000000 0.8% 43
# 0101000001 0.8% 23
# 0100010000 0.8% 43
# 0111000100 0.8% 104
# 0100010100 0.8% 23
# 1111111001 0.8% 89
# 1111110110 0.8% 89
# 0101010000 0.8% 5
# 1111110101 0.7% 89
# 0100000000 0.7% 81
# 1111111010 0.6% 89
# 0101010011 0.6% 45
# 1111110000 0.6% 49
# 1111111000 0.6% 69
# 1111110010 0.6% 69
# 0101011100 0.6% 45
# 0101010001 0.6% 25
# 1110111110 0.6% 67
# 1110101010 0.6% 85
# rand == 42
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 71.642
#        x: [ 1.410e-01  1.814e+00  1.489e+00  4.443e-01  3.439e-01
#             5.662e-01]
#     nfev: 84
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0010100000 2.3% 42
# 0011100000 2.0% 84
# 0010110000 2.0% 84
# 0011110000 1.9% 126
# 1010100000 1.8% 4
# 1010110000 1.6% 46
# 1011100000 1.6% 46
# 0010010000 1.4% 43
# 0001100000 1.4% 43
# 0011010000 1.4% 85
# 0110100000 1.4% 83
# 1011110000 1.4% 88
# 0001110000 1.3% 85
# 1010010000 1.2% 45
# 1001100000 1.2% 45
# 0111100000 1.1% 85
# 0000100000 1.1% 41
# 0110110000 1.1% 85
# 0010000000 1.1% 41
# 0000110000 1.1% 83
# rand == 45
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.666
#        x: [ 1.276e-01  1.774e+00  7.525e-01  4.009e-01  6.956e-01
#             8.237e-01]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 15.0% 40
# 0000010000 6.0% 42
# 0001000000 5.9% 42
# 0100000000 5.7% 81
# 0100000100 3.1% 61
# 0100000001 3.1% 61
# 0000000100 3.1% 60
# 0000000001 3.0% 60
# 0000001000 2.6% 60
# 0000000010 2.6% 60
# 0001010000 2.0% 44
# 0000000101 1.7% 80
# 0100010000 1.3% 43
# 0101000000 1.3% 43
# 0001000001 1.1% 62
# 1000000000 1.1% 82
# 0000010100 1.1% 62
# 0001000010 1.0% 62
# 0100000010 1.0% 101
# 0100001000 0.9% 101
# rand == 48
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.441
#        x: [ 1.652e+00  2.396e+00  1.713e+00  9.601e-01  1.790e-01
#            -1.603e-02]
#     nfev: 80
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100101 1.1% 5
# 1100100001 1.0% 64
# 1100101101 1.0% 24
# 1110000111 1.0% 24
# 1110000100 1.0% 64
# 1110000101 0.9% 44
# 1100100101 0.9% 44
# 1010000000 0.9% 43
# 1100101001 0.9% 44
# 1010100000 0.9% 4
# 1110000110 0.9% 44
# 1000101000 0.9% 23
# 1010000010 0.9% 23
# 1000100000 0.9% 43
# 1111100001 0.8% 27
# 1000000000 0.8% 82
# 1110100100 0.8% 25
# 1110100001 0.8% 25
# 1100000000 0.8% 123
# 1100100000 0.7% 84
# rand == 51
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.7325
#        x: [ 1.318e+00  3.332e-01 -1.598e-01  9.497e-01  6.813e-01
#             1.801e+00]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 14.3% 40
# 0000010000 5.5% 42
# 0001000000 5.5% 42
# 0000000100 3.8% 60
# 0000000001 3.8% 60
# 1000000000 3.1% 82
# 0000001000 2.7% 60
# 0000000010 2.6% 60
# 0001010000 2.5% 44
# 0100000000 1.8% 81
# 1000010000 1.5% 84
# 1001000000 1.5% 84
# 1000001000 1.4% 62
# 1000000010 1.4% 62
# 0001000001 1.2% 62
# 0000010100 1.2% 62
# 0001000010 1.1% 62
# 0000010010 1.1% 62
# 0000011000 1.1% 62
# 0001001000 1.0% 62
# rand == 54
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.658
#        x: [ 1.194e+00  9.681e-01  3.432e-02  6.393e-01  3.596e-01
#             7.079e-01]
#     nfev: 62
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 15.5% 40
# 1000000000 5.1% 82
# 0100000000 4.9% 81
# 0001000000 3.6% 42
# 0000010000 3.5% 42
# 0101000000 2.3% 43
# 0100010000 2.3% 43
# 1000100000 1.6% 43
# 1010000000 1.6% 43
# 1100000000 1.5% 123
# 1000000010 1.4% 62
# 0000000100 1.4% 60
# 1000001000 1.4% 62
# 0000000001 1.3% 60
# 0101010000 1.1% 5
# 1000010000 1.1% 84
# 0000100000 1.1% 41
# 1001000000 1.1% 84
# 0010000000 1.0% 41
# 1000100010 1.0% 63
# rand == 57
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.159
#        x: [ 4.673e-01  1.639e+00  4.312e-03 -1.429e-03  3.266e-01
#             1.607e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 31.4% 40
# 0000000001 6.3% 60
# 0000000100 6.3% 60
# 0000001000 6.3% 60
# 0000000010 6.2% 60
# 1000000000 2.9% 82
# 0000100000 2.1% 41
# 0010000000 2.0% 41
# 0000001010 1.6% 80
# 0000000101 1.5% 80
# 0000000011 1.3% 80
# 0000000110 1.2% 80
# 0000001001 1.2% 80
# 0000001100 1.2% 80
# 0000100010 1.1% 101
# 0010001000 1.1% 101
# 0100000000 0.9% 81
# 1000000100 0.6% 102
# 0010000100 0.6% 61
# 1000000001 0.6% 102
# rand == 60
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 51.452
#        x: [-1.406e+00  3.646e+00  8.044e-01  3.208e-01  6.000e-01
#            -8.564e-02]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 35.3% 40
# 0000100000 8.7% 41
# 0010000000 8.7% 41
# 0001000000 4.2% 42
# 0000010000 4.1% 42
# 1000000000 3.7% 82
# 0010100000 2.0% 42
# 0100000001 1.7% 61
# 0100000100 1.7% 61
# 1000001000 1.1% 62
# 1000000010 1.1% 62
# 0000000010 1.0% 60
# 0000001000 0.9% 60
# 0010010000 0.9% 43
# 0001100000 0.9% 43
# 0111000100 0.8% 104
# 0100110001 0.8% 104
# 1010000000 0.8% 43
# 1000100000 0.7% 43
# 0100000000 0.7% 81
# rand == 63
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.088
#        x: [ 1.739e+00  2.422e-01  4.330e-01  9.712e-01  6.018e-01
#             1.384e+00]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 4.6% 47
# 0101010000 4.4% 5
# 1110010000 2.4% 46
# 1101100000 2.4% 46
# 1110100000 2.3% 45
# 1101011000 2.2% 27
# 1101010010 2.1% 27
# 1101010001 1.8% 67
# 1101010100 1.7% 67
# 0101010001 1.3% 25
# 0101010100 1.3% 25
# 1001010000 1.3% 86
# 0101010010 1.0% 25
# 0101011000 0.9% 25
# 1111010000 0.8% 48
# 1101101000 0.8% 26
# 1101010110 0.8% 47
# 1101110000 0.8% 48
# 1101011001 0.8% 47
# 1110010010 0.8% 26
# rand == 66
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 87.3695
#        x: [ 1.080e+00  1.605e+00  6.861e-01  1.395e+00  1.327e+00
#             1.316e+00]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101011111 1.9% 85
# 0000001010 1.5% 80
# 0100011011 1.2% 103
# 0101001110 1.2% 103
# 1101010101 1.0% 87
# 0100001010 0.9% 121
# 0011110000 0.8% 126
# 0100011111 0.7% 83
# 0101001111 0.7% 83
# 0101000110 0.7% 83
# 1101011111 0.7% 47
# 1101101111 0.6% 46
# 1100010001 0.6% 105
# 1110011111 0.6% 46
# 0100011001 0.6% 83
# 1101101101 0.6% 26
# 1100100010 0.6% 104
# 1110001000 0.6% 104
# 1101010111 0.6% 67
# 1101011101 0.6% 67
# rand == 69
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 56.562
#        x: [ 1.440e+00  1.622e-01  7.692e-01  3.272e-01  1.664e-01
#             5.101e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 37.6% 40
# 0100000000 7.6% 81
# 1000000000 4.2% 82
# 0001000000 2.5% 42
# 0000010000 2.5% 42
# 1000000010 1.8% 62
# 1000001000 1.8% 62
# 1010000000 1.6% 43
# 1000100000 1.6% 43
# 0010000000 1.5% 41
# 0000100000 1.4% 41
# 1000100010 1.1% 63
# 1010001000 1.1% 63
# 0000000001 1.0% 60
# 0000000100 1.0% 60
# 1000001010 0.9% 42
# 1100000000 0.9% 123
# 0100000101 0.8% 41
# 0101000000 0.8% 43
# 0100010000 0.8% 43
# rand == 72
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.572
#        x: [ 1.887e-01  9.242e-01  1.983e-01  1.423e+00  1.747e+00
#             1.953e+00]
#     nfev: 75
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 5.0% 45
# 1010100000 3.5% 4
# 0110100000 2.6% 83
# 0110000000 2.4% 82
# 0100100000 2.3% 82
# 0010100000 1.9% 42
# 1110100010 1.6% 65
# 1110101000 1.5% 65
# 1010100001 1.3% 24
# 1010100100 1.2% 24
# 1010010000 1.2% 45
# 0100000000 1.1% 81
# 1001100000 1.1% 45
# 1010101000 1.1% 24
# 1100101000 1.0% 64
# 0010000001 1.0% 61
# 1110000010 1.0% 64
# 0000100100 1.0% 61
# 0011100000 1.0% 84
# 0010110000 1.0% 84
# rand == 75
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 94.753
#        x: [ 1.070e+00  1.834e+00  1.677e+00  7.314e-01  4.208e-01
#             3.731e-01]
#     nfev: 62
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 0.9% 81
# 1011111010 0.8% 128
# 1000000000 0.7% 82
# 1111111111 0.7% 129
# 1100001100 0.6% 83
# 1010111001 0.6% 126
# 1100000011 0.6% 83
# 0000001011 0.5% 100
# 0000001110 0.5% 100
# 0100011101 0.5% 63
# 1111010100 0.5% 68
# 1011100110 0.5% 126
# 1101110001 0.5% 68
# 0100001111 0.5% 81
# 1100000110 0.5% 83
# 0101000111 0.5% 63
# 1100001001 0.5% 83
# 1100000000 0.5% 123
# 0111110101 0.5% 127
# 0101010101 0.4% 45
# rand == 78
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 67.053
#        x: [ 8.349e-01  4.114e-01  1.598e-01  9.643e-01  1.251e+00
#             1.992e+00]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 4.4% 47
# 0101010000 3.6% 5
# 1101110000 3.4% 48
# 1111010000 3.3% 48
# 1111110000 2.9% 49
# 1100010000 2.8% 85
# 1101000000 2.8% 85
# 1000000000 2.6% 82
# 1100110000 2.3% 86
# 1111000000 2.3% 86
# 1100000000 1.8% 123
# 0101000000 1.7% 43
# 1001000000 1.7% 84
# 1000010000 1.6% 84
# 0100010000 1.6% 43
# 1000110000 1.2% 85
# 1011000000 1.2% 85
# 0000000000 1.2% 40
# 0000010000 1.0% 42
# 0001000000 1.0% 42
# rand == 81
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 66.131
#        x: [ 1.155e+00  7.633e-02  1.395e-01  1.461e-01  1.765e+00
#             1.933e+00]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 11.8% 49
# 1111100000 4.8% 47
# 1110110000 4.7% 47
# 1111110100 2.4% 69
# 1111110001 2.3% 69
# 1110100000 1.8% 45
# 1101110000 1.7% 48
# 1111010000 1.7% 48
# 1111111000 1.7% 69
# 1111110010 1.6% 69
# 1100110000 1.6% 86
# 1111000000 1.5% 86
# 1110110001 1.1% 67
# 1111100100 1.0% 67
# 1110111000 1.0% 67
# 1111100010 1.0% 67
# 1110110100 1.0% 27
# 1111010010 1.0% 28
# 1101111000 0.9% 28
# 1111100001 0.9% 27
# rand == 84
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 66.156
#        x: [ 7.970e-01 -2.993e-01  1.475e+00  6.162e-01  4.167e-01
#             6.601e-01]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 4.7% 45
# 1110010000 2.3% 46
# 1101100000 2.2% 46
# 1110110000 2.1% 47
# 1111100000 2.0% 47
# 1110100010 1.6% 65
# 1110101000 1.6% 65
# 1010100000 1.6% 4
# 0100000000 1.5% 81
# 0110100000 1.5% 83
# 1100000000 1.4% 123
# 1100010000 1.2% 85
# 1101000000 1.2% 85
# 1010100001 1.1% 24
# 1101010000 1.1% 47
# 1010100100 1.1% 24
# 0101000000 1.1% 43
# 0100010000 1.0% 43
# 1100100000 1.0% 84
# 1110000000 0.9% 84
# rand == 87
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 56.022
#        x: [ 1.477e+00  1.196e+00  9.624e-01  3.917e-03  3.371e-01
#             1.077e-01]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 19.0% 40
# 0000100000 7.2% 41
# 0010000000 7.1% 41
# 0000010000 5.0% 42
# 0001000000 4.9% 42
# 0011000000 2.5% 83
# 0000110000 2.5% 83
# 0010100000 2.5% 42
# 0010010000 2.1% 43
# 0001100000 2.1% 43
# 0000000100 1.9% 60
# 0000000001 1.8% 60
# 0000001000 1.7% 60
# 0000000010 1.7% 60
# 0100000000 1.4% 81
# 0010110000 1.0% 84
# 1010100000 1.0% 4
# 0001010000 0.9% 44
# 0011100000 0.9% 84
# 0110000000 0.9% 82
# rand == 90
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 55.268
#        x: [ 1.174e+00  2.727e-01  5.322e-01  1.759e-02  7.321e-01
#             8.914e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 25.0% 40
# 0100000000 15.0% 81
# 0000010000 10.6% 42
# 0001000000 10.5% 42
# 0001010000 3.1% 44
# 1010100000 1.4% 4
# 0100000101 1.4% 41
# 0100000100 1.4% 61
# 0100000001 1.3% 61
# 1000000000 1.3% 82
# 1010000010 0.8% 23
# 1000101000 0.8% 23
# 0000000001 0.8% 60
# 0000000100 0.8% 60
# 0100010000 0.7% 43
# 0011000000 0.7% 83
# 0101000000 0.7% 43
# 0000110000 0.7% 83
# 1100000000 0.7% 123
# 1000010000 0.6% 84
# rand == 93
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 70.998
#        x: [ 1.568e+00  2.137e+00 -3.490e-01  1.738e+00  5.073e-01
#             1.966e+00]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 3.9% 5
# 0101100000 3.5% 44
# 0110010000 3.5% 44
# 0100100000 3.5% 82
# 0110000000 3.4% 82
# 0110100000 2.6% 83
# 0100010000 2.4% 43
# 0101000000 2.3% 43
# 0100000000 2.0% 81
# 0000000000 1.3% 40
# 0110000001 1.2% 62
# 0100100100 1.2% 62
# 1110100000 1.1% 45
# 0101100001 1.1% 24
# 0110010100 1.1% 24
# 0100010100 1.1% 23
# 0101000001 1.1% 23
# 0000100001 1.0% 61
# 0010000100 1.0% 61
# 0101110000 0.9% 46
# rand == 96
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 63.261
#        x: [-3.971e-01  1.646e+00  4.834e-01 -5.852e-01 -3.317e-01
#             1.509e+00]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 6.9% 40
# 0101010000 5.4% 5
# 0001010000 4.8% 44
# 0011110000 3.2% 126
# 0011000000 3.1% 83
# 0001000000 3.1% 42
# 0000110000 3.0% 83
# 0000010000 3.0% 42
# 0001110000 2.3% 85
# 0011010000 2.3% 85
# 1010100000 1.6% 4
# 1001110000 1.6% 87
# 1011010000 1.6% 87
# 0111010000 1.4% 46
# 0101110000 1.3% 46
# 0100000000 1.2% 81
# 0100000100 1.1% 61
# 0100000001 1.0% 61
# 1001100000 0.9% 45
# 1010010000 0.9% 45
# rand == 99
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 71.027
#        x: [ 7.217e-01  1.974e+00  3.678e-01  1.252e-01  2.002e-01
#             9.789e-01]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 13.1% 40
# 0000000100 5.6% 60
# 0000000001 5.5% 60
# 0000000010 5.3% 60
# 0000001000 5.3% 60
# 0000001010 3.0% 80
# 0000000101 2.7% 80
# 0000000110 2.2% 80
# 0000001001 2.2% 80
# 0000000011 2.1% 80
# 0000001100 2.1% 80
# 0000110000 1.2% 83
# 0011000000 1.1% 83
# 0000001110 1.1% 100
# 0000001011 1.1% 100
# 1000100010 1.0% 63
# 0000000111 1.0% 100
# 0000001101 1.0% 100
# 0100010001 0.9% 63
# 1010001000 0.9% 63
