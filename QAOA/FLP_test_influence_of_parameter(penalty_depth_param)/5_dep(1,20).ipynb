# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit_aer import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits)) # transpile
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(1, 20):
  print(f'depth == {i}')
  test(20, i, np.full(i * 2, np.pi/4))
# Out:
# depth == 1
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 66.019
#        x: [ 1.533e+00  7.624e-01]
#     nfev: 31
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 9.5% 45
# 1110110000 6.4% 47
# 1111110000 6.3% 49
# 1111100000 6.3% 47
# 1011110000 3.0% 88
# 1110000000 2.3% 84
# 1100100000 2.2% 84
# 1111000000 2.1% 86
# 1100110000 2.1% 86
# 1101110000 1.9% 48
# 1010100000 1.9% 4
# 1111010000 1.9% 48
# 1110010000 1.9% 46
# 1101100000 1.8% 46
# 0110100000 1.2% 83
# 1011100000 0.9% 46
# 1010110000 0.9% 46
# 1101010000 0.8% 47
# 1101000000 0.8% 85
# 0100000000 0.8% 81
# depth == 2
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.3905
#        x: [ 1.482e+00  7.750e-01  1.595e+00  2.091e+00]
#     nfev: 54
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 3.9% 5
# 1111010000 3.1% 48
# 1101110000 3.1% 48
# 1111110000 2.6% 49
# 0101110000 2.1% 46
# 0111010000 2.1% 46
# 1101011000 1.8% 27
# 1101010010 1.7% 27
# 1101111000 1.5% 28
# 1111010010 1.5% 28
# 0111110000 1.5% 87
# 0001100000 1.3% 43
# 1101011010 1.3% 7
# 0010010000 1.2% 43
# 0110010000 1.2% 44
# 0101110001 1.2% 66
# 0111010100 1.2% 66
# 0101100000 1.1% 44
# 1111110100 1.0% 69
# 1111110001 1.0% 69
# depth == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 53.663
#        x: [ 2.073e+00  2.681e-01  1.960e-01  1.386e-01 -3.460e-01
#             7.784e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 30.6% 49
# 1111100001 3.8% 27
# 1110110100 3.8% 27
# 1111010010 3.5% 28
# 1101111000 3.4% 28
# 1011100000 2.9% 46
# 1010110000 2.9% 46
# 0111010000 2.6% 46
# 0101110000 2.6% 46
# 1110110000 1.9% 47
# 1111100000 1.7% 47
# 1011110000 1.7% 88
# 1111010000 1.1% 48
# 1101110000 1.1% 48
# 1111111000 0.9% 69
# 1111110100 0.9% 69
# 1111110010 0.9% 69
# 1111110001 0.9% 69
# 0111110000 0.8% 87
# 1110100000 0.7% 45
# depth == 4
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 69.3505
#        x: [ 1.790e+00  1.018e+00  6.689e-01  8.082e-01  7.614e-01
#             1.783e+00  1.784e+00  8.383e-01]
#     nfev: 94
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100101 4.4% 5
# 1010100000 3.7% 4
# 1000101000 1.7% 23
# 1111100101 1.6% 47
# 1010000010 1.6% 23
# 1110110101 1.5% 47
# 1110010111 1.3% 26
# 1101101101 1.3% 26
# 1001101001 1.1% 45
# 1010010110 1.1% 45
# 1101101001 1.0% 6
# 1110010110 0.9% 6
# 1000001010 0.9% 42
# 1011100000 0.8% 46
# 1110100000 0.8% 45
# 1010110000 0.8% 46
# 1010110001 0.8% 106
# 1011100100 0.8% 106
# 1010100100 0.7% 24
# 1010100001 0.7% 24
# depth == 5
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 58.7275
#        x: [ 1.946e+00  6.482e-01  7.085e-01  6.090e-01  5.626e-01
#             4.495e-01  5.975e-01  7.267e-02  5.403e-01  3.665e-01]
#     nfev: 122
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 12.0% 49
# 1101110000 4.2% 48
# 1111010000 4.2% 48
# 1010100101 3.6% 44
# 1111100000 2.9% 47
# 1110110000 2.9% 47
# 1110110100 2.1% 27
# 1111100001 2.1% 27
# 1110100000 2.1% 45
# 1011110000 1.5% 88
# 0101110000 1.2% 46
# 1110010000 1.2% 46
# 1110100101 1.2% 5
# 1101100000 1.2% 46
# 0111010000 1.2% 46
# 1101010000 1.1% 47
# 1010110000 1.0% 46
# 1110100100 1.0% 25
# 1011100000 1.0% 46
# 0101011010 1.0% 45
# depth == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 49.9465
#        x: [ 1.770e+00  7.799e-01  8.661e-01  1.805e+00  4.848e-01
#             7.702e-01  7.900e-01  1.759e+00  7.883e-01  7.898e-01
#             7.757e-01  8.011e-01]
#     nfev: 138
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 37.8% 40
# 0000100000 8.5% 41
# 0010000000 8.4% 41
# 0010100000 2.1% 42
# 1010100000 1.7% 4
# 0100000000 1.6% 81
# 0010001000 1.6% 101
# 0101000000 1.6% 43
# 0100010000 1.5% 43
# 0001000000 1.5% 42
# 0000110000 1.5% 83
# 0000100010 1.5% 101
# 0011000000 1.5% 83
# 0000010000 1.5% 42
# 1010000000 1.4% 43
# 1000100000 1.4% 43
# 1000000010 1.3% 62
# 1000001000 1.2% 62
# 0000000010 0.9% 60
# 0000001000 0.8% 60
# depth == 7
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 54.7685
#        x: [ 1.781e+00  5.535e-01 ...  7.870e-01  7.791e-01]
#     nfev: 182
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 42.8% 40
# 0000000100 5.8% 60
# 0000000001 5.8% 60
# 0000000010 5.3% 60
# 0000001000 5.3% 60
# 0000010000 3.2% 42
# 0001000000 3.1% 42
# 0100000000 1.5% 81
# 1000000000 1.4% 82
# 0010000000 1.3% 41
# 0000100000 1.3% 41
# 0010001000 0.8% 101
# 0000100010 0.8% 101
# 0000001001 0.7% 80
# 0000001100 0.7% 80
# 0000000011 0.7% 80
# 0000000110 0.7% 80
# 0000110000 0.7% 83
# 0011000000 0.6% 83
# 1000100000 0.5% 43
# depth == 8
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 58.466
#        x: [ 1.612e+00  5.567e-01 ...  7.805e-01  7.788e-01]
#     nfev: 177
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 13.7% 47
# 1101010010 3.6% 27
# 1101011000 3.5% 27
# 1110100000 3.3% 45
# 1101100000 2.2% 46
# 1110010000 2.1% 46
# 1010100000 1.6% 4
# 0100000000 1.5% 81
# 1101010001 1.4% 67
# 1101010100 1.3% 67
# 0101010000 1.2% 5
# 1001100000 1.2% 45
# 1100010100 1.2% 65
# 1101000001 1.2% 65
# 1010010000 1.2% 45
# 1101100001 1.2% 26
# 1110010100 1.1% 26
# 1101000000 0.8% 85
# 1100010000 0.8% 85
# 0101011000 0.7% 25
# depth == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.2665
#        x: [ 2.065e+00  7.597e-01 ...  7.822e-01  8.020e-01]
#     nfev: 183
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 8.4% 40
# 1010100000 5.6% 4
# 0000100000 3.1% 41
# 0010000000 3.0% 41
# 0010100000 2.0% 42
# 0111000000 1.9% 84
# 0110100000 1.9% 83
# 0100110000 1.8% 84
# 1110100000 1.8% 45
# 1111100000 1.7% 47
# 1110110000 1.7% 47
# 1010000000 1.7% 43
# 1000100000 1.6% 43
# 1111100100 1.6% 67
# 1110110001 1.5% 67
# 0111000100 1.2% 104
# 0100110001 1.2% 104
# 0000000100 1.1% 60
# 1100000000 1.1% 123
# 0000000001 1.1% 60
# depth == 10
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 36.52
#        x: [ 1.736e+00  7.703e-01 ...  7.668e-01  7.922e-01]
#     nfev: 268
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 30.7% 4
# 1110100000 4.9% 45
# 0000100000 4.1% 41
# 0010000000 4.0% 41
# 1001100000 2.6% 45
# 1010010000 2.5% 45
# 1000100000 2.0% 43
# 1010000000 1.9% 43
# 1010100100 1.8% 24
# 1010100001 1.7% 24
# 0000000000 1.6% 40
# 1111100000 1.5% 47
# 1110110000 1.5% 47
# 0010100000 1.3% 42
# 0110000000 1.1% 82
# 0100100000 1.0% 82
# 1010100010 0.9% 24
# 1010101000 0.9% 24
# 1110100001 0.9% 25
# 1110100100 0.9% 25
# depth == 11
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 55.6085
#        x: [ 1.778e+00  7.808e-01 ...  7.776e-01  7.875e-01]
#     nfev: 225
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 18.7% 40
# 0000100000 7.4% 41
# 0010000000 7.3% 41
# 0010100000 3.4% 42
# 0000001000 2.6% 60
# 0000000010 2.5% 60
# 0100000101 2.1% 41
# 0000010000 1.5% 42
# 0001000000 1.4% 42
# 0010000010 1.4% 61
# 1010100000 1.3% 4
# 0000101000 1.3% 61
# 1000001010 1.2% 42
# 0000110000 1.2% 83
# 0011000000 1.1% 83
# 1010000000 1.1% 43
# 1000100000 1.1% 43
# 0100000001 1.0% 61
# 0100000100 1.0% 61
# 0000000100 1.0% 60
# depth == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 52.227
#        x: [ 1.778e+00  7.715e-01 ...  7.747e-01  7.953e-01]
#     nfev: 292
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 36.9% 40
# 0000100000 6.4% 41
# 0010000000 6.3% 41
# 0000001000 6.0% 60
# 0000000010 5.9% 60
# 0100000001 2.8% 61
# 0100000100 2.8% 61
# 0000001010 1.3% 80
# 0100010000 1.1% 43
# 0101000000 1.1% 43
# 1010100000 0.9% 4
# 0010000010 0.9% 61
# 0000101000 0.9% 61
# 0010100000 0.8% 42
# 0000000101 0.8% 80
# 0000110000 0.7% 83
# 0000000001 0.7% 60
# 0000000100 0.7% 60
# 0011000000 0.7% 83
# 0100010001 0.7% 63
# depth == 13
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 51.8565
#        x: [ 1.764e+00  7.903e-01 ...  7.908e-01  7.875e-01]
#     nfev: 263
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 31.0% 40
# 0000100000 4.2% 41
# 0010000000 4.2% 41
# 0000000010 2.7% 60
# 0000001000 2.7% 60
# 1010000000 2.5% 43
# 1000100000 2.5% 43
# 1010100000 2.3% 4
# 1010001000 2.0% 63
# 1000100010 2.0% 63
# 1000001000 1.9% 62
# 1000000010 1.9% 62
# 0000010000 1.7% 42
# 1000101000 1.7% 23
# 0001000000 1.7% 42
# 1010000010 1.7% 23
# 0100000101 1.0% 41
# 1000001010 1.0% 42
# 0010100000 0.9% 42
# 1010101000 0.8% 24
# depth == 14
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 59.0715
#        x: [ 1.609e+00  5.674e-01 ...  7.881e-01  7.855e-01]
#     nfev: 237
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 6.5% 44
# 0010010000 4.6% 43
# 0001100000 4.5% 43
# 1010100000 3.7% 4
# 0010100000 3.6% 42
# 1010010000 2.1% 45
# 1001100000 2.0% 45
# 0100000000 1.8% 81
# 0000010000 1.7% 42
# 0001000000 1.7% 42
# 0000100000 1.6% 41
# 0010000000 1.6% 41
# 0110010000 1.4% 44
# 0000000000 1.4% 40
# 0101100000 1.3% 44
# 1010000000 1.3% 43
# 1000100000 1.3% 43
# 0101010000 1.2% 5
# 1110100000 0.9% 45
# 1100100000 0.8% 84
# depth == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 58.5725
#        x: [ 1.795e+00  7.217e-01 ...  7.814e-01  1.782e+00]
#     nfev: 292
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 4.4% 40
# 0010000000 3.5% 41
# 0100000101 3.5% 41
# 0000100000 3.4% 41
# 0010100000 2.3% 42
# 0000000010 2.3% 60
# 0000001000 2.2% 60
# 0110000101 2.1% 42
# 0100100101 2.1% 42
# 0100001101 1.8% 61
# 0100000111 1.8% 61
# 0001000000 1.6% 42
# 0000010000 1.6% 42
# 0010010000 1.3% 43
# 0001100000 1.3% 43
# 0010000010 1.3% 61
# 0000101000 1.3% 61
# 0110100101 1.0% 43
# 1010100000 1.0% 4
# 0000001010 1.0% 80
# depth == 16
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 45.479
#        x: [ 1.484e+00  9.388e-01 ...  7.842e-01  7.944e-01]
#     nfev: 347
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 20.5% 5
# 1101010000 4.6% 47
# 1101110000 3.2% 48
# 1111010000 3.2% 48
# 1101010010 2.6% 27
# 1101011000 2.6% 27
# 0111010000 2.1% 46
# 0101110000 2.1% 46
# 0100010000 1.9% 43
# 0101000000 1.9% 43
# 1111110000 1.7% 49
# 1101111000 1.6% 28
# 1111010010 1.6% 28
# 0101000001 1.5% 23
# 0100010100 1.5% 23
# 0000000000 1.4% 40
# 1101011010 1.2% 7
# 0001000000 1.1% 42
# 0000010000 1.0% 42
# 0110010000 0.9% 44
# depth == 17
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 44.8155
#        x: [ 1.728e+00  7.886e-01 ...  7.625e-01  7.805e-01]
#     nfev: 413
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 25.1% 4
# 1010000000 5.2% 43
# 1000100000 5.2% 43
# 1110100000 5.1% 45
# 1010101010 3.7% 44
# 1001100000 2.7% 45
# 1010010000 2.6% 45
# 1110010000 1.8% 46
# 1101100000 1.7% 46
# 1010101000 1.7% 24
# 1010100010 1.6% 24
# 0110100000 1.4% 83
# 0000000000 1.1% 40
# 0110000000 0.9% 82
# 0100100000 0.9% 82
# 1100100000 0.9% 84
# 1110000000 0.9% 84
# 0110010000 0.8% 44
# 0101010000 0.8% 5
# 0101100000 0.8% 44
# depth == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 56.782
#        x: [ 1.786e+00  7.863e-01 ...  7.888e-01  7.876e-01]
#     nfev: 362
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 4.6% 4
# 1110100000 4.0% 45
# 0001010000 2.7% 44
# 1111100000 2.4% 47
# 1110110000 2.4% 47
# 1001101000 2.1% 25
# 1010010010 2.1% 25
# 1110000010 1.8% 64
# 1100101000 1.8% 64
# 1001011010 1.3% 46
# 1010100100 1.2% 24
# 1010100001 1.2% 24
# 0101100000 1.2% 44
# 1010101000 1.2% 24
# 1010100010 1.2% 24
# 0110010000 1.1% 44
# 0010010000 1.1% 43
# 0001100000 1.0% 43
# 0110100000 1.0% 83
# 1110010010 0.8% 26
# depth == 19
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 41.775
#        x: [ 1.745e+00  8.321e-01 ...  7.693e-01  7.757e-01]
#     nfev: 424
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 31.9% 4
# 1110100000 11.5% 45
# 1010000010 3.0% 23
# 1000101000 3.0% 23
# 1000000000 2.6% 82
# 1001100000 2.5% 45
# 1010010000 2.5% 45
# 1010000000 1.9% 43
# 1000100000 1.8% 43
# 1110000010 1.6% 64
# 1100101000 1.6% 64
# 1100000000 1.4% 123
# 0000000000 1.0% 40
# 0100000000 1.0% 81
# 1100100000 0.6% 84
# 1000011000 0.6% 64
# 1110000000 0.6% 84
# 1001000010 0.6% 64
# 0010101010 0.6% 162
# 0010101000 0.6% 102
