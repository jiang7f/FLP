# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits))
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(3, 100, 3):
  print(f'penalty == {i}')
  test(i, 3, np.ones(2 * 3))
# Out:
# penalty == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 9.9325
#        x: [ 2.012e+00  1.233e+00  8.697e-01  9.308e-01  9.877e-01
#             9.677e-01]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 32.3% 6
# 0001000000 5.6% 8
# 0000010000 5.5% 8
# 1000000000 5.1% 14
# 0101010000 2.2% 5
# 0100010000 1.8% 9
# 0101000000 1.7% 9
# 0000100010 1.5% 16
# 0010001000 1.5% 16
# 0100000001 1.5% 10
# 0100000100 1.4% 10
# 0010000000 1.3% 7
# 0000100000 1.2% 7
# 0000000010 1.2% 9
# 0000001000 1.1% 9
# 0000000100 0.9% 9
# 0000000001 0.8% 9
# 0001010000 0.7% 10
# 0100010100 0.6% 6
# 0101000001 0.6% 6
# penalty == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 23.765
#        x: [ 2.172e+00  4.412e-01  3.630e-01  4.569e-01  9.921e-01
#             1.620e+00]
#     nfev: 80
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 4.1% 21
# 1101010000 3.5% 19
# 1111010000 3.4% 20
# 0111110000 3.4% 31
# 1101110000 3.3% 20
# 1110110000 3.2% 19
# 1111100000 3.2% 19
# 1110100000 3.2% 17
# 1110010000 3.0% 18
# 1101100000 2.9% 18
# 0111100000 2.4% 29
# 0110110000 2.4% 29
# 0110100000 2.0% 27
# 0101110000 1.6% 18
# 0111010000 1.5% 18
# 1011110000 1.5% 32
# 1110000000 1.2% 28
# 0011110000 1.2% 42
# 1100100000 1.2% 28
# 1101000000 1.1% 29
# penalty == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 29.4955
#        x: [ 1.999e+00  9.664e-01  9.971e-01  1.018e+00  1.029e+00
#             9.944e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 18.2% 18
# 0001000000 5.4% 20
# 0000010000 5.2% 20
# 0100000000 5.0% 37
# 1000000000 4.9% 38
# 0101010000 2.3% 5
# 0101000000 2.2% 21
# 0001010000 2.2% 22
# 0100010000 2.2% 21
# 0000100000 1.4% 19
# 1000010000 1.4% 40
# 0110000000 1.4% 38
# 0010000000 1.3% 19
# 1001000000 1.3% 40
# 0100100000 1.3% 38
# 1100000000 1.0% 57
# 0100000100 1.0% 28
# 1010001000 0.9% 30
# 1000100010 0.9% 30
# 0100000001 0.9% 28
# penalty == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 37.773
#        x: [ 2.709e+00  2.071e+00  2.403e+00  5.832e-01  1.778e-01
#             1.979e+00]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 7.3% 33
# 1110110000 7.0% 31
# 1111100000 7.0% 31
# 1011110000 4.9% 56
# 1110100000 3.0% 29
# 1111100001 2.7% 19
# 1110110100 2.7% 19
# 1010100000 1.6% 4
# 1110100100 1.5% 17
# 1101111000 1.4% 20
# 1110100001 1.4% 17
# 1111010010 1.4% 20
# 0101010000 1.2% 5
# 1110100101 1.0% 5
# 1110010010 1.0% 18
# 1101101000 1.0% 18
# 1101011010 0.9% 7
# 1111000001 0.9% 42
# 1100110100 0.9% 42
# 0110100000 0.9% 51
# penalty == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 49.0385
#        x: [ 2.015e+00  1.019e+00  8.838e-01  8.432e-01  1.054e+00
#             1.064e+00]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 17.9% 30
# 0000000100 5.9% 45
# 0000000001 5.7% 45
# 0000000010 5.6% 45
# 0000001000 5.4% 45
# 1000000000 3.9% 62
# 0010000000 2.7% 31
# 0000100000 2.6% 31
# 0000001010 2.2% 60
# 1000000010 1.9% 47
# 0000000101 1.9% 60
# 1000001000 1.9% 47
# 0000000011 1.9% 60
# 0000001001 1.8% 60
# 0000001100 1.8% 60
# 0000000110 1.7% 60
# 1000000001 1.3% 77
# 1000000100 1.3% 77
# 0100000000 1.1% 61
# 1000001010 1.1% 32
# penalty == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.8625
#        x: [ 8.820e-01  1.224e+00  9.079e-01  5.567e-01  9.931e-01
#             4.183e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100101101 1.8% 56
# 0110000111 1.8% 56
# 0110000110 1.4% 74
# 0100101001 1.4% 74
# 0100001111 1.3% 73
# 1110100000 1.3% 41
# 1011110000 1.2% 80
# 0100101100 1.1% 74
# 1110100101 1.1% 5
# 0110000011 1.0% 74
# 0100101000 1.0% 92
# 0110000010 0.9% 92
# 1110100001 0.9% 23
# 1110100100 0.8% 23
# 0100001011 0.8% 91
# 0100001110 0.8% 91
# 1010100001 0.7% 22
# 0110100101 0.7% 39
# 1010100100 0.7% 22
# 0000001010 0.7% 72
# penalty == 21
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 84.7305
#        x: [ 1.125e+00  1.005e+00  1.002e+00  1.998e+00  1.006e+00
#             1.995e+00]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110010111 1.5% 27
# 1101101101 1.4% 27
# 1111010010 1.0% 29
# 1101111000 1.0% 29
# 1110010110 0.9% 6
# 1101101001 0.9% 6
# 1110100000 0.9% 47
# 1101011111 0.9% 49
# 0100000000 0.8% 85
# 1100001010 0.8% 87
# 1001011111 0.7% 174
# 0110100000 0.6% 87
# 1011101000 0.6% 69
# 0011110101 0.6% 258
# 1010110010 0.6% 69
# 1111010000 0.5% 50
# 1100001111 0.5% 45
# 0001001000 0.5% 65
# 1111010111 0.5% 71
# 1101110000 0.5% 50
# penalty == 24
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 100.6755
#        x: [ 1.025e+00  8.582e-01  1.732e+00  1.160e-01  2.588e-01
#             7.183e-01]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000100 1.1% 73
# 0100000001 1.1% 73
# 0100000000 0.9% 97
# 1100000011 0.8% 99
# 1100001100 0.8% 99
# 0100000011 0.8% 97
# 0100000101 0.8% 49
# 0100001001 0.8% 97
# 0100000110 0.7% 97
# 0100001100 0.7% 97
# 0000000000 0.7% 48
# 1100000001 0.7% 123
# 1100000100 0.6% 123
# 0100001101 0.6% 73
# 0100000111 0.6% 73
# 0000000101 0.5% 96
# 1100000111 0.5% 75
# 1100000101 0.5% 99
# 1100001101 0.5% 75
# 0110000100 0.5% 74
# penalty == 27
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 83.922
#        x: [ 1.782e+00  2.145e+00  1.053e+00  1.862e+00  1.636e+00
#             2.112e+00]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 5.1% 109
# 0000000000 4.3% 54
# 0100100000 4.1% 110
# 0110000000 4.0% 110
# 0010000000 3.2% 55
# 0000100000 3.1% 55
# 0110100000 3.0% 111
# 0001000000 2.8% 56
# 0101000000 2.7% 57
# 0000010000 2.7% 56
# 0100010000 2.6% 57
# 0101010000 2.5% 5
# 0101100000 2.4% 58
# 0110010000 2.4% 58
# 0001010000 2.1% 58
# 0010100000 2.0% 56
# 0010010000 2.0% 57
# 0001100000 2.0% 57
# 0111010000 0.8% 60
# 0000110000 0.8% 111
# penalty == 30
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 106.0035
#        x: [ 2.167e+00  1.947e+00  9.511e-01  2.204e+00  2.011e+00
#             9.735e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0110100000 9.2% 123
# 0110010000 4.1% 64
# 0101100000 4.0% 64
# 0101010000 3.3% 5
# 0100100000 1.8% 122
# 0110000000 1.7% 122
# 0010100000 1.6% 62
# 0111100000 1.5% 125
# 1110100000 1.5% 65
# 0110110000 1.4% 125
# 0010100100 1.3% 92
# 0010100001 1.2% 92
# 0010010001 1.2% 153
# 0001100100 1.2% 153
# 0110100100 1.1% 93
# 0100000000 1.0% 121
# 0110100001 1.0% 93
# 1100000000 0.8% 183
# 0110010001 0.8% 94
# 0101100100 0.8% 94
# penalty == 33
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 123.524
#        x: [ 8.433e-01  6.971e-01  2.157e+00 -1.078e-02  7.882e-01
#             6.088e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 3.0% 66
# 0010000000 2.4% 67
# 0000100000 2.2% 67
# 1000000010 1.5% 101
# 0010100000 1.4% 68
# 0001000000 1.4% 68
# 1000001000 1.4% 101
# 0000010000 1.4% 68
# 0000000001 1.2% 99
# 0100000000 1.2% 133
# 0000000100 1.2% 99
# 1000001010 1.0% 68
# 0001100000 0.9% 69
# 0010010000 0.9% 69
# 0000000010 0.9% 99
# 0000001000 0.9% 99
# 0010000001 0.8% 100
# 0000100100 0.8% 100
# 0110000000 0.8% 134
# 0100100000 0.8% 134
# penalty == 36
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 141.0835
#        x: [ 2.213e+00  1.005e+00  1.123e+00  1.997e+00  1.003e+00
#             9.999e-01]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 1.9% 72
# 0100000101 1.8% 73
# 1000001010 1.7% 74
# 1100001111 1.5% 75
# 0000000101 1.5% 144
# 1000000000 1.3% 146
# 0100100100 0.9% 110
# 0110000001 0.8% 110
# 1100000101 0.8% 147
# 1000001111 0.8% 146
# 0100000001 0.7% 109
# 0100000100 0.7% 109
# 0100010100 0.7% 39
# 0101000001 0.7% 39
# 1100001110 0.6% 111
# 1100001011 0.6% 111
# 0010000010 0.6% 109
# 1000000101 0.6% 218
# 0000101000 0.6% 109
# 0100100101 0.6% 74
# penalty == 39
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 167.772
#        x: [ 1.925e+00  1.788e+00  1.022e+00  1.948e+00  7.561e-01
#             1.241e+00]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1000001010 1.0% 80
# 0000000000 0.8% 78
# 1111110000 0.7% 87
# 1000001111 0.6% 158
# 0101010000 0.6% 5
# 1010100000 0.6% 4
# 1010100101 0.6% 82
# 0000000101 0.5% 156
# 1111000011 0.5% 84
# 1100111100 0.5% 84
# 0101011010 0.5% 83
# 1101011010 0.5% 7
# 0101101001 0.5% 82
# 0011010010 0.4% 200
# 0110010110 0.4% 82
# 1010100001 0.4% 43
# 1100001111 0.4% 81
# 1011000010 0.4% 122
# 1000111000 0.4% 122
# 1100001011 0.4% 120
# penalty == 42
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 154.71
#        x: [ 8.688e-01  2.079e+00  8.859e-01  8.244e-01  1.458e+00
#             1.836e+00]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 1.9% 89
# 1101101000 1.8% 48
# 1110010010 1.8% 48
# 1101011010 1.6% 7
# 0111110000 1.4% 175
# 1101011000 1.3% 49
# 1101010010 1.2% 49
# 0110010000 1.1% 88
# 0101100000 1.1% 88
# 0110100000 0.9% 171
# 1010010010 0.9% 47
# 1001101000 0.8% 47
# 1111110000 0.8% 93
# 0101011010 0.7% 89
# 1110101000 0.7% 131
# 0011100000 0.7% 172
# 1110100010 0.7% 131
# 1011110100 0.6% 302
# 1011110001 0.6% 302
# 0010110000 0.6% 172
# penalty == 45
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 170.1555
#        x: [ 1.674e+00  1.608e+00  9.571e-01  2.016e+00  9.925e-01
#             1.046e+00]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 4.1% 181
# 0000000000 2.7% 90
# 0100100000 2.6% 182
# 0110000000 2.5% 182
# 0010000000 1.6% 91
# 0000100000 1.6% 91
# 1110100000 1.6% 95
# 0100001000 1.4% 226
# 0100000010 1.3% 226
# 0100101000 1.2% 227
# 0110000010 1.2% 227
# 0000000010 0.9% 135
# 0000001000 0.9% 135
# 0110000100 0.8% 137
# 0100100001 0.8% 137
# 1110101000 0.7% 140
# 0000000100 0.7% 135
# 0111000000 0.7% 184
# 0000101000 0.7% 136
# 1100000010 0.7% 228
# penalty == 48
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 143.318
#        x: [ 2.382e+00  2.463e+00  9.798e-01  2.614e+00  5.058e-01
#             8.671e-01]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 4.7% 5
# 0100010000 3.0% 99
# 0110010000 2.8% 100
# 0101000000 2.8% 99
# 0101100000 2.8% 100
# 0001010000 2.8% 100
# 0101000001 2.6% 51
# 0100010100 2.6% 51
# 0100000001 1.4% 145
# 0100000100 1.4% 145
# 0100000101 1.4% 97
# 0100000000 1.3% 193
# 0110000001 1.3% 146
# 0100100100 1.3% 146
# 0110000000 1.3% 194
# 0100100000 1.3% 194
# 0110100000 1.2% 195
# 0111010000 1.1% 102
# 0000010000 1.1% 98
# 0110010100 1.0% 52
# penalty == 51
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 166.567
#        x: [ 2.350e+00  6.014e-01  2.188e+00  4.781e-01  7.468e-01
#             4.134e-01]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0110100101 1.8% 105
# 0110100100 1.7% 156
# 0110100001 1.6% 156
# 0110000001 1.2% 155
# 0100100100 1.2% 155
# 1100000110 1.1% 207
# 1100001001 1.1% 207
# 1001011010 1.0% 108
# 1110000011 1.0% 106
# 0110000101 1.0% 104
# 1100101100 1.0% 106
# 1100101101 1.0% 55
# 0100100101 1.0% 104
# 1110000111 0.9% 55
# 1100101001 0.9% 106
# 0011110000 0.9% 312
# 1100001110 0.9% 156
# 1110000110 0.9% 106
# 1100001011 0.8% 156
# 1100000111 0.8% 156
# penalty == 54
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 195.3985
#        x: [ 1.999e+00  1.999e+00  2.000e+00  9.987e-01  2.004e+00
#             1.001e+00]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 2.2% 5
# 0101010100 1.8% 59
# 0101010001 1.8% 59
# 1111011011 0.9% 170
# 1101111110 0.9% 170
# 1101011010 0.8% 7
# 1111011010 0.8% 116
# 1101111010 0.8% 116
# 1101111000 0.7% 62
# 0001000000 0.7% 110
# 1111010010 0.7% 62
# 1101111100 0.7% 116
# 1111010011 0.6% 116
# 0000010000 0.6% 110
# 1101111001 0.6% 116
# 0100101101 0.6% 164
# 1111011110 0.6% 170
# 1000001010 0.6% 110
# 1001011010 0.6% 114
# 1111010110 0.6% 116
# penalty == 57
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 165.867
#        x: [ 2.070e+00  9.020e-01  7.221e-01  8.177e-01  9.856e-01
#             2.002e+00]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 9.6% 4
# 1110100000 8.6% 119
# 1010100001 4.8% 61
# 1010100100 4.8% 61
# 1010100101 3.9% 118
# 1001100000 1.8% 119
# 1010010000 1.8% 119
# 1001100001 1.4% 176
# 1010010100 1.3% 176
# 1011100000 1.3% 120
# 1010110000 1.2% 120
# 1110000010 1.1% 175
# 1100101000 1.1% 175
# 1111100000 1.0% 121
# 1001101000 1.0% 62
# 1110000000 0.9% 232
# 1110110000 0.9% 121
# 1100100000 0.9% 232
# 1010010010 0.9% 62
# 1010110100 0.8% 177
# penalty == 60
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 174.9535
#        x: [ 2.082e+00  9.424e-01  1.962e+00  9.961e-01  9.843e-01
#             2.104e+00]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 9.6% 127
# 0101010000 3.7% 5
# 1101010010 2.8% 67
# 1101011000 2.8% 67
# 1101110000 2.6% 128
# 1111010000 2.5% 128
# 1101100000 1.9% 126
# 1101110010 1.9% 188
# 1111011000 1.9% 188
# 1001010000 1.9% 246
# 1110010000 1.9% 126
# 1101010001 1.7% 187
# 1101010100 1.7% 187
# 1111110000 1.5% 129
# 1101011010 1.4% 7
# 0111110000 0.9% 247
# 1001000000 0.8% 244
# 1001010100 0.8% 426
# 0111010000 0.7% 126
# 1001010001 0.7% 426
# penalty == 63
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 173.0555
#        x: [ 1.007e+00  1.091e+00  1.059e+00  1.039e+00  2.002e+00
#             1.050e+00]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 10.4% 131
# 1010100000 9.4% 4
# 0000000000 4.2% 126
# 0100000000 4.0% 253
# 1111100000 2.8% 133
# 1110110000 2.7% 133
# 1000100000 1.9% 129
# 1010000000 1.8% 129
# 0110100000 1.8% 255
# 0010100000 1.7% 128
# 1100100000 1.5% 256
# 1110000000 1.5% 256
# 1101100000 1.4% 132
# 1110010000 1.3% 132
# 0110000000 1.2% 254
# 0100100000 1.2% 254
# 1111110000 1.0% 135
# 1111100100 1.0% 196
# 1010100001 0.9% 67
# 1110110001 0.9% 196
# penalty == 66
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 250.0075
#        x: [ 1.647e+00  7.668e-01  1.119e+00  2.099e+00  1.288e+00
#             6.932e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 2.3% 139
# 1111110000 1.7% 141
# 1111010000 1.7% 140
# 1101110000 1.7% 140
# 0101011010 1.5% 137
# 0101110000 1.4% 138
# 0111010000 1.3% 138
# 1111000001 1.2% 204
# 1100110100 1.2% 204
# 0111110000 1.1% 271
# 1111100000 1.1% 139
# 0111010010 1.1% 204
# 0101111000 1.1% 204
# 1110110000 1.1% 139
# 1111110010 1.0% 207
# 1111111000 1.0% 207
# 1110010000 0.9% 138
# 1101100000 0.9% 138
# 1100010100 0.9% 203
# 1101000001 0.8% 203
# penalty == 69
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 193.392
#        x: [ 2.282e+00  1.677e-01  7.458e-01  4.943e-01 -1.421e-01
#             7.536e-01]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 5.6% 147
# 1011110000 3.0% 284
# 1110100101 2.7% 5
# 1110100001 2.4% 74
# 1110100100 2.3% 74
# 1111100001 2.2% 76
# 1110110100 2.2% 76
# 1111010000 2.1% 146
# 1101110000 2.1% 146
# 1110110000 1.8% 145
# 1010110000 1.8% 144
# 1110100000 1.7% 143
# 1011100000 1.7% 144
# 1111100000 1.7% 145
# 1101010000 1.7% 145
# 1111010010 1.6% 77
# 1101111000 1.6% 77
# 1101100001 1.5% 75
# 1110010100 1.5% 75
# 1110010110 1.2% 6
# penalty == 72
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 195.28
#        x: [ 1.866e+00  9.991e-01  9.589e-01  9.987e-01  1.001e+00
#             9.994e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 28.6% 144
# 0000010000 7.3% 146
# 0001000000 7.1% 146
# 1000000000 2.8% 290
# 0101010000 2.7% 5
# 0100000000 2.5% 289
# 0101000000 2.3% 147
# 0100010000 2.3% 147
# 0001010000 1.7% 148
# 0100000001 1.6% 217
# 0100000100 1.5% 217
# 0010001000 1.4% 361
# 0000100010 1.4% 361
# 1000000010 0.9% 218
# 1000001000 0.9% 218
# 0010000000 0.8% 145
# 0000100000 0.8% 145
# 0111000000 0.7% 292
# 0100110000 0.7% 292
# 1000100010 0.7% 219
# penalty == 75
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 231.474
#        x: [ 9.990e-01  1.994e+00  9.986e-01  1.001e+00  1.997e+00
#             1.007e+00]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 3.4% 4
# 0010010000 2.4% 153
# 0001100000 2.3% 153
# 0001010000 1.9% 154
# 0010000000 1.3% 151
# 0000100000 1.3% 151
# 1011100000 1.2% 156
# 0000000000 1.2% 150
# 1010110000 1.2% 156
# 0110010000 1.0% 154
# 0101100000 1.0% 154
# 1110100100 0.9% 80
# 0010100000 0.9% 152
# 0101010000 0.9% 5
# 0000010000 0.9% 152
# 1110100001 0.8% 80
# 0011100000 0.8% 304
# 0001000000 0.8% 152
# 0010110000 0.8% 304
# 1000011000 0.8% 229
# penalty == 78
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 273.599
#        x: [ 2.000e+00  1.007e+00  9.965e-01  1.002e+00  2.125e+00
#             1.006e+00]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 10.1% 156
# 0100000000 4.4% 313
# 0001000000 4.3% 158
# 0000010000 4.2% 158
# 0001010000 3.3% 160
# 1000000000 2.0% 314
# 0100000001 1.7% 235
# 1001010000 1.7% 318
# 0100000100 1.7% 235
# 1000010000 1.6% 316
# 1001000000 1.6% 316
# 0010000000 1.2% 157
# 0000100000 1.1% 157
# 1100000000 1.1% 471
# 1000110000 1.1% 317
# 1011000000 1.0% 317
# 0101000001 1.0% 81
# 0100010100 1.0% 81
# 0101000000 0.8% 159
# 0100010000 0.7% 159
# penalty == 81
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 204.706
#        x: [ 1.864e+00  2.213e+00  2.061e+00  1.242e+00  1.005e+00
#             2.020e+00]
#     nfev: 76
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 28.0% 162
# 0001000000 13.7% 164
# 0000010000 13.6% 164
# 0001010000 6.8% 166
# 1000000000 2.3% 326
# 0000100000 2.0% 163
# 0010000000 2.0% 163
# 0000010001 1.3% 407
# 0100010000 1.3% 165
# 0001000100 1.3% 407
# 0101000000 1.3% 165
# 1000010000 1.2% 328
# 0000000010 1.2% 243
# 1001000000 1.2% 328
# 0000001000 1.1% 243
# 0010010000 1.0% 165
# 0001100000 1.0% 165
# 0100000000 1.0% 325
# 1010000000 0.9% 165
# 1000100000 0.9% 165
# penalty == 84
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 332.9835
#        x: [ 9.275e-01  7.580e-01  6.956e-01  1.992e+00  1.084e+00
#             1.072e+00]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100101 4.2% 172
# 1110100000 2.1% 173
# 0010100101 1.8% 338
# 1110100101 1.6% 5
# 1010010111 0.8% 425
# 0111110100 0.8% 427
# 1001101101 0.8% 425
# 0111110001 0.7% 427
# 0011100001 0.7% 424
# 0010110100 0.7% 424
# 1111100101 0.7% 175
# 1110110101 0.6% 175
# 1100101000 0.6% 256
# 1010100000 0.6% 4
# 1010110000 0.6% 174
# 1111100100 0.6% 259
# 1011100000 0.6% 174
# 1010000111 0.6% 255
# 1010100001 0.6% 88
# 1010100100 0.6% 88
# penalty == 87
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 293.04
#        x: [ 1.030e+00  1.976e+00  1.019e+00  1.013e+00  9.688e-01
#             1.019e+00]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101011010 3.4% 179
# 0101011000 2.9% 92
# 0101010010 2.9% 92
# 0101010000 2.1% 5
# 1101011010 1.4% 7
# 0101001000 1.1% 264
# 0100010010 1.1% 264
# 0100011010 1.1% 351
# 0101001010 1.0% 351
# 0100010110 1.0% 177
# 0100011110 1.0% 264
# 0101000011 1.0% 177
# 0100011100 1.0% 177
# 0101001011 1.0% 264
# 0101001001 1.0% 177
# 0100011000 1.0% 264
# 0101000010 0.9% 264
# 0101000000 0.9% 177
# 0100010000 0.9% 177
# 0101011110 0.8% 266
# penalty == 90
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 265.3415
#        x: [ 1.483e+00  2.063e+00  1.998e+00  7.979e-01  8.520e-01
#             1.015e+00]
#     nfev: 75
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 9.5% 185
# 1110010000 4.8% 186
# 1101100000 4.7% 186
# 1010100000 3.9% 4
# 1111100000 2.6% 187
# 1110110000 2.5% 187
# 1101010000 2.5% 187
# 1110100010 1.5% 275
# 1110101000 1.5% 275
# 1101110000 1.5% 188
# 0110100000 1.4% 363
# 1111010000 1.4% 188
# 1010100101 1.1% 184
# 1110100100 1.1% 95
# 1110100001 1.0% 95
# 0100000000 1.0% 361
# 1100100000 0.9% 364
# 0101010000 0.9% 5
# 1110000000 0.9% 364
# 1010010001 0.9% 455
# penalty == 93
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 362.2235
#        x: [ 2.041e+00  1.020e+00  1.986e+00  1.967e+00  2.093e+00
#             9.394e-01]
#     nfev: 61
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1001010000 1.7% 378
# 1000000000 1.7% 374
# 1000010000 1.3% 376
# 1001000000 1.3% 376
# 1100000000 1.3% 561
# 1101110001 1.1% 287
# 1111010100 1.1% 287
# 1001010010 1.1% 285
# 1001011000 1.0% 285
# 0000001010 0.9% 372
# 1101010000 0.9% 193
# 1001110000 0.9% 379
# 1011010000 0.9% 379
# 1011110000 0.9% 380
# 0001011010 0.9% 376
# 1101000000 0.9% 377
# 1100010000 0.9% 377
# 1100110001 0.8% 471
# 1111000100 0.8% 471
# 1010100000 0.7% 4
# penalty == 96
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 263.731
#        x: [ 2.291e+00  2.069e+00  9.743e-01  1.566e+00  9.171e-01
#             2.184e+00]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 5.6% 196
# 0000010000 3.1% 194
# 0001000000 3.0% 194
# 0101010000 3.0% 5
# 0000000000 2.7% 192
# 1001100000 2.1% 197
# 1010010000 2.1% 197
# 0011010000 1.7% 389
# 0001110000 1.7% 389
# 0011000000 1.6% 387
# 0100000000 1.6% 385
# 0000110000 1.5% 387
# 0111010000 1.4% 198
# 0101110000 1.4% 198
# 0100010000 1.3% 195
# 0101000000 1.3% 195
# 0010000000 1.3% 193
# 1011100000 1.3% 198
# 1010110000 1.2% 198
# 0000100000 1.2% 193
# penalty == 99
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 290.495
#        x: [ 9.078e-01  8.687e-01  8.671e-01  1.043e+00  2.121e+00
#             8.470e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100101 3.1% 5
# 0100000101 2.6% 199
# 1100100101 1.7% 202
# 1110000101 1.7% 202
# 1110100100 1.5% 104
# 0000000000 1.5% 198
# 1110100001 1.5% 104
# 1100101101 1.1% 103
# 1010000000 1.1% 201
# 1110000111 1.1% 103
# 1000100000 1.0% 201
# 1111100001 0.9% 106
# 1110110100 0.9% 106
# 0101010000 0.8% 5
# 0101000001 0.8% 102
# 0100010100 0.7% 102
# 0100101101 0.7% 299
# 0101000101 0.7% 201
# 0110000111 0.7% 299
# 1110100000 0.7% 203
