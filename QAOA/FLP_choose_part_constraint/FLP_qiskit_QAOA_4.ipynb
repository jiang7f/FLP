# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j - 1] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits)) # transpile
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(1, 20):
  print(f'depth == {i}')
  test(20, i, np.full(i * 2, np.pi/4))
# Out:
# depth == 1
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 63.8365
#        x: [ 1.554e+00  7.660e-01]
#     nfev: 28
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 10.6% 45
# 1110110000 5.8% 47
# 1111100000 5.8% 47
# 1111110000 4.0% 49
# 1110000000 3.6% 84
# 1100100000 3.4% 84
# 1111000000 2.2% 86
# 1100110000 2.2% 86
# 1010100000 2.0% 4
# 1101100000 2.0% 46
# 1110010000 1.9% 46
# 1100000000 1.5% 123
# 1111010000 1.5% 48
# 1101110000 1.4% 48
# 1010100100 1.1% 24
# 1011110000 1.1% 88
# 1010000000 1.1% 43
# 1010100001 1.0% 24
# 1000100000 1.0% 43
# 0110100000 1.0% 83
# depth == 2
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 71.761
#        x: [ 9.062e-01  7.436e-01  7.771e-01  1.781e+00]
#     nfev: 46
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010101010 4.5% 44
# 0000000000 4.4% 40
# 1000000000 2.8% 82
# 0000100010 2.6% 101
# 0010001000 2.5% 101
# 1010100010 2.4% 24
# 1010101000 2.3% 24
# 1001000000 1.6% 84
# 1010100000 1.6% 4
# 1000010000 1.5% 84
# 1000100000 1.4% 43
# 0001000000 1.4% 42
# 1010000000 1.4% 43
# 0000010000 1.4% 42
# 0010011000 1.2% 103
# 0001100010 1.1% 103
# 0010000000 1.1% 41
# 1001100000 1.0% 45
# 0000100000 1.0% 41
# 1010010000 1.0% 45
# depth == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 52.358
#        x: [ 7.634e-01  7.959e-01  7.564e-01  7.723e-01  8.089e-01
#             7.714e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 14.1% 5
# 1101010000 6.0% 47
# 0001010000 5.4% 44
# 0101000000 3.8% 43
# 0100010000 3.8% 43
# 0101011000 2.3% 25
# 0101010010 2.3% 25
# 0101100000 2.2% 44
# 0110010000 2.2% 44
# 1001010000 2.2% 86
# 0000010000 1.6% 42
# 0001000000 1.6% 42
# 1101010010 1.3% 27
# 0100000000 1.3% 81
# 1101011000 1.3% 27
# 0000000000 1.3% 40
# 1101110000 1.2% 48
# 1111010000 1.1% 48
# 1100010000 1.1% 85
# 1101000000 1.1% 85
# depth == 4
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 59.5495
#        x: [ 1.791e+00  7.910e-01  7.886e-01  7.951e-01  7.823e-01
#             1.789e+00  7.905e-01  7.842e-01]
#     nfev: 91
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0010100000 10.3% 42
# 1000101000 5.0% 23
# 1010000010 5.0% 23
# 1010000000 3.2% 43
# 1000100000 3.2% 43
# 0000001010 3.1% 80
# 0010000000 3.0% 41
# 0000100000 3.0% 41
# 1000001010 2.8% 42
# 0010100010 2.0% 102
# 1000000000 2.0% 82
# 0010101000 1.9% 102
# 1010100000 1.6% 4
# 0000000000 1.4% 40
# 1010100010 1.3% 24
# 1010101000 1.3% 24
# 0010001000 1.2% 101
# 0000100010 1.2% 101
# 0010100100 1.1% 62
# 0010100001 1.1% 62
# depth == 5
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 24.19
#        x: [ 5.096e-01  7.685e-01  7.909e-01  1.822e+00  7.875e-01
#             7.758e-01  7.962e-01  7.905e-01  7.914e-01  7.752e-01]
#     nfev: 133
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 49.1% 4
# 1010100001 6.5% 24
# 1010100100 6.4% 24
# 0010100000 5.4% 42
# 1010100010 3.3% 24
# 1010101000 3.3% 24
# 1110100100 2.6% 25
# 1110100001 2.5% 25
# 1110100000 2.1% 45
# 1010110001 1.6% 106
# 1011100100 1.6% 106
# 1010100101 0.8% 44
# 0010100100 0.7% 62
# 0010100001 0.7% 62
# 1110100101 0.6% 5
# 1010000000 0.6% 43
# 1000100000 0.6% 43
# 1010100011 0.5% 44
# 1010100110 0.4% 44
# 1010101100 0.4% 44
# depth == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 40.6885
#        x: [ 1.526e+00  1.902e+00  7.931e-01  7.828e-01  7.842e-01
#             7.875e-01  7.886e-01  1.785e+00  7.829e-01  7.951e-01
#             7.831e-01  7.743e-01]
#     nfev: 147
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 36.3% 5
# 0101110000 5.4% 46
# 0111010000 5.3% 46
# 0101000000 5.0% 43
# 0100010000 5.0% 43
# 0101010100 3.0% 25
# 0101010001 2.9% 25
# 0111011000 2.2% 106
# 0101110010 2.1% 106
# 0001010000 2.0% 44
# 0110010000 1.6% 44
# 0101100000 1.6% 44
# 1101010000 1.5% 47
# 1101011000 1.0% 27
# 1101010010 0.9% 27
# 1101011010 0.8% 7
# 0111000000 0.8% 84
# 0100110000 0.7% 84
# 0111110000 0.7% 87
# 0000000000 0.7% 40
# depth == 7
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.851
#        x: [ 1.798e+00  7.575e-01 ...  7.742e-01  7.588e-01]
#     nfev: 191
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 9.0% 47
# 0101010000 3.6% 5
# 1101010010 3.0% 27
# 1101011000 2.9% 27
# 1101100000 2.4% 46
# 1110010000 2.4% 46
# 0101011010 1.6% 45
# 0110010000 1.3% 44
# 0101100000 1.3% 44
# 1101100001 1.2% 26
# 1110010100 1.2% 26
# 0110010100 1.1% 24
# 0101100001 1.1% 24
# 1110100000 1.0% 45
# 0101101000 1.0% 64
# 1001010000 0.9% 86
# 0110010010 0.9% 64
# 1101010001 0.9% 67
# 1101010100 0.9% 67
# 1101011010 0.8% 7
# depth == 8
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 57.427
#        x: [ 1.783e+00  7.859e-01 ...  7.880e-01  7.828e-01]
#     nfev: 147
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 7.2% 4
# 0000000000 5.7% 40
# 0010100000 4.4% 42
# 1010101000 3.5% 24
# 1010100010 3.5% 24
# 0010000010 3.0% 61
# 0000101000 3.0% 61
# 0000001010 2.5% 80
# 0010000000 2.0% 41
# 0000100000 1.9% 41
# 1010010000 1.3% 45
# 1001100000 1.3% 45
# 0011000000 1.2% 83
# 1000000000 1.2% 82
# 0000110000 1.1% 83
# 1000001010 1.1% 42
# 0000001000 1.0% 60
# 0000000010 1.0% 60
# 1000100010 1.0% 63
# 1110100100 0.9% 25
# depth == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 50.332
#        x: [ 1.927e+00  6.907e-01 ...  7.747e-01  7.579e-01]
#     nfev: 232
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 16.7% 44
# 0001000000 10.3% 42
# 0000010000 10.0% 42
# 0101010000 4.9% 5
# 0100000000 4.8% 81
# 0000000000 4.7% 40
# 0100010100 2.1% 23
# 0101000001 2.0% 23
# 0001000001 1.6% 62
# 0000010100 1.6% 62
# 0100000001 1.3% 61
# 0100000100 1.3% 61
# 0000000001 1.2% 60
# 0000000100 1.1% 60
# 0010010000 1.1% 43
# 0001100000 1.0% 43
# 0100010001 1.0% 63
# 0101000100 1.0% 63
# 0011010000 0.9% 85
# 0001110000 0.9% 85
# depth == 10
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 53.645
#        x: [ 1.784e+00  1.802e+00 ...  7.968e-01  7.855e-01]
#     nfev: 217
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 19.9% 40
# 0000100000 11.5% 41
# 0010000000 11.4% 41
# 0010100000 6.5% 42
# 0100000100 2.4% 61
# 0100000001 2.4% 61
# 0000010000 1.9% 42
# 0001000000 1.8% 42
# 0110000001 1.5% 62
# 0100100100 1.5% 62
# 0010010000 1.1% 43
# 1000001000 1.1% 62
# 0001100000 1.1% 43
# 0000001000 1.0% 60
# 1000000010 1.0% 62
# 0101000100 1.0% 63
# 0100010001 1.0% 63
# 0000000010 1.0% 60
# 0000000101 0.9% 80
# 0110000100 0.9% 62
# depth == 11
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 31.895
#        x: [ 1.781e+00  2.270e+00 ...  7.875e-01  7.872e-01]
#     nfev: 259
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 44.9% 4
# 1010000000 4.4% 43
# 1000100000 4.2% 43
# 1000101000 3.1% 23
# 1010000010 3.1% 23
# 0000000000 2.8% 40
# 0000100000 1.8% 41
# 0010000000 1.7% 41
# 1010100010 1.4% 24
# 1010101000 1.4% 24
# 0000001010 1.1% 80
# 1001101000 1.0% 25
# 1010010010 1.0% 25
# 1010110000 1.0% 46
# 1011100000 0.9% 46
# 1010010000 0.9% 45
# 1001100000 0.9% 45
# 0010001000 0.8% 101
# 1110110000 0.7% 47
# 0000100010 0.7% 101
# depth == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 31.6475
#        x: [ 1.806e+00  7.917e-01 ...  7.875e-01  7.894e-01]
#     nfev: 238
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 38.5% 4
# 1010100100 5.7% 24
# 1010100001 5.7% 24
# 0010100000 3.4% 42
# 1010000010 2.9% 23
# 1000101000 2.8% 23
# 1010101000 2.7% 24
# 1010100010 2.7% 24
# 0000000000 1.8% 40
# 0000100010 1.4% 101
# 0010001000 1.4% 101
# 1110100101 1.0% 5
# 1000100000 0.9% 43
# 1010000000 0.9% 43
# 1011100000 0.9% 46
# 1001100000 0.9% 45
# 1010110000 0.9% 46
# 1010010000 0.8% 45
# 1010110001 0.7% 106
# 1011100100 0.7% 106
# depth == 13
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 13.1075
#        x: [ 5.390e-01  1.748e+00 ...  7.861e-01  7.832e-01]
#     nfev: 309
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 74.3% 5
# 0101010010 6.2% 25
# 0101011000 6.2% 25
# 0101000001 0.9% 23
# 0101000000 0.8% 43
# 0100010000 0.8% 43
# 0100010100 0.8% 23
# 0101010001 0.7% 25
# 0101010100 0.7% 25
# 1111010000 0.6% 48
# 0110010000 0.6% 44
# 1101110000 0.6% 48
# 0111011000 0.5% 106
# 0101100000 0.5% 44
# 0101011010 0.5% 45
# 1101010000 0.5% 47
# 0101110010 0.5% 106
# 1101011000 0.4% 27
# 1101010010 0.4% 27
# 0001000000 0.4% 42
# depth == 14
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 15.3185
#        x: [ 5.477e-01  8.167e-01 ...  7.753e-01  7.873e-01]
#     nfev: 317
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 71.1% 5
# 0101010010 3.9% 25
# 0101011000 3.9% 25
# 0101010100 2.0% 25
# 0101010001 2.0% 25
# 1101110000 1.9% 48
# 1111010000 1.9% 48
# 0000010000 1.3% 42
# 0001000000 1.3% 42
# 0101110000 1.0% 46
# 0111010000 1.0% 46
# 0001010000 0.8% 44
# 0100010100 0.7% 23
# 0101000001 0.6% 23
# 0110010000 0.6% 44
# 0101100000 0.5% 44
# 1101010010 0.3% 27
# 1101011000 0.3% 27
# 0001010001 0.2% 104
# 0001010100 0.2% 104
# depth == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 51.7295
#        x: [ 1.623e+00  9.731e-01 ...  7.776e-01  8.651e-01]
#     nfev: 288
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 6.2% 4
# 0010000000 5.6% 41
# 0000100000 5.4% 41
# 0000000000 5.3% 40
# 0010100000 3.8% 42
# 1010101000 3.2% 24
# 1010100010 3.2% 24
# 1000000000 1.7% 82
# 1010101010 1.5% 44
# 1000101000 1.4% 23
# 1010000010 1.3% 23
# 1011100000 1.2% 46
# 1010110000 1.2% 46
# 0000001000 0.8% 60
# 1000101010 0.8% 43
# 0001000000 0.8% 42
# 1010001010 0.8% 43
# 0000000010 0.8% 60
# 0000010000 0.8% 42
# 0010010000 0.8% 43
# depth == 16
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 19.213
#        x: [ 1.779e+00  7.869e-01 ...  7.798e-01  7.890e-01]
#     nfev: 427
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 56.9% 4
# 1010101000 9.5% 24
# 1010100010 9.5% 24
# 0010100000 2.1% 42
# 1000101000 1.6% 23
# 1010000010 1.5% 23
# 0010000010 0.8% 61
# 1000100000 0.8% 43
# 1010000000 0.8% 43
# 0000101000 0.8% 61
# 1110100100 0.8% 25
# 1110100001 0.7% 25
# 1010100001 0.7% 24
# 1010100100 0.7% 24
# 1000100010 0.7% 63
# 1010001000 0.7% 63
# 0010001000 0.7% 101
# 0000100010 0.7% 101
# 1010101010 0.6% 44
# 0000001000 0.3% 60
# depth == 17
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 20.173
#        x: [ 1.782e+00  1.799e+00 ...  7.903e-01  7.805e-01]
#     nfev: 348
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 50.8% 5
# 0101010010 11.3% 25
# 0101011000 11.2% 25
# 0101010100 3.8% 25
# 0101010001 3.7% 25
# 0101011010 2.5% 45
# 0001010000 1.4% 44
# 1101010000 1.3% 47
# 0100010100 1.1% 23
# 0101000001 1.0% 23
# 0101011100 0.8% 45
# 0101010110 0.8% 45
# 0101011001 0.8% 45
# 0101010011 0.8% 45
# 0110010000 0.5% 44
# 0101100000 0.5% 44
# 0001010100 0.3% 104
# 0001010010 0.3% 64
# 0001011000 0.3% 64
# 0001010001 0.3% 104
# depth == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 29.361
#        x: [ 1.841e+00  2.090e+00 ...  7.878e-01  7.872e-01]
#     nfev: 416
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 46.3% 4
# 1010000000 4.7% 43
# 1000100000 4.6% 43
# 1010010000 3.9% 45
# 1001100000 3.8% 45
# 0010100000 3.6% 42
# 1110100000 2.2% 45
# 1110100101 1.5% 5
# 1110100100 1.3% 25
# 1110100001 1.3% 25
# 1010110000 1.2% 46
# 1011100000 1.2% 46
# 0000000000 0.9% 40
# 1010100100 0.9% 24
# 1010100001 0.9% 24
# 1010101000 0.7% 24
# 1010100010 0.6% 24
# 1010010010 0.6% 25
# 1001101000 0.6% 25
# 0010000010 0.6% 61
# depth == 19
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 32.6575
#        x: [ 1.656e+00  1.007e+00 ...  7.729e-01  7.854e-01]
#     nfev: 427
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 43.5% 4
# 1110100000 6.1% 45
# 0010100000 4.7% 42
# 0000000000 3.2% 40
# 1010000000 2.7% 43
# 1000100000 2.6% 43
# 1010010000 2.4% 45
# 1001100000 2.4% 45
# 1000000000 1.5% 82
# 1010101000 1.4% 24
# 1010100010 1.4% 24
# 1010100100 1.0% 24
# 1000101000 1.0% 23
# 1010100001 1.0% 24
# 1010000010 0.9% 23
# 0000100010 0.8% 101
# 0010001000 0.8% 101
# 1101100100 0.6% 66
# 1110010001 0.5% 66
# 1011100000 0.5% 46
