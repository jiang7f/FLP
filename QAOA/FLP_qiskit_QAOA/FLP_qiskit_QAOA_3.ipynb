# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j - 1] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits))
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(3, 100, 3):
  print(f'penalty == {i}')
  test(i, 3, np.ones(2 * 3))
# Out:
# penalty == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 10.082
#        x: [ 2.009e+00  1.245e+00  9.841e-01  9.267e-01  1.024e+00
#             9.334e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 20.5% 6
# 0100000000 8.0% 13
# 0000010000 7.4% 8
# 0001000000 7.2% 8
# 0000000100 2.0% 9
# 0000000001 2.0% 9
# 0001010000 1.9% 10
# 0101000000 1.9% 9
# 0100010000 1.9% 9
# 0101010000 1.7% 5
# 1010000000 1.7% 9
# 1000100000 1.6% 9
# 0000100000 1.5% 7
# 1010100000 1.5% 4
# 0010000000 1.4% 7
# 0101000100 1.2% 12
# 0100010001 1.1% 12
# 1001100000 0.8% 11
# 1000110000 0.8% 17
# 1011000000 0.8% 17
# penalty == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 25.898
#        x: [ 2.107e+00  1.205e+00  8.813e-01  1.001e+00  1.033e+00
#             1.981e+00]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000001101 2.1% 30
# 0000000111 2.1% 30
# 0000000110 1.9% 24
# 0000001001 1.8% 24
# 0000000010 1.8% 18
# 0000000101 1.8% 24
# 0000000011 1.7% 24
# 0000001000 1.7% 18
# 0000001100 1.6% 24
# 1000001010 1.5% 14
# 0000000001 1.5% 18
# 0000001111 1.4% 36
# 0000000100 1.4% 18
# 1000101011 1.4% 21
# 1010001110 1.4% 21
# 1000001111 1.4% 26
# 1000101111 1.3% 27
# 0000000000 1.3% 12
# 1010001111 1.3% 27
# 1000001110 1.2% 20
# penalty == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 27.0055
#        x: [ 1.865e+00  1.106e+00  9.212e-01  1.016e+00  1.054e+00
#             9.963e-01]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 19.8% 18
# 0100000000 13.6% 37
# 0000010000 7.0% 20
# 0001000000 6.8% 20
# 0000000100 3.0% 27
# 0000000001 3.0% 27
# 0100010000 2.9% 21
# 0101000000 2.9% 21
# 0001010000 2.7% 22
# 0000100000 2.1% 19
# 0010000000 2.1% 19
# 0110000000 1.2% 38
# 0100100000 1.2% 38
# 1000000010 0.9% 29
# 1000001000 0.8% 29
# 0000010100 0.8% 29
# 0001000001 0.8% 29
# 0001100000 0.7% 21
# 0010010000 0.7% 21
# 1010100000 0.7% 4
# penalty == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 48.74
#        x: [ 2.450e+00  1.792e+00  9.028e-01  8.530e-01  2.019e+00
#             9.836e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000101 3.0% 25
# 0100010101 2.2% 27
# 0101000101 2.1% 27
# 1100001111 1.8% 27
# 0000000000 1.3% 24
# 0100001111 1.1% 49
# 1000001010 1.1% 26
# 0101010101 1.0% 29
# 0100010001 1.0% 39
# 0100000100 1.0% 37
# 0100000001 1.0% 37
# 0101000100 1.0% 39
# 1100000111 0.9% 39
# 1100001101 0.9% 39
# 1100011111 0.8% 29
# 0100001101 0.8% 37
# 0100000111 0.8% 37
# 1101001111 0.8% 29
# 1101000111 0.8% 41
# 0000000100 0.8% 36
# penalty == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 46.957
#        x: [ 1.145e+00  9.769e-01  9.965e-01  1.031e+00  1.122e+00
#             8.626e-01]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010101010 5.4% 34
# 1010101000 4.2% 19
# 1010100000 4.2% 4
# 1010100010 4.1% 19
# 1000101000 2.3% 18
# 1010000010 2.3% 18
# 1010001010 1.7% 33
# 0010101010 1.7% 122
# 1000101010 1.6% 33
# 0000000000 1.6% 30
# 1000001010 1.4% 32
# 1010101110 1.0% 49
# 1000000000 0.9% 62
# 1010101011 0.9% 49
# 1010011010 0.9% 35
# 1001101010 0.9% 35
# 0010001000 0.9% 76
# 0000001000 0.8% 45
# 0000100010 0.8% 76
# 0000000010 0.8% 45
# penalty == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 59.292
#        x: [ 1.459e+00  2.116e+00  8.543e-01  8.763e-01  9.700e-01
#             8.059e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 6.4% 41
# 1111100000 3.2% 43
# 1110110000 3.2% 43
# 1111110000 2.9% 45
# 1110010010 2.5% 24
# 1101101000 2.5% 24
# 1101111000 2.3% 26
# 1111010010 2.2% 26
# 1100100000 2.0% 76
# 1110000000 2.0% 76
# 1111010000 1.5% 44
# 1101110000 1.4% 44
# 1010100000 1.3% 4
# 1101011010 1.2% 7
# 1110101000 1.1% 59
# 1110100010 1.1% 59
# 1011110000 1.0% 80
# 0110010000 1.0% 40
# 0101100000 1.0% 40
# 1101100000 0.9% 42
# penalty == 21
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 43.0305
#        x: [ 1.429e+00  8.804e-01  1.909e+00  8.848e-01  1.453e+00
#             1.080e+00]
#     nfev: 77
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 26.8% 5
# 0101010001 9.4% 26
# 0101010100 9.2% 26
# 0001010000 8.1% 46
# 0101010101 3.1% 47
# 0001000001 1.3% 65
# 1101011000 1.2% 28
# 1101010010 1.2% 28
# 0000010100 1.2% 65
# 0111010000 1.0% 48
# 0101110000 0.9% 48
# 0101011000 0.9% 26
# 0101010010 0.8% 26
# 0100000000 0.8% 85
# 0001010100 0.7% 109
# 0101110001 0.7% 69
# 0001010001 0.7% 109
# 1111011000 0.7% 71
# 0111010100 0.7% 69
# 1101110010 0.6% 71
# penalty == 24
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 104.95
#        x: [ 1.998e+00  1.999e+00  2.002e+00  9.976e-01  2.001e+00
#             1.004e+00]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 2.0% 57
# 1011110000 1.3% 104
# 1111100000 1.2% 55
# 1110110000 1.2% 55
# 1010110000 1.0% 54
# 1011100000 1.0% 54
# 1011110101 1.0% 248
# 0111110000 0.9% 103
# 1101010000 0.8% 55
# 1000111100 0.7% 101
# 1100010000 0.7% 101
# 1011000011 0.6% 101
# 1101000000 0.6% 101
# 0101010000 0.6% 5
# 1101010010 0.5% 31
# 1111110010 0.5% 81
# 1101011000 0.5% 31
# 0110110000 0.5% 101
# 1110110001 0.5% 79
# 1111111000 0.5% 81
# penalty == 27
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 86.2125
#        x: [ 3.328e+00  1.833e+00  5.176e-01  2.259e+00  8.932e-01
#             6.211e-01]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 9.9% 4
# 1010101000 5.2% 31
# 1010100010 5.2% 31
# 0010100000 4.7% 56
# 1010101010 3.1% 58
# 0010100010 2.4% 137
# 0010101000 2.4% 137
# 1001101000 2.0% 32
# 1010010010 2.0% 32
# 0010101010 1.9% 218
# 1011100000 1.3% 60
# 1010110000 1.2% 60
# 1001100000 1.1% 59
# 1010010000 1.0% 59
# 1000101000 0.8% 30
# 1010000010 0.8% 30
# 1010111000 0.8% 87
# 1010110010 0.8% 87
# 0010110000 0.8% 112
# 1011101000 0.8% 87
# penalty == 30
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 85.233
#        x: [ 1.772e+00  9.519e-01  3.968e-01  6.441e-01  1.998e+00
#             1.020e+00]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 12.1% 4
# 1010000000 5.9% 63
# 1000100000 5.9% 63
# 1110100000 2.8% 65
# 1000000000 2.8% 122
# 0000000000 2.4% 60
# 1111100000 1.8% 67
# 1110110000 1.7% 67
# 1010000001 1.2% 93
# 1000100100 1.2% 93
# 1100100000 1.2% 124
# 1110000000 1.2% 124
# 1010100001 1.1% 34
# 1010100100 1.1% 34
# 1110000001 1.1% 94
# 1100100100 1.0% 94
# 1110100100 1.0% 35
# 1111000000 1.0% 126
# 1110100001 0.9% 35
# 1100110000 0.9% 126
# penalty == 33
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 45.0795
#        x: [ 7.714e-01  9.636e-01  1.105e+00  1.417e+00  2.106e+00
#             8.615e-01]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 44.3% 4
# 1010100001 5.8% 37
# 1010100100 5.7% 37
# 1010100010 3.3% 37
# 1010101000 3.3% 37
# 1110100000 2.8% 71
# 1010000000 2.5% 69
# 1000100000 2.5% 69
# 0010100000 2.2% 68
# 1111100000 1.1% 73
# 1110110000 1.0% 73
# 1010110000 0.7% 72
# 1011100000 0.7% 72
# 1000000000 0.7% 134
# 1010100101 0.7% 70
# 1010010000 0.6% 71
# 1001100000 0.6% 71
# 1110110001 0.5% 106
# 1010000010 0.5% 36
# 1011100100 0.5% 171
# penalty == 36
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 109.575
#        x: [ 2.012e+00  9.545e-01  7.458e-01  1.998e+00  9.704e-01
#             9.617e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 5.9% 72
# 0001000000 5.8% 74
# 0001010000 5.8% 76
# 0000010000 5.7% 74
# 1000000000 5.1% 146
# 1000010000 3.6% 148
# 1001000000 3.5% 148
# 1001010000 2.6% 150
# 0010010000 2.1% 75
# 0000100000 2.1% 73
# 0010000000 2.1% 73
# 0001100000 2.1% 75
# 0101010000 1.6% 5
# 0001010010 0.9% 112
# 0001110000 0.8% 149
# 0001011000 0.8% 112
# 0001001000 0.8% 110
# 0011000000 0.8% 147
# 0000110000 0.8% 147
# 0011010000 0.8% 149
# penalty == 39
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 145.518
#        x: [ 2.249e+00  1.001e+00  1.000e+00  2.001e+00  9.990e-01
#             1.026e+00]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 3.7% 83
# 1010100000 2.5% 4
# 1010100100 1.7% 43
# 1010100001 1.7% 43
# 1110101000 1.4% 122
# 1110100010 1.3% 122
# 1110100101 1.1% 5
# 0110001000 0.9% 275
# 0100100010 0.9% 275
# 1010100011 0.8% 82
# 1010101100 0.8% 82
# 1111100000 0.8% 85
# 1110110000 0.8% 85
# 1010010001 0.7% 200
# 1110100100 0.7% 44
# 1001100100 0.7% 200
# 1110100001 0.7% 44
# 1100101000 0.7% 121
# 1010101000 0.6% 43
# 1110000010 0.6% 121
# penalty == 42
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 174.424
#        x: [ 1.004e+00  1.777e+00  8.938e-01  2.001e+00  1.000e+00
#             9.987e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1100101101 1.2% 46
# 1110000111 1.2% 46
# 1011110000 0.8% 176
# 0010100000 0.7% 86
# 0011111010 0.7% 510
# 1001101000 0.6% 47
# 1010010010 0.6% 47
# 1111000011 0.6% 90
# 0001011010 0.6% 172
# 1100111100 0.5% 90
# 1001011010 0.5% 90
# 0101000011 0.5% 87
# 0100011100 0.5% 87
# 0101010000 0.5% 5
# 1100101001 0.5% 88
# 1111000010 0.5% 132
# 0101010010 0.5% 47
# 1100111000 0.5% 132
# 1110000110 0.5% 88
# 0110101111 0.4% 339
# penalty == 45
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 134.949
#        x: [ 2.435e+00  2.547e+00  2.352e-01  2.033e+00  8.361e-01
#             8.758e-01]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0010100000 17.3% 92
# 0110100000 5.7% 183
# 0010010000 3.1% 93
# 0001100000 2.9% 93
# 0010100001 2.8% 137
# 0010100100 2.8% 137
# 0000100000 2.8% 91
# 0010000000 2.8% 91
# 0100100000 1.8% 182
# 0110000000 1.7% 182
# 0010000010 1.4% 136
# 0000101000 1.3% 136
# 1010000000 1.3% 93
# 0100000000 1.3% 181
# 1000100000 1.3% 93
# 0000000000 1.2% 90
# 0101100000 1.2% 94
# 0110010000 1.2% 94
# 1000000000 1.0% 182
# 0111100000 1.0% 185
# penalty == 48
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 102.779
#        x: [ 1.580e+00  1.420e+00  1.555e+00  1.764e+00  1.047e+00
#             2.293e+00]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 16.8% 5
# 0101000000 7.0% 99
# 0100010000 6.9% 99
# 0001010000 5.3% 100
# 0101010010 3.4% 53
# 0101011000 3.4% 53
# 0100000000 2.8% 193
# 0101010100 2.5% 53
# 0101010001 2.4% 53
# 1101010000 2.3% 103
# 0100011000 1.5% 147
# 0101000010 1.4% 147
# 0100010010 1.4% 147
# 0101001000 1.4% 147
# 0100010001 1.1% 147
# 0001011000 1.1% 148
# 0000010000 1.1% 98
# 0101000100 1.1% 147
# 0001000000 1.0% 98
# 0001010010 1.0% 148
# penalty == 51
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 91.016
#        x: [ 2.034e+00  1.002e+00  2.074e+00  1.298e+00  9.908e-01
#             9.810e-01]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 29.0% 4
# 1110100000 9.3% 107
# 0010100000 8.3% 104
# 1001100000 4.0% 107
# 1010010000 3.8% 107
# 1010000000 3.0% 105
# 1000100000 2.9% 105
# 0110100000 2.6% 207
# 1011100000 2.5% 108
# 1010110000 2.5% 108
# 1010100001 2.0% 55
# 1010100100 1.9% 55
# 1110000000 0.9% 208
# 1100100000 0.9% 208
# 1110100001 0.9% 56
# 1110100100 0.8% 56
# 1111100000 0.8% 109
# 1110110000 0.8% 109
# 0010110000 0.6% 208
# 1000101000 0.6% 54
# penalty == 54
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 152.4675
#        x: [ 1.566e+00  2.101e+00  9.435e-01  2.097e+00  8.664e-01
#             8.733e-01]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 8.2% 4
# 1111110000 7.3% 117
# 1011100000 7.0% 114
# 1010110000 6.9% 114
# 1011110000 6.5% 224
# 1111100000 5.5% 115
# 1110110000 5.5% 115
# 1110100000 4.2% 113
# 1010100010 1.3% 58
# 1010101000 1.2% 58
# 0111110000 1.2% 223
# 1111110010 1.2% 171
# 1011101000 1.1% 168
# 1011100010 1.1% 168
# 1111111000 1.1% 171
# 0010100000 1.1% 110
# 1010110010 1.1% 168
# 0011100000 1.1% 220
# 0010000000 1.1% 109
# 1010111000 1.1% 168
# penalty == 57
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 190.25
#        x: [ 1.999e+00  9.972e-01  1.014e+00  9.997e-01  9.986e-01
#             1.001e+00]
#     nfev: 61
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 9.9% 121
# 1100010000 3.5% 233
# 1101000000 3.5% 233
# 1100000000 3.2% 345
# 0101010000 2.8% 5
# 1111010000 2.2% 122
# 1101110000 2.2% 122
# 1101010001 2.1% 178
# 1101010100 2.1% 178
# 1000000000 2.0% 230
# 1101010010 1.6% 64
# 1101011000 1.6% 64
# 0100000000 1.5% 229
# 1000010000 1.2% 232
# 1001000000 1.2% 232
# 1111000000 1.2% 234
# 0101000000 1.2% 117
# 0100010000 1.2% 117
# 1100110000 1.1% 234
# 1001010000 1.1% 234
# penalty == 60
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 195.6545
#        x: [ 1.482e+00  8.791e-01  2.039e+00  4.723e-01  8.721e-01
#             6.959e-01]
#     nfev: 68
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 2.6% 127
# 0101010000 2.4% 5
# 1101010001 2.0% 187
# 1101010100 1.9% 187
# 0101010100 1.8% 65
# 0101010001 1.7% 65
# 1100010100 1.1% 185
# 1101010101 1.1% 247
# 1101000001 1.1% 185
# 0100010100 1.0% 63
# 0101010101 1.0% 125
# 0101000001 0.9% 63
# 1001010000 0.8% 246
# 1101010010 0.8% 67
# 1110011000 0.8% 186
# 1101011000 0.8% 67
# 1101100010 0.7% 186
# 1100010000 0.7% 245
# 1101000000 0.7% 245
# 0001010000 0.7% 124
# penalty == 63
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 142.245
#        x: [ 1.003e+00  1.083e+00  7.328e-01  9.997e-01  9.984e-01
#             2.002e+00]
#     nfev: 58
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 20.5% 5
# 1101010000 6.6% 133
# 0101011000 5.0% 68
# 0101010010 4.9% 68
# 0001010000 4.5% 130
# 0101000000 4.3% 129
# 0100010000 4.3% 129
# 0101011010 1.8% 131
# 0101110000 1.5% 132
# 0111010000 1.5% 132
# 1001010000 1.5% 258
# 0100011000 1.3% 192
# 0101000010 1.3% 192
# 1101000000 1.2% 257
# 1100010000 1.2% 257
# 0100000000 1.2% 253
# 0001010010 1.1% 193
# 0001011000 1.1% 193
# 0100010010 1.0% 192
# 0101001000 1.0% 192
# penalty == 66
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 200.13
#        x: [ 2.031e+00  9.807e-01  2.006e+00  1.962e+00  1.044e+00
#             9.886e-01]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 10.3% 132
# 0001000000 6.7% 134
# 0000010000 6.5% 134
# 0001010000 6.3% 136
# 0010000000 2.5% 133
# 0000100000 2.4% 133
# 0100000001 1.8% 199
# 0100000100 1.7% 199
# 0101000000 1.7% 135
# 1000000000 1.6% 266
# 0100010000 1.6% 135
# 0101010001 1.5% 71
# 0101010100 1.4% 71
# 0100000000 1.1% 265
# 0101000100 1.1% 201
# 0100010001 1.1% 201
# 0001100000 1.0% 135
# 0010010000 1.0% 135
# 0010100000 0.9% 134
# 0110000000 0.9% 266
# penalty == 69
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 239.966
#        x: [ 2.053e+00  3.666e-01  7.505e-01  2.042e+00  8.603e-01
#             6.719e-02]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1001010000 3.4% 282
# 1000000000 3.3% 278
# 1001000000 3.1% 280
# 1000010000 3.1% 280
# 1001110000 2.7% 283
# 1011010000 2.7% 283
# 1110100000 2.3% 143
# 1010100000 2.2% 4
# 0010010000 2.0% 141
# 0001100000 1.9% 141
# 1011100000 1.8% 144
# 0010000000 1.7% 139
# 0000100000 1.7% 139
# 1010110000 1.7% 144
# 1100000000 1.5% 417
# 1001100000 1.4% 143
# 0110000000 1.4% 278
# 0100100000 1.4% 278
# 1010010000 1.4% 143
# 1011000000 1.3% 281
# penalty == 72
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 191.308
#        x: [ 2.004e+00  9.984e-01  1.025e+00  9.989e-01  1.002e+00
#             1.000e+00]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 25.0% 144
# 0100000000 6.9% 289
# 0000010000 4.8% 146
# 0001000000 4.7% 146
# 0100010000 3.3% 147
# 0101000000 3.3% 147
# 0000000100 2.7% 216
# 0000000001 2.7% 216
# 1010000000 2.6% 147
# 1000100000 2.5% 147
# 0101010000 2.2% 5
# 0100000001 1.0% 217
# 0010000000 1.0% 145
# 0100000100 1.0% 217
# 0000100000 1.0% 145
# 1010100000 0.9% 4
# 0000010100 0.9% 218
# 0001000001 0.9% 218
# 1010010000 0.8% 149
# 1110000000 0.8% 292
# penalty == 75
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 212.073
#        x: [ 1.565e+00  1.032e+00  2.023e+00  9.178e-01  2.004e+00
#             9.422e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 4.4% 5
# 0101011000 2.4% 80
# 0101010010 2.3% 80
# 0001010000 2.2% 154
# 0101000000 1.8% 153
# 1101010000 1.8% 157
# 0100010000 1.7% 153
# 0101100000 1.4% 154
# 0110010000 1.4% 154
# 0101010100 1.3% 80
# 0101010001 1.3% 80
# 0101110000 1.2% 156
# 0111010000 1.1% 156
# 0101011010 1.1% 155
# 0101000010 1.1% 228
# 0100011000 1.1% 228
# 0001011000 1.1% 229
# 0001010010 1.0% 229
# 0100010010 0.8% 228
# 0110010100 0.8% 79
# penalty == 78
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 285.13
#        x: [ 2.005e+00  1.047e+00  1.210e+00  7.201e-01  9.706e-01
#             9.946e-01]
#     nfev: 58
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1000000000 5.4% 314
# 1110100000 3.2% 161
# 1100000000 2.5% 471
# 1010100000 2.4% 4
# 1100100000 2.3% 316
# 1110000000 2.2% 316
# 1000100000 1.8% 159
# 1010000000 1.8% 159
# 0000100000 1.2% 157
# 0100100000 1.1% 314
# 0110000000 1.1% 314
# 0010000000 1.1% 157
# 1100110000 1.1% 318
# 1111000000 1.1% 318
# 1011110000 1.0% 320
# 1110110001 1.0% 241
# 1111100100 1.0% 241
# 1010101000 0.8% 82
# 1000010000 0.8% 316
# 1010100010 0.8% 82
# penalty == 81
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 251.2805
#        x: [ 2.060e+00  7.413e-01  2.036e+00  9.271e-01  9.590e-01
#             9.330e-01]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 8.9% 167
# 0110100000 6.0% 327
# 1100100000 4.2% 328
# 1110000000 4.2% 328
# 1100000000 3.7% 489
# 1010100000 3.7% 4
# 0010100000 2.8% 164
# 0110000000 1.9% 326
# 0100100000 1.8% 326
# 1111100000 1.4% 169
# 1110110000 1.4% 169
# 1101100000 1.3% 168
# 1110010000 1.3% 168
# 1010100001 1.2% 85
# 1010100100 1.2% 85
# 1101000000 1.2% 329
# 0111100000 1.2% 329
# 0110110000 1.1% 329
# 1100010000 1.1% 329
# 1010000000 1.1% 165
# penalty == 84
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 322.222
#        x: [ 5.196e-01  3.473e-01  9.508e-01  2.547e+00  6.762e-01
#             2.063e+00]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0010100101 1.6% 338
# 1011110000 1.2% 344
# 0011110000 1.2% 510
# 0110110000 1.1% 341
# 0111100000 1.1% 341
# 0110100000 1.0% 339
# 1100110000 0.9% 342
# 1111000000 0.9% 342
# 1111100000 0.9% 175
# 0010100000 0.9% 170
# 0010100100 0.9% 254
# 1010000101 0.9% 339
# 1110110000 0.9% 175
# 0010100001 0.8% 254
# 1100000000 0.8% 507
# 0111100001 0.8% 257
# 1000100101 0.8% 339
# 0110110100 0.8% 257
# 1001101001 0.8% 173
# 1110000000 0.8% 340
# penalty == 87
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 258.218
#        x: [ 1.467e+00  2.034e+00  8.838e-01  4.720e-01  1.271e+00
#             9.380e-01]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 5.3% 183
# 1110100000 4.9% 179
# 1110110000 4.6% 181
# 1111100000 4.6% 181
# 1010100000 1.9% 4
# 1011110000 1.8% 356
# 1011100000 1.5% 180
# 1111110100 1.5% 270
# 1111110001 1.5% 270
# 1010110000 1.5% 180
# 1110110100 1.5% 94
# 1111111000 1.5% 270
# 1111100001 1.5% 94
# 1111110010 1.4% 270
# 0111110000 1.3% 355
# 1111101000 1.2% 268
# 1110110010 1.2% 268
# 1110100010 1.1% 266
# 1110101000 1.1% 266
# 1110111000 1.0% 268
# penalty == 90
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 292.745
#        x: [ 8.431e-01  2.532e+00  6.724e-01  7.227e-02  8.628e-01
#             9.465e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1100000000 1.3% 543
# 1100100000 1.2% 364
# 1110100000 1.2% 185
# 1110000000 1.2% 364
# 1100000010 1.1% 453
# 1100101000 1.1% 274
# 1101000000 1.1% 365
# 1110000010 1.1% 274
# 1100001000 1.0% 453
# 1101100000 1.0% 186
# 1110100001 1.0% 95
# 1100100001 1.0% 274
# 1100010000 1.0% 365
# 1110100100 1.0% 95
# 1110000100 1.0% 274
# 1110010000 0.9% 186
# 1101101000 0.9% 96
# 1101010000 0.9% 187
# 1100010010 0.9% 275
# 1100101001 0.9% 184
# penalty == 93
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 333.608
#        x: [ 2.004e+00  2.242e+00  1.012e+00  1.115e+00  1.963e+00
#             1.115e+00]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110101111 5.7% 191
# 1110111111 2.9% 379
# 1111101111 2.8% 379
# 1010101111 2.8% 376
# 1110101101 1.9% 98
# 1110100111 1.8% 98
# 1111111111 1.7% 567
# 1010101011 1.6% 283
# 1110101011 1.5% 284
# 1010101110 1.5% 283
# 1110101110 1.5% 284
# 1100101111 1.4% 190
# 1110001111 1.4% 190
# 1110011111 1.0% 192
# 1111101101 1.0% 286
# 1110110111 0.9% 286
# 1101101111 0.9% 192
# 1010101101 0.9% 283
# 1010100111 0.9% 283
# 1110111101 0.9% 286
# penalty == 96
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 359.06
#        x: [ 9.881e-01  7.154e-01  2.001e+00  2.001e+00  2.002e+00
#             9.990e-01]
#     nfev: 62
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 4.3% 385
# 0101010000 1.6% 5
# 0001000000 1.4% 194
# 0000010000 1.4% 194
# 0110100000 1.3% 387
# 0100000100 1.2% 289
# 0110010000 1.1% 196
# 0100000001 1.1% 289
# 0101100000 1.1% 196
# 1100100000 0.9% 388
# 1110000000 0.9% 388
# 0100000010 0.9% 481
# 0100001000 0.9% 481
# 1000000000 0.7% 386
# 0001010000 0.7% 196
# 0010100000 0.7% 194
# 0101000000 0.7% 195
# 0100010000 0.7% 195
# 1010100000 0.7% 4
# 1110101010 0.6% 389
# penalty == 99
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 289.9845
#        x: [ 1.492e+00  7.465e-01  2.003e+00  2.069e+00  1.042e+00
#             1.017e+00]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 4.7% 4
# 1110110000 2.8% 205
# 1111100000 2.8% 205
# 1011100000 2.4% 204
# 1010110000 2.4% 204
# 1110100000 2.0% 203
# 1110110001 1.9% 304
# 1111100100 1.9% 304
# 0010100000 1.8% 200
# 1111110000 1.6% 207
# 1101100000 1.5% 204
# 1110010000 1.5% 204
# 1101110000 0.9% 206
# 1000100000 0.9% 201
# 1010000000 0.8% 201
# 1111010000 0.8% 206
# 1001100000 0.8% 203
# 1010010000 0.8% 203
# 1110010001 0.7% 303
# 0110010010 0.7% 301
