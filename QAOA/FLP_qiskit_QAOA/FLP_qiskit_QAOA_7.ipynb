# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j - 1] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits))
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(3, 100, 3):
  print(f'rand == {i}')
  test(20, 3, np.random.rand(2 * 3))
# Out:
# rand == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.9145
#        x: [ 1.516e+00  1.440e+00  2.418e-01  9.221e-01  2.014e+00
#             3.337e-01]
#     nfev: 67
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 5.1% 4
# 1010100010 2.5% 24
# 1010101000 2.5% 24
# 1000100000 2.4% 43
# 1010000000 2.2% 43
# 0010100000 1.5% 42
# 1000101000 1.4% 23
# 1010000010 1.4% 23
# 1010101010 1.2% 44
# 1000000000 1.2% 82
# 1110100000 1.1% 45
# 1010100100 1.1% 24
# 1010001010 1.1% 43
# 1010001000 1.1% 63
# 1000101010 1.1% 43
# 1000100010 1.1% 63
# 1010100001 1.1% 24
# 1010010000 0.9% 45
# 1110100001 0.8% 25
# 1001100000 0.8% 45
# rand == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 82.838
#        x: [ 8.533e-01  6.479e-01  1.081e+00  1.387e+00  4.042e-01
#             3.793e-01]
#     nfev: 62
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1000001001 1.2% 82
# 1010111110 1.2% 106
# 1000000110 1.2% 82
# 1011101011 1.2% 106
# 1100111010 1.1% 86
# 1111001010 1.1% 86
# 1100001010 1.1% 83
# 1000110110 1.0% 125
# 1011001001 0.9% 125
# 1100001101 0.9% 63
# 1011001011 0.9% 105
# 1000111110 0.9% 105
# 1100000111 0.9% 63
# 0100000101 0.9% 41
# 1100001000 0.7% 103
# 1111111010 0.7% 89
# 1100000010 0.7% 103
# 1000001011 0.7% 62
# 1000001110 0.7% 62
# 1110111010 0.6% 87
# rand == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.3705
#        x: [ 1.460e+00  2.241e-01  6.328e-02  7.665e-01  1.380e+00
#             3.811e-01]
#     nfev: 84
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 11.2% 45
# 1110110000 6.1% 47
# 1111100000 6.0% 47
# 1111110000 4.5% 49
# 1010100000 4.2% 4
# 1110000000 3.6% 84
# 1100100000 3.4% 84
# 1111000000 2.2% 86
# 1100110000 2.2% 86
# 1010000000 2.1% 43
# 1000100000 2.1% 43
# 1100000000 1.4% 123
# 1000000000 1.4% 82
# 1010110000 1.1% 46
# 1011100000 1.1% 46
# 1110100100 1.1% 25
# 1110100001 1.0% 25
# 1011110000 1.0% 88
# 1100101000 1.0% 64
# 1110000010 1.0% 64
# rand == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.848
#        x: [ 6.098e-01  3.991e-01  1.545e+00  4.231e-01  2.078e-01
#             4.533e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 8.8% 40
# 1000000000 4.5% 82
# 1000100000 3.8% 43
# 1010000000 3.8% 43
# 1010100000 3.0% 4
# 1000001010 2.1% 42
# 1000001000 2.0% 62
# 1000000010 2.0% 62
# 0100000101 1.5% 41
# 0010000000 1.3% 41
# 0000100000 1.3% 41
# 1000101000 1.3% 23
# 0000000100 1.3% 60
# 0000000001 1.2% 60
# 1010000010 1.2% 23
# 1010001000 1.1% 63
# 1000100010 1.1% 63
# 0000000010 1.0% 60
# 0000001000 1.0% 60
# 1100000101 0.7% 83
# rand == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 76.8155
#        x: [ 1.421e+00  7.259e-01  9.182e-01  1.323e-02  1.660e+00
#             2.544e-01]
#     nfev: 60
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 10.2% 44
# 0000010000 3.8% 42
# 0001000000 3.6% 42
# 0101010000 3.6% 5
# 1001010000 3.5% 86
# 0001010001 1.8% 104
# 0001010100 1.7% 104
# 0000000000 1.5% 40
# 0001100000 1.4% 43
# 0010010000 1.4% 43
# 1000010000 1.4% 84
# 1001000000 1.3% 84
# 0000010100 1.2% 62
# 0001000001 1.2% 62
# 0001100010 1.1% 103
# 0010011000 1.1% 103
# 1010011000 1.1% 65
# 1001100010 1.1% 65
# 1101010000 1.1% 47
# 0100000101 1.0% 41
# rand == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 85.3935
#        x: [ 1.594e+00  1.236e+00  2.642e-02  1.162e-01  5.684e-01
#             1.616e+00]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 1.5% 49
# 0000111100 1.3% 123
# 0101111000 1.2% 66
# 0011000011 1.2% 123
# 0111010010 1.2% 66
# 1011100001 1.1% 66
# 1010110100 1.1% 66
# 1101010010 1.0% 27
# 1101011000 0.9% 27
# 1111000000 0.8% 86
# 1100110000 0.8% 86
# 1101100000 0.7% 46
# 1110010000 0.7% 46
# 1011000011 0.6% 85
# 1000111100 0.6% 85
# 1101110000 0.6% 48
# 1101011010 0.6% 7
# 1111010000 0.6% 48
# 1111110010 0.6% 69
# 0011100001 0.6% 104
# rand == 21
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 73.45
#        x: [ 4.103e-01 -3.701e-01  4.584e-01  3.417e-01 -5.998e-01
#            -3.031e-02]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 2.7% 81
# 1100000000 2.4% 123
# 1000000000 2.3% 82
# 0000000000 2.0% 40
# 0000010000 1.4% 42
# 0001000000 1.4% 42
# 0101010000 1.1% 5
# 0000100000 1.0% 41
# 0000000100 1.0% 60
# 1000000100 1.0% 102
# 0010000000 1.0% 41
# 1000000001 1.0% 102
# 0000000001 0.9% 60
# 1000010000 0.9% 84
# 0100000010 0.9% 101
# 1001000000 0.9% 84
# 0100001000 0.8% 101
# 0100100000 0.8% 82
# 0110000000 0.8% 82
# 0100010000 0.8% 43
# rand == 24
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 69.233
#        x: [ 2.453e-01  8.657e-01  4.455e-01  3.045e-01  6.564e-01
#             8.105e-01]
#     nfev: 84
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 3.8% 49
# 1111010000 2.2% 48
# 1101110000 2.2% 48
# 0101010000 1.6% 5
# 1111100000 1.3% 47
# 1110110000 1.2% 47
# 1111000000 1.2% 86
# 1100110000 1.2% 86
# 1101111000 1.0% 28
# 1111010010 1.0% 28
# 1101010000 1.0% 47
# 1111000001 0.9% 66
# 0100010000 0.9% 43
# 0101000000 0.9% 43
# 1100110100 0.9% 66
# 0101010010 0.7% 25
# 1101010010 0.7% 27
# 1101100000 0.7% 46
# 0101011000 0.7% 25
# 1101011000 0.7% 27
# rand == 27
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.2295
#        x: [ 1.399e+00  5.046e-01  1.009e+00  1.457e-01  8.183e-01
#             4.781e-02]
#     nfev: 59
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 3.6% 47
# 1101100000 3.1% 46
# 1110010000 3.1% 46
# 1110100000 3.1% 45
# 1111010000 2.9% 48
# 1101110000 2.8% 48
# 1011100000 2.5% 46
# 1010110000 2.5% 46
# 1001010000 2.3% 86
# 0111110000 2.0% 87
# 0101010000 1.9% 5
# 1011010000 1.8% 87
# 1001110000 1.8% 87
# 1010010000 1.7% 45
# 1001100000 1.7% 45
# 0110100000 1.5% 83
# 0101100000 1.5% 44
# 1111100000 1.4% 47
# 1110110000 1.4% 47
# 0110010000 1.4% 44
# rand == 30
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 66.158
#        x: [ 1.580e+00  8.531e-01  5.897e-01  7.851e-01  6.008e-01
#             8.191e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 18.6% 40
# 1000000000 7.6% 82
# 0000000100 4.2% 60
# 0000000001 4.1% 60
# 0000000010 2.9% 60
# 0000001000 2.8% 60
# 0010000000 2.4% 41
# 0001000000 2.3% 42
# 0000100000 2.3% 41
# 0100000000 2.3% 81
# 0000010000 2.2% 42
# 1000000100 1.7% 102
# 1000000001 1.7% 102
# 0000000101 1.6% 80
# 1000100000 1.5% 43
# 1010000000 1.4% 43
# 0100000100 1.2% 61
# 0100000001 1.2% 61
# 0000001010 0.9% 80
# 1100000000 0.8% 123
# rand == 33
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 68.633
#        x: [ 3.690e-01  1.850e+00  1.879e+00  6.961e-03  1.720e-01
#             9.934e-01]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110010110 1.0% 6
# 1101101001 1.0% 6
# 1110000111 0.9% 24
# 1100101101 0.9% 24
# 1110111100 0.8% 47
# 1100111100 0.8% 46
# 1101101101 0.7% 26
# 1110101101 0.7% 25
# 1110010111 0.7% 26
# 1111100011 0.7% 47
# 1110100111 0.7% 25
# 1111000011 0.7% 46
# 1101101011 0.7% 26
# 1110011110 0.7% 26
# 1100001111 0.7% 43
# 1101001011 0.6% 25
# 1110001111 0.6% 44
# 1101111100 0.6% 48
# 1100101111 0.6% 44
# 1111010011 0.6% 48
# rand == 36
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 56.94
#        x: [ 1.565e+00  1.246e+00  1.645e+00  9.244e-01  4.338e-01
#             9.556e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 9.9% 4
# 1110100000 8.7% 45
# 1111100000 6.1% 47
# 1110110000 6.1% 47
# 1111110000 5.0% 49
# 1100100000 3.6% 84
# 1110000000 3.5% 84
# 1000100000 2.5% 43
# 1010000000 2.5% 43
# 1011100000 2.0% 46
# 1111000000 2.0% 86
# 1010110000 2.0% 46
# 1100110000 2.0% 86
# 1110100100 1.4% 25
# 1110100001 1.4% 25
# 1010100001 1.3% 24
# 1010100100 1.3% 24
# 1110110100 1.1% 27
# 1111100001 1.1% 27
# 0010100000 0.9% 42
# rand == 39
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 69.437
#        x: [ 8.159e-02  6.206e-01  4.172e-01  7.105e-01  3.767e-01
#             9.225e-01]
#     nfev: 61
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 5.1% 40
# 1000000000 4.9% 82
# 1000100000 3.2% 43
# 1010000000 3.2% 43
# 1000100010 2.1% 63
# 1010001000 2.1% 63
# 1010100000 1.5% 4
# 0000010000 1.4% 42
# 0001000000 1.4% 42
# 0100000000 1.3% 81
# 0000000001 1.3% 60
# 0000000100 1.3% 60
# 1000000001 1.2% 102
# 1000000100 1.1% 102
# 1100000000 1.1% 123
# 1011000000 1.0% 85
# 1010100010 1.0% 24
# 1010101000 1.0% 24
# 1000110000 1.0% 85
# 1001000000 1.0% 84
# rand == 42
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 58.9975
#        x: [ 9.142e-01  7.124e-01  3.087e-02  3.316e-01  1.931e+00
#             1.465e+00]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 11.7% 40
# 1000000000 3.9% 82
# 0001000000 3.7% 42
# 0000010000 3.7% 42
# 0010000000 3.2% 41
# 0000100000 3.1% 41
# 0100000001 2.5% 61
# 0100000100 2.5% 61
# 0001010000 2.3% 44
# 0100000101 1.8% 41
# 1000101000 1.6% 23
# 1010000010 1.6% 23
# 0101000000 1.6% 43
# 0100010000 1.6% 43
# 1000001010 1.4% 42
# 1010100000 1.2% 4
# 0001100000 1.1% 43
# 0010010000 1.1% 43
# 1000010000 1.0% 84
# 1001000000 1.0% 84
# rand == 45
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 65.1355
#        x: [ 1.428e+00  9.367e-01  7.639e-01  1.789e-01  2.103e-01
#             8.838e-01]
#     nfev: 53
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1100001111 3.9% 43
# 0100000101 2.6% 41
# 1100101101 2.1% 24
# 1110000111 2.0% 24
# 1000001010 1.9% 42
# 0000000000 1.7% 40
# 0100000111 1.6% 61
# 0100001101 1.6% 61
# 1101001011 1.5% 25
# 1100011110 1.5% 25
# 1101001111 1.5% 45
# 1100011111 1.4% 45
# 0000001000 1.4% 60
# 0000000010 1.4% 60
# 0110001101 1.3% 102
# 0100100111 1.2% 102
# 0100010110 1.1% 43
# 0101001001 1.1% 43
# 0100001111 1.0% 81
# 1000101000 1.0% 23
# rand == 48
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.8075
#        x: [ 5.933e-01  3.606e-01  6.783e-01  6.526e-01  4.997e-01
#             4.293e-01]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 6.5% 5
# 1101010000 4.5% 47
# 1101110000 3.5% 48
# 1111010000 3.4% 48
# 0101010010 3.0% 25
# 0101011000 2.9% 25
# 1111110000 2.5% 49
# 1100010000 1.6% 85
# 1101000000 1.6% 85
# 0101000000 1.4% 43
# 0100010000 1.4% 43
# 1111000000 1.3% 86
# 0101011010 1.3% 45
# 1100110000 1.2% 86
# 1101011000 1.1% 27
# 1101010010 1.1% 27
# 1101000001 0.8% 65
# 1100010100 0.8% 65
# 0101000001 0.8% 23
# 0111010000 0.8% 46
# rand == 51
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 40.1445
#        x: [ 2.359e+00  4.819e-02  1.634e+00  2.213e+00 -3.095e-01
#            -1.748e-01]
#     nfev: 79
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010000 23.2% 5
# 0101000000 6.7% 43
# 0100010000 6.7% 43
# 1101010000 5.8% 47
# 0000010000 3.2% 42
# 0001010000 3.2% 44
# 0001000000 3.0% 42
# 0101010100 3.0% 25
# 0101010001 2.9% 25
# 0000000000 2.2% 40
# 0101011000 1.8% 25
# 0101010010 1.8% 25
# 0100000000 1.7% 81
# 1100010000 1.5% 85
# 1101000000 1.4% 85
# 0100010001 1.1% 63
# 0101000100 1.1% 63
# 1101010010 1.0% 27
# 1101011000 1.0% 27
# 0100010100 1.0% 23
# rand == 54
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 77.466
#        x: [ 1.624e+00  1.506e+00  1.750e+00  6.051e-01  1.849e-01
#             1.198e-01]
#     nfev: 59
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 2.4% 4
# 1010110000 1.0% 46
# 1011100000 1.0% 46
# 0001100000 0.9% 43
# 1000101000 0.9% 23
# 1010000010 0.9% 23
# 0010010000 0.9% 43
# 0101010000 0.8% 5
# 0010100000 0.7% 42
# 1110000001 0.6% 64
# 1100100100 0.6% 64
# 1100100000 0.6% 84
# 1100001010 0.6% 83
# 1101100000 0.6% 46
# 1110000000 0.6% 84
# 1110010000 0.6% 46
# 1100011000 0.5% 65
# 1101000010 0.5% 65
# 0110010000 0.5% 44
# 1011110000 0.5% 88
# rand == 57
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.4255
#        x: [ 7.551e-01  3.879e-01  1.657e-01  3.313e-01  1.348e+00
#             5.836e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 13.0% 40
# 1000000000 4.8% 82
# 0001000000 4.7% 42
# 0000010000 4.5% 42
# 0100000000 2.8% 81
# 0000100000 1.7% 41
# 0010000000 1.7% 41
# 0001010000 1.6% 44
# 0100000100 1.6% 61
# 0100000001 1.6% 61
# 1010000000 1.5% 43
# 1000010000 1.5% 84
# 1000100000 1.5% 43
# 1001000000 1.5% 84
# 0101000100 1.5% 63
# 0100010001 1.5% 63
# 0000001000 1.4% 60
# 0000000010 1.3% 60
# 1000100010 1.1% 63
# 1010001000 1.1% 63
# rand == 60
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.8975
#        x: [ 3.871e-01  1.955e+00  4.212e-01  3.626e-01 -2.254e-01
#             4.758e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 3.8% 45
# 1111110000 3.3% 49
# 0111110000 3.2% 87
# 1011110000 3.2% 88
# 1101010000 2.6% 47
# 0011110000 2.3% 126
# 1101100000 2.3% 46
# 1110010000 2.3% 46
# 1111100000 2.0% 47
# 1110110000 2.0% 47
# 1101110000 1.9% 48
# 1111010000 1.9% 48
# 0110100000 1.4% 83
# 0111100000 1.4% 85
# 0110110000 1.3% 85
# 1011010000 1.2% 87
# 1001110000 1.2% 87
# 1110000000 1.2% 84
# 1100100000 1.1% 84
# 0101010000 1.0% 5
# rand == 63
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 63.9145
#        x: [ 1.880e+00  1.715e+00  1.488e+00  1.816e-01  5.886e-01
#            -1.465e-02]
#     nfev: 72
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 2.8% 49
# 1101111000 1.3% 28
# 1111010010 1.2% 28
# 1101011010 1.2% 7
# 1100111100 0.9% 46
# 1111110010 0.9% 69
# 1111000011 0.9% 46
# 1111111000 0.9% 69
# 1100001111 0.8% 43
# 1111100001 0.8% 27
# 1110110100 0.8% 27
# 0111000001 0.7% 64
# 0100110100 0.7% 64
# 1100011110 0.7% 25
# 0111010000 0.6% 46
# 0101110000 0.6% 46
# 1110000111 0.6% 24
# 1101001011 0.6% 25
# 1110100101 0.6% 5
# 1100101101 0.6% 24
# rand == 66
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.397
#        x: [ 1.407e+00 -5.591e-02  9.374e-01  9.534e-01  1.776e+00
#            -1.088e-01]
#     nfev: 77
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 6.3% 81
# 0000000000 5.4% 40
# 0001000000 4.8% 42
# 0000010000 4.8% 42
# 0001010000 4.1% 44
# 0100000101 3.0% 41
# 0101000001 3.0% 23
# 0100010100 2.9% 23
# 0100010000 2.2% 43
# 0101000000 2.1% 43
# 0100000001 1.9% 61
# 0100000100 1.9% 61
# 0010000000 1.6% 41
# 0110000000 1.5% 82
# 0100100000 1.5% 82
# 0001000100 1.5% 102
# 0000100000 1.4% 41
# 0001100000 1.4% 43
# 0000010001 1.4% 102
# 0010010000 1.3% 43
# rand == 69
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.213
#        x: [ 1.561e+00  2.584e-01  4.485e-01  9.549e-01  1.047e+00
#             9.460e-01]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 10.0% 81
# 0000000000 9.7% 40
# 0000010000 4.1% 42
# 0100010000 4.1% 43
# 0001000000 4.1% 42
# 0101000000 4.0% 43
# 0101010000 3.8% 5
# 0101010001 2.2% 25
# 0100100000 2.2% 82
# 0101010100 2.2% 25
# 0110000000 2.1% 82
# 0100010001 2.1% 63
# 0101000100 2.0% 63
# 0100000100 1.7% 61
# 0100000001 1.7% 61
# 0001000100 1.7% 102
# 0000010001 1.6% 102
# 0001010000 1.5% 44
# 0010000000 1.5% 41
# 0000100000 1.5% 41
# rand == 72
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.2705
#        x: [ 1.294e+00  1.986e+00  1.652e+00  5.845e-01  5.119e-03
#             2.074e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 25.5% 49
# 1111110001 6.0% 69
# 1111110100 5.9% 69
# 1111110010 4.7% 69
# 1111111000 4.7% 69
# 1011110000 2.1% 88
# 1111110101 1.9% 89
# 1101111000 1.7% 28
# 1111010010 1.7% 28
# 1101011010 1.5% 7
# 1111111010 1.4% 89
# 1111111001 1.0% 89
# 1111110110 1.0% 89
# 1111110011 0.9% 89
# 1101110000 0.9% 48
# 1111010000 0.9% 48
# 1111111100 0.9% 89
# 1110110100 0.9% 27
# 1010100101 0.8% 44
# 1111100001 0.8% 27
# rand == 75
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 52.95
#        x: [ 1.131e+00  3.346e-01  2.253e-01  1.890e+00  4.684e-01
#             6.732e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0101010010 7.0% 25
# 0101011000 6.9% 25
# 0101010000 5.9% 5
# 0101011010 5.8% 45
# 1101010000 4.2% 47
# 0101010110 2.3% 45
# 0101010011 2.3% 45
# 0101011100 2.3% 45
# 0101011001 2.2% 45
# 0101010100 2.0% 25
# 0101011110 2.0% 65
# 0101011011 2.0% 65
# 0101010001 1.9% 25
# 0111010000 1.9% 46
# 0101110000 1.8% 46
# 1101011010 1.6% 7
# 0101111000 1.6% 66
# 0111010010 1.6% 66
# 1101010010 1.5% 27
# 1101011000 1.5% 27
# rand == 78
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.329
#        x: [ 1.211e+00  6.653e-01  5.938e-01  4.556e-01  1.633e+00
#             1.555e+00]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 4.9% 47
# 1110010000 4.3% 46
# 1101100000 4.3% 46
# 1010100101 3.7% 44
# 1110100000 3.0% 45
# 1111100000 2.3% 47
# 1110110000 2.3% 47
# 1101100001 2.0% 26
# 1111010000 2.0% 48
# 1101110000 2.0% 48
# 1110010100 2.0% 26
# 0101010000 1.9% 5
# 0101100000 1.8% 44
# 0110010000 1.8% 44
# 1001010000 1.6% 86
# 0010100101 1.6% 82
# 1111100001 1.4% 27
# 1110110100 1.3% 27
# 0110100000 1.3% 83
# 0110110000 1.1% 85
# rand == 81
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 78.6865
#        x: [ 1.280e+00  8.227e-01  1.509e+00  1.551e+00  3.238e-01
#             8.570e-02]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000101 1.1% 80
# 1000100111 0.8% 103
# 1010001101 0.8% 103
# 0000100101 0.7% 81
# 1100100011 0.7% 84
# 1010101101 0.7% 64
# 0010000101 0.7% 81
# 1110001100 0.7% 84
# 1010100111 0.6% 64
# 0100000100 0.6% 61
# 0100000001 0.6% 61
# 1010101111 0.6% 84
# 0100000101 0.6% 41
# 1000001000 0.6% 62
# 1000000010 0.5% 62
# 0110000001 0.5% 62
# 1001001101 0.5% 144
# 0100100100 0.5% 62
# 1110001110 0.5% 64
# 1110001101 0.5% 64
# rand == 84
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.232
#        x: [ 4.307e-01  1.790e+00  5.643e-01  3.604e-01  4.428e-01
#             4.810e-01]
#     nfev: 58
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101011111 6.5% 47
# 1101001111 2.6% 45
# 1100011111 2.5% 45
# 1101011011 2.4% 27
# 1101011110 2.3% 27
# 1101011010 2.2% 7
# 1101001011 1.8% 25
# 1100011110 1.8% 25
# 0101011111 1.7% 85
# 1101101101 1.6% 26
# 1110010111 1.5% 26
# 1101101111 1.5% 46
# 1100001111 1.5% 43
# 1110011111 1.5% 46
# 1101101011 1.1% 26
# 0101001111 1.1% 83
# 1110011110 1.1% 26
# 1110010110 1.0% 6
# 0100011111 1.0% 83
# 1101101001 1.0% 6
# rand == 87
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 74.233
#        x: [ 3.124e-01  1.699e+00  1.189e+00 -1.216e-01 -3.676e-01
#             3.789e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1011110000 3.1% 88
# 1011111000 2.5% 108
# 1011110010 2.4% 108
# 1001111000 1.7% 67
# 1011010010 1.7% 67
# 1111100001 1.4% 27
# 1110110100 1.4% 27
# 1110111100 1.0% 47
# 1111100011 1.0% 47
# 1111110100 1.0% 69
# 1111110001 1.0% 69
# 1111101001 1.0% 47
# 1110110110 0.9% 47
# 1110010110 0.9% 6
# 1111000011 0.8% 46
# 1111111100 0.8% 89
# 1100111100 0.8% 46
# 1101101001 0.8% 6
# 1111110011 0.7% 89
# 1111010011 0.7% 48
# rand == 90
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 82.4045
#        x: [ 1.237e+00  1.500e+00  8.994e-01  4.280e-01  1.011e-01
#             1.283e+00]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101011010 2.6% 7
# 1101010000 1.9% 47
# 1110010110 1.0% 6
# 1101101001 1.0% 6
# 1111100000 0.9% 47
# 1110110000 0.9% 47
# 1101101000 0.8% 26
# 1110010010 0.8% 26
# 1110101010 0.7% 85
# 1110100100 0.7% 25
# 1110100001 0.6% 25
# 1010011011 0.5% 105
# 1001101110 0.5% 105
# 1101111000 0.5% 28
# 0100001111 0.5% 81
# 1101010101 0.5% 87
# 1111010010 0.5% 28
# 1111110000 0.5% 49
# 1100001111 0.5% 43
# 1101110000 0.4% 48
# rand == 93
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.273
#        x: [ 3.783e-01  1.636e+00 -4.711e-01  3.493e-01  4.246e-01
#             1.114e-02]
#     nfev: 79
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 7.0% 40
# 1010100000 4.6% 4
# 1000000000 4.5% 82
# 1000100000 3.9% 43
# 1010000000 3.9% 43
# 1110100000 3.0% 45
# 0010000000 2.4% 41
# 0000100000 2.4% 41
# 0010100000 1.5% 42
# 1110000000 1.4% 84
# 1111100000 1.4% 47
# 0000001000 1.4% 60
# 1100100000 1.4% 84
# 1110110000 1.3% 47
# 0100000000 1.3% 81
# 0000000010 1.3% 60
# 0000000001 1.0% 60
# 0000000100 1.0% 60
# 1010001000 0.9% 63
# 1000100010 0.9% 63
# rand == 96
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 59.6015
#        x: [ 3.745e-01  1.766e+00  8.039e-01  1.250e+00  4.671e-01
#             5.003e-01]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 24.1% 44
# 0000010000 5.0% 42
# 0001000000 5.0% 42
# 0001000001 3.8% 62
# 0000010100 3.7% 62
# 1001010000 2.8% 86
# 0001110000 2.2% 85
# 0011010000 2.1% 85
# 0100000000 1.9% 81
# 0001100000 1.8% 43
# 0010010000 1.7% 43
# 0001010010 1.4% 64
# 0001011000 1.3% 64
# 0000000001 1.2% 60
# 0000000100 1.2% 60
# 0100010100 1.2% 23
# 0101000001 1.2% 23
# 0101010100 1.1% 25
# 0101010001 1.1% 25
# 1000010000 1.0% 84
# rand == 99
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.905
#        x: [ 1.243e+00 -7.681e-01  4.989e-01 -3.122e-01  1.664e-01
#             9.182e-01]
#     nfev: 76
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 33.0% 49
# 1111100000 5.3% 47
# 1110110000 5.3% 47
# 1111111000 3.2% 69
# 1101110000 3.2% 48
# 1111010000 3.1% 48
# 1111110010 3.1% 69
# 1011110000 3.0% 88
# 1100110000 2.6% 86
# 1111000000 2.6% 86
# 1111110001 2.6% 69
# 1111110100 2.6% 69
# 0111110000 1.0% 87
# 1010110000 0.9% 46
# 1011100000 0.9% 46
# 1110100000 0.8% 45
# 0101110000 0.7% 46
# 0111010000 0.7% 46
# 1111100010 0.6% 67
# 1110111000 0.6% 67
