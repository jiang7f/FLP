# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
# d = [[1, 2], [3, 4], [5, 6]]
# n = 2   # 两个设施点
# m = 3   # 三个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits))
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts[:20]:
    print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
for i in range(3, 100, 3):
  print(f'rand == {i}')
  test(20, 3, np.random.rand(2 * 3))
# Out:
# rand == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.424
#        x: [ 1.327e+00  3.352e-01  1.069e-01  4.560e-01  2.062e+00
#             1.288e+00]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 14.7% 49
# 1111100000 5.2% 47
# 1110110000 5.1% 47
# 1100110000 4.5% 86
# 1111000000 4.5% 86
# 1111010000 4.1% 48
# 1101110000 4.1% 48
# 1110100000 2.4% 45
# 0111110000 2.2% 87
# 1100100000 1.8% 84
# 1110000000 1.7% 84
# 1110010000 1.4% 46
# 1101100000 1.4% 46
# 1010100000 1.2% 4
# 1100000000 1.1% 123
# 1101010000 1.1% 47
# 0111100000 1.1% 85
# 1100010000 1.1% 85
# 0110110000 1.1% 85
# 1101000000 1.1% 85
# rand == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.4365
#        x: [ 1.919e+00  6.358e-01  4.102e-01  3.230e-01  1.632e+00
#             3.969e-01]
#     nfev: 78
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 27.7% 40
# 0000010000 8.8% 42
# 0001000000 8.8% 42
# 0001010000 3.6% 44
# 0010001000 3.2% 101
# 0000100010 3.0% 101
# 0100000000 2.4% 81
# 0100000101 1.6% 41
# 0100010000 1.5% 43
# 0101000000 1.5% 43
# 0000100000 1.4% 41
# 1000000000 1.4% 82
# 0010000000 1.4% 41
# 0001000100 1.3% 102
# 0000010001 1.3% 102
# 0010011000 1.0% 103
# 0001100010 0.9% 103
# 0000001000 0.8% 60
# 0000000010 0.8% 60
# 0000110000 0.7% 83
# rand == 9
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 75.9655
#        x: [ 2.658e-01  9.652e-01  1.996e+00  6.239e-01  1.673e-01
#             8.725e-01]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 4.9% 49
# 1011110000 3.7% 88
# 1110110000 3.6% 47
# 1111100000 3.6% 47
# 1110100000 2.9% 45
# 0111110000 2.4% 87
# 1010110000 2.0% 46
# 1011100000 2.0% 46
# 0110110000 2.0% 85
# 0011110000 2.0% 126
# 0111100000 1.9% 85
# 0110100000 1.4% 83
# 1111110001 1.3% 69
# 1111110100 1.3% 69
# 1100110000 1.2% 86
# 1010100000 1.2% 4
# 1111000000 1.1% 86
# 1011010000 1.1% 87
# 1001110000 1.1% 87
# 1101100000 1.0% 46
# rand == 12
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 79.1415
#        x: [ 6.926e-01  1.809e+00  1.939e+00  6.530e-01  9.062e-01
#             6.932e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 2.9% 45
# 1100100000 1.6% 84
# 1110000000 1.5% 84
# 1111100000 1.5% 47
# 1110110000 1.5% 47
# 1110100001 1.4% 25
# 1110100100 1.4% 25
# 1111000000 1.2% 86
# 1100110000 1.1% 86
# 1101100000 1.1% 46
# 1110010000 1.1% 46
# 1010100000 1.1% 4
# 0110101010 1.0% 203
# 1100000000 1.0% 123
# 1011100000 1.0% 46
# 1111110000 1.0% 49
# 1010110000 0.9% 46
# 0110111000 0.8% 145
# 0000000000 0.8% 40
# 0111100010 0.8% 145
# rand == 15
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 53.9665
#        x: [ 9.073e-01  4.318e-01  5.380e-01  2.106e-02  7.581e-01
#             1.184e+00]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 19.4% 40
# 0000010000 8.7% 42
# 0001000000 8.6% 42
# 0100000000 5.0% 81
# 0000000100 3.5% 60
# 0000000001 3.4% 60
# 0001010000 3.0% 44
# 1000000010 2.0% 62
# 1000001000 2.0% 62
# 0100000100 1.5% 61
# 0100000101 1.5% 41
# 0100000001 1.4% 61
# 1000001010 1.2% 42
# 0101000000 1.1% 43
# 0100010000 1.1% 43
# 1000101000 1.0% 23
# 1010100000 1.0% 4
# 1010000010 1.0% 23
# 1000011000 0.9% 64
# 1001000010 0.9% 64
# rand == 18
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 70.435
#        x: [ 1.017e+00  1.246e+00  7.843e-01  6.272e-01  7.843e-01
#             5.592e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 6.8% 40
# 0001000000 4.1% 42
# 0000010000 4.0% 42
# 0000000100 3.0% 60
# 0000000001 2.9% 60
# 0001010000 2.0% 44
# 0100000000 1.7% 81
# 0000100000 1.5% 41
# 0010000000 1.4% 41
# 0100000101 1.4% 41
# 0000100010 1.0% 101
# 0010001000 1.0% 101
# 0001000001 1.0% 62
# 0000010100 1.0% 62
# 0000010001 1.0% 102
# 0001000100 0.9% 102
# 1000001010 0.9% 42
# 0001100000 0.9% 43
# 0010010000 0.9% 43
# 0101000001 0.9% 23
# rand == 21
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 88.2975
#        x: [ 7.870e-01  1.911e-01 -5.837e-01  7.374e-01  2.354e-02
#             2.040e+00]
#     nfev: 60
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0110100000 3.3% 83
# 1110100000 2.9% 45
# 0011100000 1.4% 84
# 0010110000 1.4% 84
# 1110100010 1.3% 65
# 1110101000 1.3% 65
# 0010110001 1.3% 144
# 0011100100 1.2% 144
# 0011110000 1.1% 126
# 0111110101 1.0% 127
# 1110000000 0.9% 84
# 0111110100 0.9% 107
# 1100100000 0.8% 84
# 1010100000 0.8% 4
# 0111110001 0.8% 107
# 1010000000 0.8% 43
# 1000100000 0.8% 43
# 0110110001 0.7% 105
# 0110110000 0.7% 85
# 0010100000 0.7% 42
# rand == 24
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.514
#        x: [ 9.912e-01  8.073e-01  4.264e-01  9.535e-01  1.203e-01
#             2.080e+00]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 32.5% 40
# 0100000000 17.4% 81
# 1000000000 3.1% 82
# 1000100000 3.0% 43
# 1010000000 3.0% 43
# 0000000001 1.9% 60
# 0000000100 1.8% 60
# 0100110000 1.5% 84
# 1110000000 1.5% 84
# 0111000000 1.5% 84
# 1100100000 1.5% 84
# 1010100000 1.4% 4
# 1100000000 1.1% 123
# 0000000010 1.0% 60
# 0000001000 1.0% 60
# 0100100000 0.8% 82
# 0010000000 0.8% 41
# 0000100000 0.8% 41
# 1110100000 0.8% 45
# 0110000000 0.8% 82
# rand == 27
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 75.3725
#        x: [ 7.580e-01  2.267e-01  1.214e+00  1.268e+00  8.402e-01
#             1.494e-01]
#     nfev: 65
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 1.8% 44
# 0011010000 1.6% 85
# 0001110000 1.5% 85
# 0011110000 1.4% 126
# 1001011000 0.9% 66
# 0001100000 0.8% 43
# 0010010000 0.8% 43
# 1001010010 0.8% 66
# 0011100000 0.7% 84
# 1001111000 0.7% 67
# 0010110000 0.7% 84
# 1011010010 0.7% 67
# 0100010100 0.6% 23
# 1000011000 0.6% 64
# 0100100101 0.6% 42
# 1001000010 0.6% 64
# 0101000001 0.6% 23
# 0110100101 0.6% 43
# 1001101000 0.6% 25
# 1010010010 0.6% 25
# rand == 30
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 74.7605
#        x: [ 1.526e+00  1.730e+00  6.239e-02  1.264e-01  5.747e-01
#             7.779e-01]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1100001111 3.7% 43
# 1100000111 2.2% 63
# 1100001101 2.2% 63
# 1100011110 1.3% 25
# 1101001011 1.3% 25
# 1111001111 1.3% 86
# 1100111111 1.3% 86
# 1100101111 1.0% 44
# 1110001111 0.9% 44
# 1100000011 0.9% 83
# 1100001100 0.8% 83
# 1001001011 0.8% 64
# 1110001011 0.8% 64
# 1000011110 0.8% 64
# 1110000111 0.8% 24
# 1100101110 0.8% 64
# 1100111100 0.8% 46
# 1100001011 0.8% 63
# 1100011101 0.8% 65
# 1100101101 0.8% 24
# rand == 33
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 61.075
#        x: [ 7.774e-01  1.184e+00  7.078e-01  7.835e-01  8.145e-01
#             7.362e-01]
#     nfev: 58
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 10.7% 47
# 0101010000 7.4% 5
# 1001000000 3.8% 84
# 1000010000 3.7% 84
# 1001010000 3.4% 86
# 0001010000 2.0% 44
# 1101010001 2.0% 67
# 1101010100 1.9% 67
# 1101011000 1.5% 27
# 1101010010 1.5% 27
# 1000000000 1.2% 82
# 0101010001 1.2% 25
# 0101010100 1.1% 25
# 0001000000 1.1% 42
# 0000010000 1.0% 42
# 0000011000 1.0% 62
# 0101011000 0.9% 25
# 0101010010 0.9% 25
# 1100010000 0.9% 85
# 0001000010 0.9% 62
# rand == 36
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 67.5525
#        x: [ 5.986e-01  8.798e-01  2.771e-01  3.346e-01  1.881e+00
#             2.071e+00]
#     nfev: 61
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 3.8% 47
# 0101010000 3.7% 5
# 0111010000 2.9% 46
# 0101110000 2.9% 46
# 1111110000 2.4% 49
# 1101110000 2.2% 48
# 1111010000 2.2% 48
# 0101010010 1.7% 25
# 0101011000 1.6% 25
# 0110010000 1.5% 44
# 0101100000 1.5% 44
# 0111110000 1.4% 87
# 1101000000 1.3% 85
# 1100010000 1.3% 85
# 0101111000 1.0% 66
# 0111010010 1.0% 66
# 1000000000 0.9% 82
# 0101000000 0.9% 43
# 1100110000 0.8% 86
# 1111000000 0.8% 86
# rand == 39
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 65.744
#        x: [ 1.609e+00  1.671e+00  6.571e-01  6.443e-01  1.036e-02
#             5.870e-01]
#     nfev: 60
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101100000 2.5% 46
# 1110010000 2.5% 46
# 1110100000 2.1% 45
# 1101101000 1.7% 26
# 1110010010 1.6% 26
# 1101010000 1.4% 47
# 1110000000 1.4% 84
# 1110100100 1.4% 25
# 1100100000 1.4% 84
# 1110100001 1.3% 25
# 1101100001 1.3% 26
# 1110010100 1.3% 26
# 1101010010 1.2% 27
# 1101000000 1.2% 85
# 1101011000 1.2% 27
# 1100010000 1.1% 85
# 1110100101 1.0% 5
# 1110010110 0.9% 6
# 1101011010 0.9% 7
# 1101101001 0.9% 6
# rand == 42
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 56.417
#        x: [ 1.029e+00  2.345e+00 -6.913e-01  2.890e-01  4.923e-01
#             1.685e+00]
#     nfev: 59
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 24.3% 40
# 0000010000 3.7% 42
# 0001000000 3.7% 42
# 1000000010 2.7% 62
# 1000001000 2.7% 62
# 0101000000 2.6% 43
# 0100010000 2.6% 43
# 1000001010 2.3% 42
# 0000001000 1.9% 60
# 0000000010 1.9% 60
# 0010000000 1.7% 41
# 0000100000 1.7% 41
# 0000000001 1.5% 60
# 0100000001 1.5% 61
# 0100000100 1.4% 61
# 0000000100 1.4% 60
# 1000000000 1.3% 82
# 1000100000 1.3% 43
# 1010000000 1.2% 43
# 0001010000 1.1% 44
# rand == 45
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 69.292
#        x: [ 5.356e-01  1.015e+00  2.626e-01  1.095e-01  2.215e-01
#             1.821e+00]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 5.5% 40
# 1000000000 3.0% 82
# 0001000000 1.8% 42
# 0000010000 1.8% 42
# 0100010000 1.7% 43
# 0101000000 1.6% 43
# 0000001000 1.5% 60
# 0000000010 1.5% 60
# 0001001000 1.2% 62
# 0000000001 1.1% 60
# 0000010010 1.1% 62
# 0000000100 1.0% 60
# 0001010000 0.9% 44
# 0010100000 0.9% 42
# 0000100000 0.9% 41
# 0010000000 0.9% 41
# 1000000100 0.7% 102
# 1000000001 0.7% 102
# 0101000001 0.7% 23
# 1000100000 0.7% 43
# rand == 48
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.7025
#        x: [ 1.069e+00  4.756e-01  4.300e-01  9.494e-01  9.999e-01
#             1.283e+00]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 24.6% 40
# 1000001010 4.8% 42
# 0000010000 3.4% 42
# 0001000000 3.2% 42
# 1000000000 3.2% 82
# 0000010001 3.1% 102
# 0001000100 3.1% 102
# 0010000000 2.5% 41
# 0000100000 2.4% 41
# 1000000010 1.6% 62
# 1000001000 1.5% 62
# 1000101000 1.5% 23
# 1010000010 1.4% 23
# 0000001000 1.2% 60
# 0000000010 1.2% 60
# 0000001010 1.1% 80
# 0000000001 1.1% 60
# 0000000100 1.0% 60
# 0100000000 0.9% 81
# 0010001000 0.8% 101
# rand == 51
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.2155
#        x: [ 1.018e+00  1.285e-01  3.818e-01  1.682e-02  1.146e-01
#             3.396e-01]
#     nfev: 69
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 20.2% 40
# 0000000010 6.1% 60
# 0000000001 6.0% 60
# 0000001000 6.0% 60
# 0000000100 5.9% 60
# 0010000000 2.2% 41
# 0000100000 2.2% 41
# 0000000011 1.9% 80
# 0000001100 1.8% 80
# 0000001001 1.8% 80
# 0000000110 1.7% 80
# 1000000000 1.7% 82
# 0000010000 1.6% 42
# 0001000000 1.6% 42
# 0100000000 1.6% 81
# 0000001010 1.5% 80
# 0000000101 1.4% 80
# 0000100001 0.8% 61
# 0010000100 0.8% 61
# 0010000010 0.8% 61
# rand == 54
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 68.657
#        x: [ 1.960e-01 -2.541e-01  1.915e+00 -3.774e-01  9.543e-02
#             1.177e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 12.4% 49
# 1111110100 4.1% 69
# 1111110001 4.1% 69
# 1111110010 4.0% 69
# 1111111000 3.9% 69
# 1101110000 2.8% 48
# 1111010000 2.7% 48
# 0111110000 2.6% 87
# 1111100000 2.2% 47
# 1110110000 2.2% 47
# 1011110000 1.7% 88
# 1111111001 1.4% 89
# 1111110011 1.3% 89
# 1111111100 1.3% 89
# 1101111000 1.3% 28
# 1111110110 1.3% 89
# 1111010010 1.2% 28
# 0111110100 1.0% 107
# 1111010001 1.0% 68
# 1101110100 1.0% 68
# rand == 57
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.237
#        x: [ 4.886e-02  1.561e+00  1.871e-01  1.737e+00  6.008e-01
#             3.142e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 10.7% 44
# 0101010000 8.0% 5
# 0000010000 4.2% 42
# 0101000000 4.1% 43
# 0100010000 4.0% 43
# 0001000000 4.0% 42
# 0100000000 3.0% 81
# 0000000000 2.7% 40
# 1001010000 2.7% 86
# 0001010100 2.6% 104
# 0001010001 2.5% 104
# 1101010000 2.1% 47
# 1001011000 0.9% 66
# 1001010010 0.9% 66
# 0110010000 0.9% 44
# 0101100000 0.9% 44
# 0101010100 0.9% 25
# 0101010001 0.9% 25
# 1011010000 0.8% 87
# 0001000100 0.8% 102
# rand == 60
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 80.179
#        x: [ 9.905e-01  2.141e+00  1.394e+00  7.631e-01  1.349e+00
#             1.604e-01]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0001010000 2.0% 44
# 0001011000 1.0% 64
# 0001010010 1.0% 64
# 1001011000 0.9% 66
# 1001010010 0.9% 66
# 0000000000 0.9% 40
# 0001011010 0.9% 84
# 0000010000 0.9% 42
# 0001110000 0.8% 85
# 0011010000 0.8% 85
# 0001111000 0.8% 105
# 0011010010 0.8% 105
# 0001000000 0.8% 42
# 1000110000 0.7% 85
# 0101000000 0.7% 43
# 1011000000 0.7% 85
# 0100010000 0.7% 43
# 0000010100 0.7% 62
# 0010010000 0.7% 43
# 0001000001 0.7% 62
# rand == 63
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 66.6685
#        x: [ 7.485e-01  1.777e+00  2.067e+00  6.086e-01  4.356e-01
#             1.881e+00]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 3.4% 4
# 1111110000 3.0% 49
# 1111100000 2.4% 47
# 1110110000 2.4% 47
# 1110100101 2.0% 5
# 1101110000 1.6% 48
# 1111010000 1.5% 48
# 1010110000 1.5% 46
# 1011100000 1.5% 46
# 1011100001 1.4% 66
# 1010110100 1.4% 66
# 1110100100 1.3% 25
# 1110100001 1.3% 25
# 1101100000 1.2% 46
# 1110010000 1.1% 46
# 0000001010 1.1% 80
# 1010010000 1.1% 45
# 1001100000 1.1% 45
# 1101010000 1.0% 47
# 1010100001 1.0% 24
# rand == 66
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 65.764
#        x: [-6.098e-01  1.917e+00 -7.615e-01 -5.891e-01  6.163e-01
#             6.351e-01]
#     nfev: 73
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 4.1% 40
# 0100000000 2.7% 81
# 1010100000 2.1% 4
# 1000000000 2.0% 82
# 0010000000 1.7% 41
# 0000100000 1.6% 41
# 0101010000 1.5% 5
# 0001000000 1.5% 42
# 0001100000 1.5% 43
# 0000010000 1.5% 42
# 0010010000 1.4% 43
# 0001010000 1.3% 44
# 1000101000 1.2% 23
# 1010000010 1.1% 23
# 1100000000 1.0% 123
# 0000000010 0.9% 60
# 0000001000 0.9% 60
# 0000000001 0.9% 60
# 0101000001 0.8% 23
# 0100010100 0.8% 23
# rand == 69
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 60.701
#        x: [ 1.540e+00  7.232e-01  7.337e-01  1.456e-01  3.048e-01
#             6.096e-01]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 18.3% 49
# 1110110000 7.7% 47
# 1111100000 7.7% 47
# 1010100000 2.6% 4
# 0111110000 2.3% 87
# 1111100001 2.2% 27
# 1110110100 2.2% 27
# 1100110000 1.8% 86
# 1110100000 1.8% 45
# 1111000000 1.7% 86
# 1010110000 1.6% 46
# 1011100000 1.5% 46
# 1111010010 1.1% 28
# 1101111000 1.0% 28
# 1111000010 1.0% 66
# 1100111000 1.0% 66
# 0111110010 0.9% 147
# 0111010000 0.9% 46
# 0111111000 0.9% 147
# 0101110000 0.9% 46
# rand == 72
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.754
#        x: [-1.464e-02  2.285e+00 -2.656e-01  2.377e-01  2.124e-01
#             1.840e+00]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1111110000 3.0% 49
# 1011110000 3.0% 88
# 1111100000 2.5% 47
# 1110110000 2.4% 47
# 1110110100 2.1% 27
# 1111100001 2.0% 27
# 1110010000 2.0% 46
# 1101100000 2.0% 46
# 1101110000 2.0% 48
# 1111010000 1.9% 48
# 1110100100 1.7% 25
# 1110100001 1.7% 25
# 0111110000 1.7% 87
# 0011110000 1.6% 126
# 1010100000 1.6% 4
# 1001110000 1.5% 87
# 1011010000 1.5% 87
# 1101010000 1.4% 47
# 1101100001 1.4% 26
# 1110010100 1.4% 26
# rand == 75
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 79.978
#        x: [ 1.096e+00  1.977e+00  1.578e+00  4.789e-01  5.502e-01
#             3.587e-01]
#     nfev: 76
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1000001000 1.4% 62
# 1000000010 1.3% 62
# 0000000000 1.2% 40
# 1101001100 1.0% 85
# 1100000010 0.9% 103
# 1100010011 0.9% 85
# 1010001000 0.9% 63
# 1000100010 0.9% 63
# 1100001000 0.9% 103
# 1100011011 0.9% 65
# 1100001110 0.8% 63
# 1100001010 0.8% 83
# 1101001110 0.8% 65
# 1100001011 0.8% 63
# 1000001010 0.8% 42
# 0100000000 0.8% 81
# 1100001100 0.8% 83
# 1100000011 0.8% 83
# 1010101010 0.7% 44
# 1000000000 0.6% 82
# rand == 78
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 51.9455
#        x: [ 1.701e+00  9.282e-01  5.153e-01  4.564e-01  5.555e-01
#             5.455e-01]
#     nfev: 63
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1110100000 7.1% 45
# 1110100001 2.7% 25
# 1110100100 2.6% 25
# 1101010000 2.5% 47
# 0110010100 1.8% 24
# 1001100000 1.8% 45
# 1010100001 1.8% 24
# 1010100100 1.8% 24
# 1010010000 1.7% 45
# 1110100101 1.7% 5
# 0101100001 1.7% 24
# 0101100000 1.7% 44
# 0110010000 1.6% 44
# 1110010000 1.6% 46
# 1010010010 1.5% 25
# 1001101000 1.5% 25
# 1101100000 1.5% 46
# 1010100000 1.4% 4
# 0001100000 1.3% 43
# 0010010000 1.3% 43
# rand == 81
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 71.176
#        x: [ 1.673e+00  1.348e+00  1.954e+00  3.538e-01  1.542e-01
#             3.702e-02]
#     nfev: 71
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1100110000 4.1% 86
# 1111000000 4.1% 86
# 1101100000 3.5% 46
# 1110010000 3.5% 46
# 0011110000 3.3% 126
# 1111110000 3.0% 49
# 0110100000 2.9% 83
# 0000000000 2.8% 40
# 1011100000 2.5% 46
# 1010110000 2.4% 46
# 0111010000 2.1% 46
# 0101110000 2.1% 46
# 0100000000 1.8% 81
# 1001010000 1.7% 86
# 1000000000 1.6% 82
# 1011000000 1.6% 85
# 1000110000 1.5% 85
# 0101010000 1.4% 5
# 1001000000 1.4% 84
# 1000010000 1.4% 84
# rand == 84
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 79.408
#        x: [ 6.486e-01  7.527e-01  1.935e+00  2.847e-01  2.613e-01
#             3.720e-01]
#     nfev: 66
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0110101111 1.8% 163
# 1101101111 1.3% 46
# 1110011111 1.3% 46
# 1110101111 1.3% 45
# 1110001111 1.2% 44
# 0100000101 1.2% 41
# 1100101111 1.1% 44
# 1001101011 0.8% 65
# 1010011110 0.8% 65
# 1100011111 0.8% 45
# 1101001111 0.7% 45
# 0110100111 0.7% 103
# 0110101101 0.7% 103
# 0000000000 0.7% 40
# 0110100101 0.7% 43
# 1110101101 0.6% 25
# 1110100111 0.6% 25
# 1010001110 0.6% 63
# 1100100111 0.6% 64
# 0100101101 0.6% 62
# rand == 87
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.1625
#        x: [ 4.366e-01  1.941e+00  6.235e-01  5.165e-01  8.952e-01
#             2.758e-01]
#     nfev: 79
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000001 3.6% 60
# 0000000100 3.4% 60
# 0100000000 3.3% 81
# 0001000000 2.1% 42
# 0000010000 2.0% 42
# 0000000000 1.4% 40
# 0000100100 1.4% 61
# 0010000001 1.4% 61
# 0000100001 1.3% 61
# 0010000100 1.3% 61
# 0100000101 1.2% 41
# 0001000001 1.2% 62
# 0000000011 1.1% 80
# 0000010100 1.1% 62
# 0000001100 1.1% 80
# 0000000110 1.0% 80
# 0110000000 0.9% 82
# 0010010000 0.9% 43
# 0000010010 0.9% 62
# 0001100000 0.9% 43
# rand == 90
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 57.09
#        x: [ 6.264e-01  8.785e-01  6.645e-01  2.280e-02  4.316e-01
#             1.810e-01]
#     nfev: 70
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 28.4% 40
# 0100000000 6.6% 81
# 0010000000 4.7% 41
# 0000100000 4.6% 41
# 1000100000 3.7% 43
# 1010000000 3.7% 43
# 1000000000 2.8% 82
# 1010100000 2.3% 4
# 0101000000 2.1% 43
# 0100010000 2.0% 43
# 0000010000 1.5% 42
# 0001000000 1.4% 42
# 1111000000 1.3% 86
# 1100110000 1.3% 86
# 0000000010 1.2% 60
# 0000000001 1.2% 60
# 0000001000 1.2% 60
# 0000000100 1.1% 60
# 0100100000 1.0% 82
# 0110000000 0.9% 82
# rand == 93
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 62.81
#        x: [ 6.295e-01  1.158e+00  4.831e-01  2.025e+00  5.058e-01
#             1.283e+00]
#     nfev: 75
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1101010000 9.4% 47
# 1001010000 3.6% 86
# 1101110000 3.4% 48
# 1111010000 3.3% 48
# 0111110000 3.1% 87
# 0101010000 2.9% 5
# 0111010000 2.0% 46
# 0101110000 2.0% 46
# 1100010000 1.8% 85
# 1101000000 1.7% 85
# 1101011000 1.7% 27
# 1101010010 1.6% 27
# 0011110000 1.6% 126
# 1011010000 1.5% 87
# 1001110000 1.5% 87
# 1001000000 1.2% 84
# 1000010000 1.2% 84
# 0101000000 1.1% 43
# 1111110000 1.1% 49
# 0100010000 1.1% 43
# rand == 96
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 72.7665
#        x: [-5.216e-02  1.195e+00 -8.101e-02  1.549e+00 -1.484e-01
#             1.719e+00]
#     nfev: 74
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0100000000 10.8% 81
# 0000000000 7.1% 40
# 0110000000 3.7% 82
# 0100100000 3.6% 82
# 0100001000 2.6% 101
# 0100000010 2.6% 101
# 0010000000 2.4% 41
# 0000100000 2.2% 41
# 0100000100 2.0% 61
# 0100000001 1.9% 61
# 0000000100 1.8% 60
# 0000000001 1.8% 60
# 0000001000 1.6% 60
# 0000000010 1.6% 60
# 0110100000 1.3% 83
# 0100010000 1.0% 43
# 0111000000 1.0% 84
# 0101000000 1.0% 43
# 0100110000 1.0% 84
# 1110100000 1.0% 45
# rand == 99
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 50.928
#        x: [ 1.514e+00  1.453e+00  8.984e-01  9.315e-01  2.027e+00
#             1.877e+00]
#     nfev: 64
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 0000000000 44.7% 40
# 0010000000 7.3% 41
# 0000100000 7.3% 41
# 1000000000 5.2% 82
# 0000010000 3.6% 42
# 0001000000 3.6% 42
# 0000001000 3.4% 60
# 0000000010 3.4% 60
# 0000000001 1.7% 60
# 0000000100 1.7% 60
# 0100000000 1.0% 81
# 0010100000 0.9% 42
# 0010010000 0.6% 43
# 0001000100 0.6% 102
# 0001100000 0.6% 43
# 0000010001 0.5% 102
# 0000100010 0.5% 101
# 1000001000 0.5% 62
# 0010001000 0.5% 101
# 1000000010 0.5% 62
