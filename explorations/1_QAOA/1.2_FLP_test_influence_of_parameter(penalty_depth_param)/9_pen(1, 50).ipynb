# %%
import networkx as nx
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit_aer import Aer
from qiskit.circuit import Parameter
from qiskit.visualization import plot_histogram

import numpy as np
from scipy.optimize import minimize

# %%
# dij需求i到设施j的成本
d = [[1, 2], [1, 2]]
n = 2   # 两个设施点
m = 2   # 两个需求点
num_qubits = n + 2 * n * m

# gi设施i的建设成本
g = [2, 1]

# %%
penalty = 25
depth = 6
params = np.ones(depth * 2)

# %%
# dtype=np.complex128
def add_in_target(num_qubits, target_qubit, gate=np.array([[1, 0],[0, -1]])):
    H = np.eye(2 ** (target_qubit))
    H = np.kron(H, gate)
    H = np.kron(H, np.eye(2 ** (num_qubits - 1 - target_qubit)))
    return H


def generate_Hp(n, m, d, g):
    # 初始化 Hp 矩阵为零矩阵
    # print(num_qubits)
    Hp = np.zeros((2**num_qubits, 2**num_qubits))
    for i in range(m):
        for j in range(n):
            Hp += d[i][j] * (add_in_target(num_qubits, n * (1 + i) + j) - np.eye(2**num_qubits)) / 2
    
    for j in range(n):
        Hp +=  g[j] * (add_in_target(num_qubits, j)- np.eye(2**num_qubits)) / 2

    for i in range(m):
        Ht = np.zeros((2**num_qubits, 2**num_qubits))
        for j in range(n):
            Ht += (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2
        Ht -= np.eye(2**num_qubits)
        Hp += -penalty * Ht @ Ht
    
    for i in range(m):
        for j in range(n):
            Ht = (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, n * (1 + m + i) + j)) / 2 + (np.eye(2**num_qubits) - add_in_target(num_qubits, j)) / 2
            Hp += -penalty * Ht @ Ht

    return Hp

# %%
from scipy.linalg import expm
def build_circ(n, m, d, g, params):
  qc = QuantumCircuit(num_qubits)
  beta = params[:depth + 1]
  gamma = params[depth:]
  for i in range(num_qubits):
    qc.h(i)
  for dp in range(depth):
    qc.unitary(expm(-1j * gamma[dp] * generate_Hp(n, m, d, g)), range(num_qubits))
    for i in range(num_qubits):
      qc.rx(beta[dp], i)
  qc.measure_all()
  return qc

# %%
def cost_function(x):
  num = [int(char) for char in x]
  C = 0
  for i in range(m):
    for j in range(n):
      C += d[i][j] * num[n * (1 + i) + j]
      
  for j in range(n):
    C += g[j] * num[j]

  for i in range(m):
    t = 0
    for j in range(n):
      t += num[n * (1 + i) + j]
    C += penalty * (t - 1)**2

  for i in range(m):
    for j in range(n):
      C += penalty * (num[n * (1 + i) + j] + num[n * (1 + m + i) + j] - num[j]) ** 2
  return C

def compute_expectation(counts):
  EV = 0
  total_count = 0
  for x, count in counts.items():
    C = cost_function(x)
    EV += C*count
    total_count += count

  return EV/total_count


def expectation_from_sample(shots = 2000):
  backend = Aer.get_backend('qasm_simulator')
  backend.shots = shots

  def execute_circ(theta):
    qc = build_circ(n, m, d, g, theta)
    counts = backend.run(qc, seed_simulator=10, shots=shots).result().get_counts()
    return compute_expectation(counts)
  
  return execute_circ

# %%
result_list=[]

# %%
from numpy.lib.utils import source
from scipy.optimize import minimize
import numpy as np
# 初始化迭代计数器
iteration_count = 0
def test(pen, dep, par):
  global penalty, depth, params, iteration_count
  iteration_count = 0
  penalty = pen
  depth = dep
  params = par
  expectation = expectation_from_sample()
  def callback(x):
      global iteration_count
      iteration_count += 1
      if iteration_count % 10 == 0:
          print(f"Iteration {iteration_count}, Result: {expectation(x)}")
  # 设定最大迭代次数
  max_iterations = 1000

  # 使用 COBYLA 方法进行最小化，并设置 callback 函数
  res = minimize(expectation, params, method='COBYLA', options={'maxiter': max_iterations})
  # 输出最终结果
  print("Final Result:", res)
  backend = Aer.get_backend('aer_simulator')
  backend.shots = 100000

  shots=100000
  qc_res = build_circ(n, m, d, g, params=res.x)

  counts = backend.run(qc_res, seed_simulator=10, shots = shots).result().get_counts()
  # plot_histogram(counts)
  sorted_counts = sorted(counts, key=counts.get, reverse=True)
  print("\n----------------- Full result ---------------------")
  print("selection\t\tprobability\tvalue")
  print("---------------------------------------------------")
  for x in sorted_counts:
    if x == '1010100000':
      result_list.append(counts[x] / shots * 100)
      print(x, "{:.1f}%".format(counts[x] / shots * 100), cost_function(x))

# %%
import time
times = []

for i in range(1, 50):
    print(f'pen == {i}')
    start_time = time.time()  # 记录开始时间
    test(i, 5, np.full(5 * 2, np.pi/3))
    end_time = time.time()  # 记录结束时间
    elapsed_time = end_time - start_time  # 计算执行时间
    times.append(elapsed_time)  # 将执行时间添加到列表中

print("Execution times:", times)
# Out:
# pen == 1
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 7.9715
#        x: [ 7.309e-01  1.040e+00  1.150e+00  2.084e+00  6.178e-01
#             1.016e+00  2.232e+00  6.171e-01  1.376e+00  1.307e+00]
#     nfev: 113
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.4% 4
# pen == 2
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 13.4275
#        x: [ 9.996e-01  1.066e+00  1.659e+00  1.026e+00  1.344e+00
#             2.088e+00  9.910e-01  9.742e-01  1.010e+00  2.043e+00]
#     nfev: 112
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.0% 4
# pen == 3
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 9.2885
#        x: [ 2.086e+00  1.521e+00  2.125e+00  1.039e+00  1.013e+00
#             9.882e-01  9.806e-01  9.676e-01  1.009e+00  9.666e-01]
#     nfev: 105
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.6% 4
# pen == 4
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 18.356
#        x: [ 7.027e-01  2.163e+00  7.054e-01  6.489e-01  4.996e-01
#             6.722e-01  9.645e-01  7.313e-01  2.327e+00  7.996e-01]
#     nfev: 106
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.1% 4
# pen == 5
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 24.093
#        x: [ 9.909e-01  1.023e+00  1.040e+00  7.677e-01  1.147e+00
#             1.057e+00  1.061e+00  2.071e+00  1.038e+00  1.057e+00]
#     nfev: 110
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.2% 4
# pen == 6
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 15.853
#        x: [ 2.099e+00  1.038e+00  2.056e+00  1.073e+00  1.029e+00
#             1.054e+00  2.038e+00  2.054e+00  1.058e+00  1.055e+00]
#     nfev: 106
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.0% 4
# pen == 7
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 31.197
#        x: [ 2.018e+00  1.812e+00  9.936e-01  9.913e-01  8.563e-01
#             1.517e+00  1.258e+00  2.050e+00  1.027e+00  9.776e-01]
#     nfev: 100
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.5% 4
# pen == 8
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun:
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.7% 4
# pen == 22
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 64.954
#        x: [ 1.292e+00  2.286e+00  7.121e-01  9.022e-01  6.227e-01
#             5.540e-01  6.802e-01  8.616e-01  6.052e-01  7.137e-01]
#     nfev: 120
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.6% 4
# pen == 23
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 84.0725
#        x: [ 6.758e-01  7.269e-01  5.888e-01  8.962e-01  8.736e-01
#             2.191e+00  3.821e-01  2.343e+00  2.044e+00  2.014e+00]
#     nfev: 118
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.6% 4
# pen == 24
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 73.9585
#        x: [ 1.761e+00  1.047e+00  2.167e+00  1.314e+00  9.936e-01
#             1.026e+00  2.274e+00  1.050e+00  1.048e+00  1.294e+00]
#     nfev: 111
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.7% 4
# pen == 25
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 97.3485
#        x: [ 1.968e+00  2.212e+00  9.928e-01  9.996e-01  9.983e-01
#             1.145e+00  1.026e+00  1.619e+00  1.064e+00  1.011e+00]
#     nfev: 104
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.6% 4
# pen == 26
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 92.575
#        x: [ 1.287e+00  7.294e-01  1.655e+00  9.864e-01  1.354e+00
#             2.047e+00  1.042e+00  1.034e+00  1.041e+00  2.304e+00]
#     nfev: 105
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.5% 4
# pen == 27
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 96.2705
#        x: [ 2.131e+00  6.956e-01  2.165e+00  7.536e-01  9.451e-01
#             9.328e-01  9.188e-01  1.035e+00  8.598e-01  9.031e-01]
#     nfev: 104
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.2% 4
# pen == 28
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 82.943
#        x: [ 8.005e-01  2.194e+00  6.569e-01  8.112e-01  5.377e-01
#             5.685e-01  1.015e+00  6.457e-01  6.657e-01  1.020e+00]
#     nfev: 131
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.1% 4
# pen == 29
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 115.904
#        x: [ 1.234e+00  8.797e-01  1.044e+00  1.043e+00  9.777e-01
#             2.047e+00  1.076e+00  9.268e-01  1.046e+00  1.047e+00]
#     nfev: 94
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.4% 4
# pen == 30
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 73.7335
#        x: [ 1.815e+00  1.116e+00  2.095e+00  1.308e+00  1.054e+00
#             1.271e+00  2.043e+00  1.048e+00  1.044e+00  1.049e+00]
#     nfev: 108
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.5% 4
# pen == 31
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 84.9945
#        x: [ 2.146e+00  2.200e+00  5.305e-01  6.445e-01  6.341e-01
#             6.134e-01  2.302e+00  9.499e-01  7.403e-01  9.559e-01]
#     nfev: 111
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 2.6% 4
# pen == 32
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 85.0905
#        x: [ 1.157e+00  4.283e-01  2.211e+00  7.530e-01  5.047e-01
#             1.685e+00  1.159e+00  1.302e+00 -7.338e-04  3.685e-01]
#     nfev: 111
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 11.0% 4
# pen == 33
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 88.85
#        x: [ 2.007e+00  1.042e+00  1.780e+00  1.129e+00  1.028e+00
#             1.038e+00  1.029e+00  1.050e+00  1.034e+00  1.037e+00]
#     nfev: 117
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 16.1% 4
# pen == 34
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 104.748
#        x: [ 1.563e+00  2.051e+00  1.001e+00  1.030e+00  9.826e-01
#             2.037e+00  2.052e+00  9.044e-01  1.031e+00  7.985e-01]
#     nfev: 112
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 3.4% 4
# pen == 35
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun:
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 11.9% 4
# pen == 49
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 182.1695
#        x: [ 1.993e+00  1.787e+00  9.886e-01  9.940e-01  9.237e-01
#             9.885e-01  9.682e-01  1.059e+00  2.050e+00  1.016e+00]
#     nfev: 126
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.2% 4
# Execution times: [139.82714557647705, 138.39476346969604, 125.95471239089966, 129.97510361671448, 137.78068780899048, 129.31030249595642, 123.21904563903809, 138.51092743873596, 154.0806062221527, 157.56743955612183, 141.5409095287323, 136.9029619693756, 131.33419013023376, 143.0176384449005, 103.33595561981201, 153.01337385177612, 148.19933819770813, 138.08952617645264, 162.40303993225098, 136.2314920425415, 138.35165524482727, 152.42062735557556, 150.88133668899536, 150.67244863510132, 140.98558712005615, 137.7394163608551, 110.06708693504333, 130.4494993686676, 93.52331781387329, 105.72023510932922, 109.92680048942566, 106.46941709518433, 115.65557217597961, 107.56619334220886, 94.12649631500244, 104.5829565525055, 105.27698683738708, 106.33110904693604, 121.83455967903137, 107.57522797584534, 106.54238843917847, 105.96604418754578, 104.46582651138306, 112.05604362487793, 98.3416588306427, 125.2279405593872, 101.38232517242432, 101.0153431892395, 118.35214328765869]

# %%
times
# Out:
# [139.82714557647705,
#  138.39476346969604,
#  125.95471239089966,
#  129.97510361671448,
#  137.78068780899048,
#  129.31030249595642,
#  123.21904563903809,
#  138.51092743873596,
#  154.0806062221527,
#  157.56743955612183,
#  141.5409095287323,
#  136.9029619693756,
#  131.33419013023376,
#  143.0176384449005,
#  103.33595561981201,
#  153.01337385177612,
#  148.19933819770813,
#  138.08952617645264,
#  162.40303993225098,
#  136.2314920425415,
#  138.35165524482727,
#  152.42062735557556,
#  150.88133668899536,
#  150.67244863510132,
#  140.98558712005615,
#  137.7394163608551,
#  110.06708693504333,
#  130.4494993686676,
#  93.52331781387329,
#  105.72023510932922,
#  109.92680048942566,
#  106.46941709518433,
#  115.65557217597961,
#  107.56619334220886,
#  94.12649631500244,
#  104.5829565525055,
#  105.27698683738708,
#  106.33110904693604,
#  121.83455967903137,
#  107.57522797584534,
#  106.54238843917847,
#  105.96604418754578,
#  104.46582651138306,
#  112.05604362487793,
#  98.3416588306427,
#  125.2279405593872,
#  101.38232517242432,
#  101.0153431892395,
#  118.35214328765869]

# %%
result_list
# Out:
# [0.387,
#  0.029,
#  0.555,
#  0.14200000000000002,
#  0.203,
#  0.015,
#  0.461,
#  0.027,
#  0.40800000000000003,
#  8.346,
#  0.16199999999999998,
#  0.005,
#  0.16999999999999998,
#  0.395,
#  0.496,
#  0.08,
#  3.418,
#  2.779,
#  1.075,
#  17.393,
#  0.6709999999999999,
#  0.5660000000000001,
#  0.641,
#  0.655,
#  0.5910000000000001,
#  0.498,
#  0.232,
#  0.095,
#  0.414,
#  0.518,
#  2.6229999999999998,
#  11.018,
#  16.144,
#  3.3550000000000004,
#  0.393,
#  0.06,
#  0.781,
#  0.03,
#  0.063,
#  0.318,
#  0.061,
#  8.769,
#  0.073,
#  2.703,
#  0.005,
#  5.833,
#  0.015,
#  11.940000000000001,
#  0.156]

# %%
times
# Out:
# [139.82714557647705,
#  138.39476346969604,
#  125.95471239089966,
#  129.97510361671448,
#  137.78068780899048,
#  129.31030249595642,
#  123.21904563903809,
#  138.51092743873596,
#  154.0806062221527,
#  157.56743955612183,
#  141.5409095287323,
#  136.9029619693756,
#  131.33419013023376,
#  143.0176384449005,
#  103.33595561981201,
#  153.01337385177612,
#  148.19933819770813,
#  138.08952617645264,
#  162.40303993225098,
#  136.2314920425415,
#  138.35165524482727,
#  152.42062735557556,
#  150.88133668899536,
#  150.67244863510132,
#  140.98558712005615,
#  137.7394163608551,
#  110.06708693504333,
#  130.4494993686676,
#  93.52331781387329,
#  105.72023510932922,
#  109.92680048942566,
#  106.46941709518433,
#  115.65557217597961,
#  107.56619334220886,
#  94.12649631500244,
#  104.5829565525055,
#  105.27698683738708,
#  106.33110904693604,
#  121.83455967903137,
#  107.57522797584534,
#  106.54238843917847,
#  105.96604418754578,
#  104.46582651138306,
#  112.05604362487793,
#  98.3416588306427,
#  125.2279405593872,
#  101.38232517242432,
#  101.0153431892395,
#  118.35214328765869]

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# x轴数据
x = range(1, 50)

# 绘制折线图
plt.rcParams['font.family'] = 'Times New Roman'  # 设置字体
plt.figure(figsize=(5, 3))  # 设置图形尺寸
plt.grid(True, linestyle='--', alpha=0.5)  # 显示网格线

# 绘制折线图
plt.plot(x, result_list, marker='o', color='steelblue', linewidth=2, markersize=6)

# 设置标题和标签
plt.xlabel('number of circuit layers', fontsize=14)
plt.ylabel('optimal solution probability', fontsize=14)

# 设置刻度字体
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# 调整网格线显示顺序
plt.gca().set_axisbelow(True)

# 修改边框颜色

# 设置 y 轴范围和百分比刻度
plt.gca().yaxis.set_major_formatter(mticker.PercentFormatter(xmax=100))

# 显示图形
plt.tight_layout()
plt.savefig("9_1_50_p2.svg", format="svg")  # 保存图形
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# x轴数据
x = range(1, 50)

# 绘制折线图
plt.rcParams['font.family'] = 'Times New Roman'  # 设置字体
plt.figure(figsize=(5, 3))  # 设置图形尺寸
plt.grid(True, linestyle='--', alpha=0.5)  # 显示网格线

# 绘制折线图
plt.plot(x, times, marker='o', color='darkorange', linewidth=2, markersize=6)

# 设置标题和标签
plt.xlabel('number of circuit layers', fontsize=14)
plt.ylabel('execution time (s)', fontsize=14)

# 设置刻度字体
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# 调整网格线显示顺序
plt.gca().set_axisbelow(True)


# 设置 y 轴范围和百分比刻度
# plt.ylim(0, 10)
# plt.gca().yaxis.set_major_formatter(mticker.PercentFormatter(xmax=100))

# 显示图形
plt.tight_layout()
plt.savefig("9_1_50_s2.svg", format="svg")  # 保存图形
plt.show()

# %%
test(45, 5, np.full(10, np.pi/3))
# Out:
# Final Result:  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 134.429
#        x: [ 2.045e+00  1.359e+00  2.170e+00  9.224e-01  1.145e+00
#             1.055e+00  1.053e+00  1.054e+00  1.046e+00  1.047e+00]
#     nfev: 102
#    maxcv: 0.0
#
# ----------------- Full result ---------------------
# selection		probability	value
# ---------------------------------------------------
# 1010100000 0.0% 4
