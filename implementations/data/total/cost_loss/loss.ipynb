# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

commute = pd.read_csv('commute.csv')
commute.drop(columns=['method'], inplace=True)
penalty = pd.read_csv('penalty.csv')
penalty.drop(columns=['method'], inplace=True)
cyclic = pd.read_csv('cyclic.csv')
cyclic.drop(columns=['method'], inplace=True)
HEA = pd.read_csv('HEA.csv')
HEA.drop(columns=['method'], inplace=True)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl


scale = 1.05
fig= plt.figure(figsize=(25*scale, 12*scale))
mpl.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Times New Roman',
    'font.size': 65,
    'axes.unicode_minus': False,
    'mathtext.fontset': 'custom',
    'mathtext.rm': 'Times New Roman',
    'mathtext.it': 'Times New Roman:italic',
    'mathtext.bf': 'Times New Roman:bold',
    'axes.linewidth': 5,
    'xtick.major.size': 20,
    'xtick.major.width': 10,
    'ytick.minor.size': 10,
    'ytick.minor.width': 3,
    'ytick.major.size': 20,
    'ytick.major.width': 5,
    "lines.markersize" : 35,
    "lines.markeredgewidth" : 2,
    "markers.fillstyle" :  'full',
    'lines.markeredgecolor': 'black',
})
axes = plt.axes([0, 0, 0.5, 0.7])
bar_width =  0.2
colors = ["#7CBEEC", "#7EB57E", "#FF6F45", "#3274A1"]
labels = ['penalty', 'cyclic', 'HEA', 'commute']

for i, method in enumerate([penalty, cyclic, HEA, commute]):
  plt.plot(range(len(method)), method, color=colors[i], linewidth=5, label=labels[i])
# axes.set_yscale('log')
plt.savefig("loss.svg", bbox_inches="tight")

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

def exponential_smoothing(data, alpha):
    smoothed = np.zeros_like(data)
    smoothed[0] = data[0]
    for t in range(1, len(data)):
        smoothed[t] = alpha * data[t] + (1 - alpha) * smoothed[t-1]
    return smoothed

scale = 1.05
fig = plt.figure(figsize=(25*scale, 12*scale))
mpl.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Times New Roman',
    'font.size': 65,
    'axes.unicode_minus': False,
    'mathtext.fontset': 'custom',
    'mathtext.rm': 'Times New Roman',
    'mathtext.it': 'Times New Roman:italic',
    'mathtext.bf': 'Times New Roman:bold',
    'axes.linewidth': 5,
    'xtick.major.size': 20,
    'xtick.major.width': 10,
    'ytick.minor.size': 10,
    'ytick.minor.width': 3,
    'ytick.major.size': 20,
    'ytick.major.width': 5,
    "lines.markersize": 35,
    "lines.markeredgewidth": 2,
    "markers.fillstyle": 'full',
    'lines.markeredgecolor': 'black',
})

axes = plt.axes([0, 0, 0.6, 0.7])
bar_width = 0.2
colors = ["#7CBEEC", "#7EB57E", "#FF6F45", "#3274A1"]
labels = ['penalty', 'cyclic', 'HEA', 'commute']
alpha = 0.3  # Smoothing factor, adjust as needed

for i, method in enumerate([penalty, cyclic, HEA, commute]):
    smoothed = exponential_smoothing(np.array(method), alpha)
    plt.plot(smoothed, color=colors[i], linewidth=5, label=labels[i])
    # plt.plot(range(0, len(smoothed), 5), [smoothed[i] for i in range(0, len(smoothed), 5)], color=colors[i], linewidth=5, marker='^',label=labels[i])

plt.legend(frameon=False, bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
axes.set_yscale('log')
plt.axhline(y=13, color='red', linestyle='--', linewidth=3)
index = [i for i in range(0, 151, 50)]
indexs = [i / 4 for i in range(0, 150 * 4 + 1, 50)]
axes.set_xticks(index, minor=False)
axes.set_xticks(indexs, minor=True)
axes.set_xticks([i / 4 for i in range(0, 151 * 4, 50)], minor=True)
plt.savefig("loss.svg", bbox_inches="tight")

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

def exponential_smoothing(data, alpha):
    smoothed = np.zeros_like(data)
    smoothed[0] = data[0]
    for t in range(1, len(data)):
        smoothed[t] = alpha * data[t] + (1 - alpha) * smoothed[t-1]
    return smoothed

scale = 1.05
fig = plt.figure(figsize=(25*scale, 12*scale))
mpl.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Times New Roman',
    'font.size': 65,
    'axes.unicode_minus': False,
    'mathtext.fontset': 'custom',
    'mathtext.rm': 'Times New Roman',
    'mathtext.it': 'Times New Roman:italic',
    'mathtext.bf': 'Times New Roman:bold',
    'axes.linewidth': 5,
    'xtick.major.size': 20,
    'xtick.major.width': 10,
    'ytick.minor.size': 10,
    'ytick.minor.width': 3,
    'ytick.major.size': 20,
    'ytick.major.width': 5,
    "lines.markersize": 35,
    "lines.markeredgewidth": 2,
    "markers.fillstyle": 'full',
    'lines.markeredgecolor': 'black',
})

axes = plt.axes([0, 0, 0.5 / 3, 0.7 /3])
bar_width = 0.2
colors = ["#7CBEEC", "#7EB57E", "#FF6F45", "#3274A1"]
labels = ['penalty', 'cyclic', 'HEA', 'commute']
alpha = 0.3  # Smoothing factor, adjust as needed

for i, method in enumerate([commute]):
    smoothed = exponential_smoothing(np.array(method), alpha)
    plt.plot(smoothed, color=colors[3], linewidth=5, label=labels[i])
# axes.set_ylim(12, 19)
axes.set_yticks([13, 15, 17, 19])
axes.set_yticks([x / 4 for x in range(13 * 4, 19 * 4, 2)], minor=True)
axes.set_xticks([0, 50], minor=False)
axes.set_xticks([10, 20, 30, 40], minor=True)  # Adding 4 auxiliary ticks on the x-axis
plt.axhline(y=13, color='red', linestyle='--', linewidth=3)
plt.legend(frameon=False, bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# axes.set_yscale('log')
plt.savefig("loss.svg", bbox_inches="tight")
