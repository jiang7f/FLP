# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
data = pd.read_csv('depth.csv')
data
# Out:
#     pkid       backend strategy  depth  culled_depth  \
# 0      0      FakeKyiv   [1, 2]   1834           423
# 1      0      FakeKyiv   [1, 1]   1979           488
# 2      0      FakeKyiv   [1, 0]   5152          1220
# 3      0    FakeTorino   [1, 2]   1146           433
# 4      0    FakeTorino   [1, 1]   1282           485
# 5      0    FakeTorino   [1, 0]   3280          1218
# 6      0  FakeBrisbane   [1, 2]   1799           428
# 7      0  FakeBrisbane   [1, 1]   2193           515
# 8      0  FakeBrisbane   [1, 0]   5202          1244
# 9      1      FakeKyiv   [1, 2]   2788           634
# 10     1      FakeKyiv   [1, 1]   4237           962
# 11     1      FakeKyiv   [1, 0]   6354          1574
# 12     1    FakeTorino   [1, 2]   1643           633
# 13     1    FakeTorino   [1, 1]   2481           998
# 14     1    FakeTorino   [1, 0]   3941          1509
# 15     1  FakeBrisbane   [1, 2]   2706           629
# 16     1  FakeBrisbane   [1, 1]   3932           904
# 17     1  FakeBrisbane   [1, 0]   6762          1618
# 18     2      FakeKyiv   [1, 2]   3783           874
# 19     2      FakeKyiv   [1, 1]   4256          1003
# 20     2      FakeKyiv   [1, 0]   4872          1180
# 21     2    FakeTorino   [1, 2]   2224           876
# 22     2    FakeTorino   [1, 1]   2471           975
# 23     2    FakeTorino   [1, 0]   2890          1144
# 24     2  FakeBrisbane   [1, 2]   3654           877
# 25     2  FakeBrisbane   [1, 1]   4322           991
# 26     2  FakeBrisbane   [1, 0]   4901          1121
#
#                                  transpile_time
# 0    (0.005534934811294079, 0.7191331470385194)
# 1    (0.003160913474857807, 0.8451533345505595)
# 2    (0.004356632940471172, 1.9243417354300618)
# 3    (0.004244212992489338, 0.7110392050817609)
# 4   (0.0033484455198049545, 0.6803535250946879)
# 5   (0.0049546025693416595, 1.5242309905588627)
# 6   (0.0029534026980400085, 0.7551510967314243)
# 7    (0.003139662556350231, 0.8921002820134163)
# 8    (0.005138297565281391, 1.8079291190952063)
# 9   (0.0034195929765701294, 1.1439244402572513)
# 10   (0.003911211155354977, 1.7619985518977046)
# 11    (0.006433835253119469, 2.237022241577506)
# 12  (0.0045350417494773865, 0.8922986183315516)
# 13   (0.004660668782889843, 1.1512174690142274)
# 14   (0.006273694336414337, 1.6493349326774478)
# 15   (0.004331614822149277, 1.1250010412186384)
# 16  (0.0053362660109996796, 1.4524316685274243)
# 17     (0.00625098031014204, 2.315054217353463)
# 18   (0.005400080233812332, 1.4771216623485088)
# 19   (0.009509382769465446, 1.5142367500811815)
# 20   (0.006348348222672939, 1.7061134213581681)
# 21   (0.005720893852412701, 0.9459877647459507)
# 22    (0.00627975445240736, 1.2813465166836977)
# 23   (0.006724834442138672, 1.2667350908741355)
# 24   (0.004318214952945709, 1.4327770294621587)
# 25   (0.005265439860522747, 1.3844549041241407)
# 26   (0.007142131216824055, 1.8802129495888948)

# %%
# data.strategy = data.strategy.apply(lambda x: '1' if x else 'qiskit')

# %%
data
# Out:
#     pkid       backend strategy  depth  culled_depth  \
# 0      0      FakeKyiv   [1, 2]   1834           423
# 1      0      FakeKyiv   [1, 1]   1979           488
# 2      0      FakeKyiv   [1, 0]   5152          1220
# 3      0    FakeTorino   [1, 2]   1146           433
# 4      0    FakeTorino   [1, 1]   1282           485
# 5      0    FakeTorino   [1, 0]   3280          1218
# 6      0  FakeBrisbane   [1, 2]   1799           428
# 7      0  FakeBrisbane   [1, 1]   2193           515
# 8      0  FakeBrisbane   [1, 0]   5202          1244
# 9      1      FakeKyiv   [1, 2]   2788           634
# 10     1      FakeKyiv   [1, 1]   4237           962
# 11     1      FakeKyiv   [1, 0]   6354          1574
# 12     1    FakeTorino   [1, 2]   1643           633
# 13     1    FakeTorino   [1, 1]   2481           998
# 14     1    FakeTorino   [1, 0]   3941          1509
# 15     1  FakeBrisbane   [1, 2]   2706           629
# 16     1  FakeBrisbane   [1, 1]   3932           904
# 17     1  FakeBrisbane   [1, 0]   6762          1618
# 18     2      FakeKyiv   [1, 2]   3783           874
# 19     2      FakeKyiv   [1, 1]   4256          1003
# 20     2      FakeKyiv   [1, 0]   4872          1180
# 21     2    FakeTorino   [1, 2]   2224           876
# 22     2    FakeTorino   [1, 1]   2471           975
# 23     2    FakeTorino   [1, 0]   2890          1144
# 24     2  FakeBrisbane   [1, 2]   3654           877
# 25     2  FakeBrisbane   [1, 1]   4322           991
# 26     2  FakeBrisbane   [1, 0]   4901          1121
#
#                                  transpile_time
# 0    (0.005534934811294079, 0.7191331470385194)
# 1    (0.003160913474857807, 0.8451533345505595)
# 2    (0.004356632940471172, 1.9243417354300618)
# 3    (0.004244212992489338, 0.7110392050817609)
# 4   (0.0033484455198049545, 0.6803535250946879)
# 5   (0.0049546025693416595, 1.5242309905588627)
# 6   (0.0029534026980400085, 0.7551510967314243)
# 7    (0.003139662556350231, 0.8921002820134163)
# 8    (0.005138297565281391, 1.8079291190952063)
# 9   (0.0034195929765701294, 1.1439244402572513)
# 10   (0.003911211155354977, 1.7619985518977046)
# 11    (0.006433835253119469, 2.237022241577506)
# 12  (0.0045350417494773865, 0.8922986183315516)
# 13   (0.004660668782889843, 1.1512174690142274)
# 14   (0.006273694336414337, 1.6493349326774478)
# 15   (0.004331614822149277, 1.1250010412186384)
# 16  (0.0053362660109996796, 1.4524316685274243)
# 17     (0.00625098031014204, 2.315054217353463)
# 18   (0.005400080233812332, 1.4771216623485088)
# 19   (0.009509382769465446, 1.5142367500811815)
# 20   (0.006348348222672939, 1.7061134213581681)
# 21   (0.005720893852412701, 0.9459877647459507)
# 22    (0.00627975445240736, 1.2813465166836977)
# 23   (0.006724834442138672, 1.2667350908741355)
# 24   (0.004318214952945709, 1.4327770294621587)
# 25   (0.005265439860522747, 1.3844549041241407)
# 26   (0.007142131216824055, 1.8802129495888948)

# %%
data['transpile_time'] = data['transpile_time'].apply(lambda x: eval(x)[0]  + eval(x)[1] if x!= 'timeout' else 'timeout')
# data['unitarydecomposition'] = data['transpile_time'].apply(lambda x: eval(x)[1] if x!= 'timeout' else 'timeout')

# %%
data
# Out:
#     pkid       backend strategy  depth  culled_depth  transpile_time
# 0      0      FakeKyiv   [1, 2]   1834           423        0.724668
# 1      0      FakeKyiv   [1, 1]   1979           488        0.848314
# 2      0      FakeKyiv   [1, 0]   5152          1220        1.928698
# 3      0    FakeTorino   [1, 2]   1146           433        0.715283
# 4      0    FakeTorino   [1, 1]   1282           485        0.683702
# 5      0    FakeTorino   [1, 0]   3280          1218        1.529186
# 6      0  FakeBrisbane   [1, 2]   1799           428        0.758104
# 7      0  FakeBrisbane   [1, 1]   2193           515        0.895240
# 8      0  FakeBrisbane   [1, 0]   5202          1244        1.813067
# 9      1      FakeKyiv   [1, 2]   2788           634        1.147344
# 10     1      FakeKyiv   [1, 1]   4237           962        1.765910
# 11     1      FakeKyiv   [1, 0]   6354          1574        2.243456
# 12     1    FakeTorino   [1, 2]   1643           633        0.896834
# 13     1    FakeTorino   [1, 1]   2481           998        1.155878
# 14     1    FakeTorino   [1, 0]   3941          1509        1.655609
# 15     1  FakeBrisbane   [1, 2]   2706           629        1.129333
# 16     1  FakeBrisbane   [1, 1]   3932           904        1.457768
# 17     1  FakeBrisbane   [1, 0]   6762          1618        2.321305
# 18     2      FakeKyiv   [1, 2]   3783           874        1.482522
# 19     2      FakeKyiv   [1, 1]   4256          1003        1.523746
# 20     2      FakeKyiv   [1, 0]   4872          1180        1.712462
# 21     2    FakeTorino   [1, 2]   2224           876        0.951709
# 22     2    FakeTorino   [1, 1]   2471           975        1.287626
# 23     2    FakeTorino   [1, 0]   2890          1144        1.273460
# 24     2  FakeBrisbane   [1, 2]   3654           877        1.437095
# 25     2  FakeBrisbane   [1, 1]   4322           991        1.389720
# 26     2  FakeBrisbane   [1, 0]   4901          1121        1.887355

# %%
dataused = data.pivot(index =['pkid', 'backend'], columns='strategy', values=["culled_depth",'transpile_time'])
dataused
# Out:
#                   culled_depth                transpile_time            \
# strategy                [1, 0]  [1, 1] [1, 2]         [1, 0]    [1, 1]
# pkid backend
# 0    FakeBrisbane       1244.0   515.0  428.0       1.813067  0.895240
#      FakeKyiv           1220.0   488.0  423.0       1.928698  0.848314
#      FakeTorino         1218.0   485.0  433.0       1.529186  0.683702
# 1    FakeBrisbane       1618.0   904.0  629.0       2.321305  1.457768
#      FakeKyiv           1574.0   962.0  634.0       2.243456  1.765910
#      FakeTorino         1509.0   998.0  633.0       1.655609  1.155878
# 2    FakeBrisbane       1121.0   991.0  877.0       1.887355  1.389720
#      FakeKyiv           1180.0  1003.0  874.0       1.712462  1.523746
#      FakeTorino         1144.0   975.0  876.0       1.273460  1.287626
#
#
# strategy             [1, 2]
# pkid backend
# 0    FakeBrisbane  0.758104
#      FakeKyiv      0.724668
#      FakeTorino    0.715283
# 1    FakeBrisbane  1.129333
#      FakeKyiv      1.147344
#      FakeTorino    0.896834
# 2    FakeBrisbane  1.437095
#      FakeKyiv      1.482522
#      FakeTorino    0.951709

# %%
dataused['culled_depth']['[1, 0]']
# Out:
# pkid  backend
# 0     FakeBrisbane    1244.0
#       FakeKyiv        1220.0
#       FakeTorino      1218.0
# 1     FakeBrisbane    1618.0
#       FakeKyiv        1574.0
#       FakeTorino      1509.0
# 2     FakeBrisbane    1121.0
#       FakeKyiv        1180.0
#       FakeTorino      1144.0
# Name: [1, 0], dtype: float64

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
scale = 1.05
fig= plt.figure(figsize=(25*scale, 12*scale))
mpl.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Times New Roman',
    'font.size': 65,
    'axes.unicode_minus': False,
    'mathtext.fontset': 'custom',
    'mathtext.rm': 'Times New Roman',
    'mathtext.it': 'Times New Roman:italic',
    'mathtext.bf': 'Times New Roman:bold',
    'axes.linewidth': 5,
    'xtick.major.size': 20,
    'xtick.major.width': 5,
    'ytick.minor.size': 10,
    'ytick.minor.width': 3,
    'ytick.major.size': 20,
    'ytick.major.width': 5,
    "markers.fillstyle" :  'left' , ## default
    "lines.markersize" : 30,
    "lines.markeredgewidth" : 3,
    # 'lines.markeredgecolor': 'black',
})
bar_width = 0.118
shrink = 0.05

colors = ["#7CBEEC", "#7EB57E", "#FF6F45", "#3274A1"]
labels = ['depth', 'rss usage (MB)']
# for i, metric in enumerate( ["culled_depth",'rss_usage']):
i = 0
axes = plt.axes([0, 0, 1, 0.37])
ylabel = 'depth'

indexs = [i for i in np.arange(0, len(dataused.index.values))]
for i in range(0, len(indexs) - 1, 3):
    indexs[i] += shrink
    indexs[i + 2] -= shrink

ymetric = "culled_depth" # best_solution_probs
axes.bar([index - 5 * bar_width / 2 for index in indexs], dataused[ymetric]['[1, 0]'].astype(float), linewidth=3, edgecolor='black', width=bar_width, label="strategy 1",
        color=colors[0])
axes.bar([index - 3 * bar_width / 2 for index in indexs], dataused[ymetric]['[1, 1]'].astype(float), linewidth=3, edgecolor='black', width=bar_width, label="strategy 2",
        color=colors[1])
axes.bar([index - 1 * bar_width / 2 for index in indexs], dataused[ymetric]['[1, 2]'].astype(float), linewidth=3, edgecolor='black', width=bar_width, label="strategy 3",
        color=colors[2])
axes.bar([index + 1 * bar_width / 2 for index in indexs], 2 * dataused[ymetric]['[1, 0]'].astype(float), linewidth=3, edgecolor='black', width=bar_width, label="strategy 4",
        color=colors[3])
axes.bar([index + 3 * bar_width / 2 for index in indexs], 2 * dataused[ymetric]['[1, 1]'].astype(float), linewidth=3, edgecolor='black', width=bar_width, label="strategy 5",
        color=colors[2])
axes.bar([index + 5 * bar_width / 2 for index in indexs], 2 * dataused[ymetric]['[1, 2]'].astype(float), linewidth=3, edgecolor='black', width=bar_width, label="strategy 6",
        color=colors[1])
index = indexs
axes.set_xticks(index, minor=False)
axes.set_yticks(range(0, 3500, 1000), minor=False)
axes.set_ylabel(r"depth")
axes.grid(axis="y", color="gray", linestyle="--", linewidth=1, dashes=(2, 2))

axes.set_xticklabels(range(0, 9), minor=False)
axes.set_xlim(0 - 4 * bar_width + shrink, 8 + 4 * bar_width - shrink)
axes.legend(frameon=False, bbox_to_anchor=(0, 1.05), loc='lower left', ncol=3, prop={'size': 60})
