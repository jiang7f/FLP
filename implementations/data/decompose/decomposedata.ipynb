# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
data = pd.read_csv('depth_linear.csv')
data
# Out:
#     pkid  qubits  layers  use_decompose  \
# 0      0       5       1           True
# 1      1       6       1           True
# 2      2       7       1           True
# 3      3       8       1           True
# 4      4       9       1           True
# 5      5      10       1           True
# 6      6      11       1           True
# 7      7      12       1           True
# 8      0       5       1          False
# 9      1       6       1          False
# 10     2       7       1          False
# 11     3       8       1          False
# 12     4       9       1          False
# 13     5      10       1          False
# 14     6      11       1          False
# 15     7      12       1          False
#
#                                    transpile_time     depth culled_depth  \
# 0     (0.00244794599711895, 0.015405298676341772)        70           24
# 1   (0.0028892005793750286, 0.017804833129048347)        87           30
# 2    (0.002700876910239458, 0.019662381149828434)       104           36
# 3   (0.0030056266114115715, 0.023305156268179417)       121           42
# 4    (0.0039010453037917614, 0.04165290668606758)       138           48
# 5    (0.0038021961227059364, 0.02765605878084898)       155           54
# 6     (0.005069174338132143, 0.05357254762202501)       172           60
# 7     (0.004276120103895664, 0.03148135915398598)       189           66
# 8       (0.007134004030376673, 5.281226423103362)      6150         1678
# 9       (0.25811708299443126, 25.156977445818484)     33289         8960
# 10       (14.347013911698014, 107.57989941816777)    165562        44624
# 11        (19.348307428881526, 540.3496752148494)    785754       211609
# 12          (23.161806575022638, 10578.697201306)   3622600       975242
# 13        (26.686505811754614, 72048.29551221104)  16372781      4406123
# 14                                        timeout   timeout      timeout
# 15                                        timeout   timeout      timeout
#
#         rss_usage
# 0       5.0390625
# 1       4.6953125
# 2      5.60546875
# 3      5.18359375
# 4       5.1640625
# 5        5.078125
# 6       5.0546875
# 7      5.07421875
# 8     33.66015625
# 9      112.828125
# 10   511.43359375
# 11  2195.15234375
# 12  9595.02734375
# 13   42355.640625
# 14        timeout
# 15        timeout

# %%
data.use_decompose = data.use_decompose.apply(lambda x: 'QAcOA-CH' if x else 'qiskit')

# %%
data
# Out:
#     pkid  qubits  layers use_decompose  \
# 0      0       5       1      QAcOA-CH
# 1      1       6       1      QAcOA-CH
# 2      2       7       1      QAcOA-CH
# 3      3       8       1      QAcOA-CH
# 4      4       9       1      QAcOA-CH
# 5      5      10       1      QAcOA-CH
# 6      6      11       1      QAcOA-CH
# 7      7      12       1      QAcOA-CH
# 8      0       5       1        qiskit
# 9      1       6       1        qiskit
# 10     2       7       1        qiskit
# 11     3       8       1        qiskit
# 12     4       9       1        qiskit
# 13     5      10       1        qiskit
# 14     6      11       1        qiskit
# 15     7      12       1        qiskit
#
#                                    transpile_time     depth culled_depth  \
# 0     (0.00244794599711895, 0.015405298676341772)        70           24
# 1   (0.0028892005793750286, 0.017804833129048347)        87           30
# 2    (0.002700876910239458, 0.019662381149828434)       104           36
# 3   (0.0030056266114115715, 0.023305156268179417)       121           42
# 4    (0.0039010453037917614, 0.04165290668606758)       138           48
# 5    (0.0038021961227059364, 0.02765605878084898)       155           54
# 6     (0.005069174338132143, 0.05357254762202501)       172           60
# 7     (0.004276120103895664, 0.03148135915398598)       189           66
# 8       (0.007134004030376673, 5.281226423103362)      6150         1678
# 9       (0.25811708299443126, 25.156977445818484)     33289         8960
# 10       (14.347013911698014, 107.57989941816777)    165562        44624
# 11        (19.348307428881526, 540.3496752148494)    785754       211609
# 12          (23.161806575022638, 10578.697201306)   3622600       975242
# 13        (26.686505811754614, 72048.29551221104)  16372781      4406123
# 14                                        timeout   timeout      timeout
# 15                                        timeout   timeout      timeout
#
#         rss_usage
# 0       5.0390625
# 1       4.6953125
# 2      5.60546875
# 3      5.18359375
# 4       5.1640625
# 5        5.078125
# 6       5.0546875
# 7      5.07421875
# 8     33.66015625
# 9      112.828125
# 10   511.43359375
# 11  2195.15234375
# 12  9595.02734375
# 13   42355.640625
# 14        timeout
# 15        timeout

# %%
data['transpile_time'] = data['transpile_time'].apply(lambda x: eval(x)[0]  + eval(x)[1] if x!= 'timeout' else 'timeout')
# data['unitarydecomposition'] = data['transpile_time'].apply(lambda x: eval(x)[1] if x!= 'timeout' else 'timeout')

# %%
data
# Out:
#     pkid  qubits  layers use_decompose transpile_time     depth culled_depth  \
# 0      0       5       1      QAcOA-CH       0.017853        70           24
# 1      1       6       1      QAcOA-CH       0.020694        87           30
# 2      2       7       1      QAcOA-CH       0.022363       104           36
# 3      3       8       1      QAcOA-CH       0.026311       121           42
# 4      4       9       1      QAcOA-CH       0.045554       138           48
# 5      5      10       1      QAcOA-CH       0.031458       155           54
# 6      6      11       1      QAcOA-CH       0.058642       172           60
# 7      7      12       1      QAcOA-CH       0.035757       189           66
# 8      0       5       1        qiskit        5.28836      6150         1678
# 9      1       6       1        qiskit      25.415095     33289         8960
# 10     2       7       1        qiskit     121.926913    165562        44624
# 11     3       8       1        qiskit     559.697983    785754       211609
# 12     4       9       1        qiskit   10601.859008   3622600       975242
# 13     5      10       1        qiskit   72074.982018  16372781      4406123
# 14     6      11       1        qiskit        timeout   timeout      timeout
# 15     7      12       1        qiskit        timeout   timeout      timeout
#
#         rss_usage
# 0       5.0390625
# 1       4.6953125
# 2      5.60546875
# 3      5.18359375
# 4       5.1640625
# 5        5.078125
# 6       5.0546875
# 7      5.07421875
# 8     33.66015625
# 9      112.828125
# 10   511.43359375
# 11  2195.15234375
# 12  9595.02734375
# 13   42355.640625
# 14        timeout
# 15        timeout

# %%
dataused = data.pivot(index =['qubits'], columns='use_decompose', values=["culled_depth",'rss_usage','transpile_time'])
dataused
# Out:
#               culled_depth            rss_usage                transpile_time  \
# use_decompose     QAcOA-CH   qiskit    QAcOA-CH         qiskit       QAcOA-CH
# qubits
# 5                       24     1678   5.0390625    33.66015625       0.017853
# 6                       30     8960   4.6953125     112.828125       0.020694
# 7                       36    44624  5.60546875   511.43359375       0.022363
# 8                       42   211609  5.18359375  2195.15234375       0.026311
# 9                       48   975242   5.1640625  9595.02734375       0.045554
# 10                      54  4406123    5.078125   42355.640625       0.031458
# 11                      60  timeout   5.0546875        timeout       0.058642
# 12                      66  timeout  5.07421875        timeout       0.035757
#
#
# use_decompose        qiskit
# qubits
# 5                   5.28836
# 6                 25.415095
# 7                121.926913
# 8                559.697983
# 9              10601.859008
# 10             72074.982018
# 11                  timeout
# 12                  timeout

# %%
dataused['culled_depth']['qiskit']
# Out:
# qubits
# 5        1678
# 6        8960
# 7       44624
# 8      211609
# 9      975242
# 10    4406123
# 11    timeout
# 12    timeout
# Name: qiskit, dtype: object

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
scale = 1.05
fig= plt.figure(figsize=(25*scale, 6*scale))
mpl.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'Times New Roman',
    'font.size': 65,
    'axes.unicode_minus': False,
    'mathtext.fontset': 'custom',
    'mathtext.rm': 'Times New Roman',
    'mathtext.it': 'Times New Roman:italic',
    'mathtext.bf': 'Times New Roman:bold',
    'axes.linewidth': 5,
    'xtick.major.size': 20,
    'xtick.major.width': 5,
    'ytick.minor.size': 10,
    'ytick.minor.width': 3,
    'ytick.major.size': 20,
    'ytick.major.width': 5,
    "lines.markersize" : 35,
    "lines.markeredgewidth" : 2,
    "markers.fillstyle" :  'full',
    'lines.markeredgecolor': 'black',
})
bar_width =  0.25
figwidth = 0.37

colors = ["#7CBEEC", "#7EB57E", "#FF6F45", "#3274A1"]
labels = ['depth', 'rss usage (MB)']
# for i, metric in enumerate( ["culled_depth",'rss_usage']):
i = 0
axes = plt.axes([0, 0, figwidth, 1])
ylabel = 'depth'
layers = np.arange(1, len(dataused.index.values) + 1)

ymetric = "culled_depth"# best_solution_probs
axes.plot(layers,dataused[ymetric]['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan), 
        #   width=bar_width,
        marker='o', markeredgewidth=2,
        label="qiskit", color=colors[2])
axes.plot(layers,dataused[ymetric]['QAcOA-CH'].astype(float), 
        #   width=bar_width,
        marker='^', markeredgewidth=2,
        label="QAcOA-CH", color=colors[3])

axes.set_xticks(np.arange(1,len(dataused.index.values)+1))
axes.set_xticklabels(dataused.index.values)
axes.set_ylim(1,10**8)

axes.set_yscale('log')
axes.set_ylabel(ylabel)

# axes.set_yticks([10**0, 10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7,10**8], minor=True)
# axes.set_yticklabels([], minor=True)
axes.set_yticks([10**0, 10**3, 10**6,10**9], minor=False)
axes.set_xlabel("#qubit")
axes.grid(axis="y", color="gray", linestyle="--", linewidth=1)
if True:
        axes = plt.axes([0.5, 0,figwidth, 1])
        ylabel =  'calculation time (s)'
        layers = np.arange(1,len(dataused.index.values)+1)
        # axes.bar(layers-0.5*bar_width,dataused['classicalcalculation']['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan),bottom = dataused['unitarydecomposition']['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan), width=bar_width,
        #         label="qiskit", color=colors[2], hatch='///', edgecolor='black')
        # axes.bar(layers+0.5*bar_width,dataused['classicalcalculation']['QAcOA-CH'].astype(float),bottom = dataused['unitarydecomposition']['QAcOA-CH'].astype(float),
        #         width=bar_width,
        #         label="QAcOA-CH", color=colors[3], hatch='///', edgecolor='black')
        axes.bar(layers-0.5*bar_width,dataused['transpile_time']['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan), width=bar_width,
                label="qiskit", color=colors[2],
                linewidth=2, edgecolor='black',
                )
        axes.bar(layers+0.5*bar_width,dataused['transpile_time']['QAcOA-CH'].astype(float), width=bar_width,
                label="QAcOA-CH", color=colors[3],
                linewidth=2, edgecolor='black',
                )
        # axes.bar(layers-0.5*bar_width,dataused['classicalcalculation']['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan), width=bar_width,
        #         label="qiskit", color=colors[2], hatch='///', edgecolor='black')
        # axes.bar(layers+0.5*bar_width,dataused['classicalcalculation']['QAcOA-CH'].astype(float),
        #         width=bar_width,
        #         label="QAcOA-CH", color=colors[3], hatch='///', edgecolor='black')
        axes.set_ylim(10**-2,10**7)
        axes.legend(frameon=False, bbox_to_anchor=(-0.2, 1.05), loc='lower center', ncol=4, prop={'size': 60})
        
        # axes.set_ylabel(ylabel)
        axes.set_yscale("log")
        axes.set_xticks(np.arange(1,len(dataused.index.values)+1))
        axes.set_xticklabels(dataused.index.values)
        axes.set_xlabel("#qubit")
        axes.set_yticks([10**-2,  10**-1,10**0, 10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7], minor=True)
        axes.set_yticklabels([], minor=True)
        axes.set_yticks([10**-2, 10**0, 10**4, 10**7], minor=False)
        axes.set_yticklabels([10**-2, 10**1, 10**4, 10**7], minor=False)
        axes.hlines(10**-1, 0.5, len(dataused.index.values)+0.5, colors='red', linestyles='--', linewidth=3)
        axes2 = axes.twinx()
        ymetric = "rss_usage"
        # # 用来把右半边涂成白色
        # axes2.plot(layers - 0.5 * bar_width, dataused[ymetric]['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan), label="qiskit", color=colors[2], 
        #            marker='o', 
        #            markerfacecolor='white', fillstyle='full', linestyle='none', 
        #            )
        axes2.plot(layers + 0.5 * bar_width, dataused[ymetric]['qiskit'].apply(lambda x: float(x) if x != 'timeout' else np.nan), label="qiskit", color=colors[2], 
                   marker='o',
                   linestyle='-', 
                   )
        # axes2.plot(layers - 0.5 * bar_width, dataused[ymetric]['QAcOA-CH'].astype(float), label="QAcOA-CH", color=colors[3], 
        #            marker='^',
        #            markerfacecolor='white', fillstyle='full', linestyle='none', 
        #            )
        axes2.plot(layers + 0.5 * bar_width, dataused[ymetric]['QAcOA-CH'].astype(float), label="QAcOA-CH", color=colors[3], 
                   marker='^',
                   linestyle='-')
        axes2.set_ylabel("rss usage (MB)")
        axes2.set_ylim(10**-1,10**5)
        axes.set_yticks([10**-2,  10**-1,10**0, 10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7], minor=True)
        axes.set_yticklabels([], minor=True)
        axes.set_yticks([10**-2, 10**0, 10**4, 10**7], minor=False)
        axes.set_yticklabels([10**-2, 10**1, 10**4, 10**7], minor=False)
       
        axes2.set_yscale("log")

axes.grid(axis="y", color="gray", linestyle="--", linewidth=1)
### set bakground color
axes.set_facecolor("#fffef877")
# axes.set_title("Comparison of QAcOA-CH with other algorithms")
# axes.set_xlabel("#layer")
axes.set_ylabel(ylabel)
axes.set_yscale("log")
axes2.legend(frameon=False, bbox_to_anchor=(-0.2, 1.05), loc='lower center', ncol=4, prop={'size': 60})
# plt.tight_layout()
plt.savefig("decomposedepth.svg", bbox_inches="tight")
